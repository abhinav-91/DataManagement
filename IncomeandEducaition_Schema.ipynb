# %% [markdown]
# ### Data source:
#
# The data is from US department of education, you can download the data here: https://ed-public-download.apps.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip.
#
# For detailed explaination of each column, you can see the database documentation: https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf

# %%
# !wget https://ed-public-download.apps.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
# Out:
# --2016-12-06 19:15:16--  https://ed-public-download.apps.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
# Resolving ed-public-download.apps.cloud.gov... 52.200.27.11, 54.85.34.4, 2406:da00:ff00::34c8:1b0b, ...
# Connecting to ed-public-download.apps.cloud.gov|52.200.27.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240264190 (229M) [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data.zip’
#
# CollegeScorecard_Ra 100%[===================>] 229.13M  17.4MB/s    in 12s
#
# 2016-12-06 19:15:29 (18.6 MB/s) - ‘CollegeScorecard_Raw_Data.zip’ saved [240264190/240264190]

# %%
# !wget https://raw.githubusercontent.com/abhinav-91/DataManagement/master/lin_urls.txt
# Out:
# --2016-12-06 19:15:29--  https://raw.githubusercontent.com/abhinav-91/DataManagement/master/lin_urls.txt
# Resolving raw.githubusercontent.com... 151.101.32.133
# Connecting to raw.githubusercontent.com|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 348 [text/plain]
# Saving to: ‘lin_urls.txt’
#
# lin_urls.txt        100%[===================>]     348  --.-KB/s    in 0s
#
# 2016-12-06 19:15:29 (33.2 MB/s) - ‘lin_urls.txt’ saved [348/348]

# %%
# !wget -i lin_urls.txt
# Out:
# --2016-12-06 19:15:30--  https://github.com/abhinav-91/DataManagement/raw/master/income06.zip
# Resolving github.com... 192.30.253.113, 192.30.253.112
# Connecting to github.com|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income06.zip [following]
# --2016-12-06 19:15:30--  https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income06.zip
# Resolving raw.githubusercontent.com... 151.101.32.133
# Connecting to raw.githubusercontent.com|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12956277 (12M) [application/octet-stream]
# Saving to: ‘income06.zip’
#
# income06.zip        100%[===================>]  12.36M  12.4MB/s    in 1.0s
#
# 2016-12-06 19:15:31 (12.4 MB/s) - ‘income06.zip’ saved [12956277/12956277]
#
# --2016-12-06 19:15:31--  https://github.com/abhinav-91/DataManagement/raw/master/income07.zip
# Connecting to github.com|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income07.zip [following]
# --2016-12-06 19:15:31--  https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income07.zip
# Connecting to raw.githubusercontent.com|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21968679 (21M) [application/octet-stream]
# Saving to: ‘income07.zip’
#
# income07.zip        100%[===================>]  20.95M  14.4MB/s    in 1.5s
#
# 2016-12-06 19:15:33 (14.4 MB/s) - ‘income07.zip’ saved [21968679/21968679]
#
# --2016-12-06 19:15:33--  https://github.com/abhinav-91/DataManagement/raw/master/income08.zip
# Connecting to github.com|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income08.zip [following]
# --2016-12-06 19:15:33--  https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income08.zip
# Connecting to raw.githubusercontent.com|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17908767 (17M) [application/octet-stream]
# Saving to: ‘income08.zip’
#
# income08.zip        100%[===================>]  17.08M  13.7MB/s    in 1.2s
#
# 2016-12-06 19:15:34 (13.7 MB/s) - ‘income08.zip’ saved [17908767/17908767]
#
# --2016-12-06 19:15:34--  https://github.com/abhinav-91/DataManagement/raw/master/income09.zip
# Connecting to github.com|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income09.zip [following]
# --2016-12-06 19:15:34--  https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income09.zip
# Connecting to raw.githubusercontent.com|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18375324 (18M) [application/octet-stream]
# Saving to: ‘income09.zip’
#
# income09.zip        100%[===================>]  17.52M  8.85MB/s    in 2.0s
#
# 2016-12-06 19:15:36 (8.85 MB/s) - ‘income09.zip’ saved [18375324/18375324]
#
# --2016-12-06 19:15:36--  https://github.com/abhinav-91/DataManagement/raw/master/income10.zip
# Connecting to github.com|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income10.zip [following]
# --2016-12-06 19:15:36--  https://raw.githubusercontent.com/abhinav-91/DataManagement/master/income10.zip
# Connecting to raw.githubusercontent.com|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18496416 (18M) [application/octet-stream]
# Saving to: ‘income10.zip’
#
# income10.zip        100%[===================>]  17.64M  12.0MB/s    in 1.5s
#
# 2016-12-06 19:15:38 (12.0 MB/s) - ‘income10.zip’ saved [18496416/18496416]
#
# FINISHED --2016-12-06 19:15:38--
# Total wall clock time: 8.6s
# Downloaded: 5 files, 86M in 7.1s (12.0 MB/s)

# %%
# !unzip '*.zip'
# Out:
# Archive:  CollegeScorecard_Raw_Data.zip
#   inflating: Crosswalks_20160908.zip
#   inflating: MERGED1996_97_PP.csv
#   inflating: MERGED1997_98_PP.csv
#   inflating: MERGED1998_99_PP.csv
#   inflating: MERGED1999_00_PP.csv
#   inflating: MERGED2000_01_PP.csv
#   inflating: MERGED2001_02_PP.csv
#   inflating: MERGED2002_03_PP.csv
#   inflating: MERGED2003_04_PP.csv
#   inflating: MERGED2004_05_PP.csv
#   inflating: MERGED2005_06_PP.csv
#   inflating: MERGED2006_07_PP.csv
#   inflating: MERGED2007_08_PP.csv
#   inflating: MERGED2008_09_PP.csv
#   inflating: MERGED2009_10_PP.csv
#   inflating: MERGED2010_11_PP.csv
#   inflating: MERGED2011_12_PP.csv
#   inflating: MERGED2012_13_PP.csv
#   inflating: MERGED2013_14_PP.csv
#   inflating: MERGED2014_15_PP.csv
#
# Archive:  income06.zip
#   inflating: zipcode06.csv
#
# Archive:  income07.zip
#   inflating: zipcode07.csv
#
# Archive:  income08.zip
#   inflating: 08zpall.csv
#
# Archive:  income09.zip
#   inflating: 09zpallagi.csv
#
# Archive:  income10.zip
#   inflating: 10zpallagi.csv
#
# Archive:  income08.zip
# replace 08zpall.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# !csvstack -g 2007,2008,2009,2010 MERGED2007_08_PP.csv MERGED2008_09_PP.csv MERGED2009_10_PP.csv MERGED2010_11_PP.csv > Education.csv

# %% [markdown]
# ### Choose useful columns to create new datasets

# %% [markdown]
# I choose 25 columns that correlated with 7 aspects (listed in the order as the database)
#
# ### Basic information about Institutions
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#
# ### Award of the institution
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#
#     There are several elements that identify the degree profile of the institution. Highest degree (HIGHDEG) identifies the highest award level. This designation differs from the highest degree element in that it is based on an institution’s reported offerings, rather than on degree or certificate completions. For example, an institution may offer a bachelor’s degree program but only infrequently have students that earn the degree. The level of institution element would consistently classify this institution as 4-year, but the highest degree element would potentially vary from year-to-year.
#
# ### Administration rate
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#
#     For institutions with multiple branches, ADM_RATE includes the admissions rate at each campus, while ADM_RATE_ALL represents the admissions rate across all campuses, defined as the total number of admitted undergraduates across all branches divided by the total number of undergraduates who applied across all branches.
#
# ### SAT scores
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#
# ### Retention rate
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#
#     Available through the IPEDS Fall Enrollment component, retention rate identifies (separately) the share of full-time and part-time students in the prior year, at four-year (RET_FT4 and RET_PT4) and less-than-four- year institutions (RET_FTL4 and RET_PTL4), who return to the institution after the first year.
#
# ### Family income
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#
#     Using data from NSLDS, these elements calculate the percentage of Title IV-receiving students who had family income data from the Free Application for Federal Student Aid (FAFSA) for each of five income quintiles16 (INC_PCT_LO = $0-$30,000; INC_PCT_M1 = $30,001-$48,000; INC_PCT_M2=$48,001-$75,000; INC_PCT_H1=$75,001-$110,000; and INC_PCT_H2 = $110,001+).
#
# ### Debt of students
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18)
#
#     This is the median loan debt accumulatedat the institution by all student borrowers of federal loans who separate (i.e., either graduate or withdraw) in a given fiscal year, measured at the point of separation (DEBT_MDN).More specifically, the measure represents the sum of all undergraduate federal loans over students’ college education at the institution for which the median debt is reported for —e.g., if a student receives a federal loan for $2,000 for each of eight semesters at one institution,their cumulative debt is recorded as $16,000 forthat institution.
#     These data are available for all borrowers at the institution, as well as disaggregated by completion status (GRAD_DEBT_MDN for students who completed and WDRAW_DEBT_MDN for students who withdrew without completing25); by FAFSA family income26 (LO_INC_DEBT_MDN = $0-$30,000; MD_INC_DEBT_MDN = $30,001-$75,000; and HI_INC_DEBT_MDN = $75,001+);
#
# ### Earnings
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#
#     Mean (MN_EARN_WNE_P*) and median (MD_EARN_WNE_P*) earnings are for the institutional aggregate of all federally aided students who enroll in an institution each year and who are employed but not enrolled. Earnings are defined as the sum of wages and deferred compensation from all non-duplicate W-2 forms received for each individual, plus positive self- employment earnings from Schedule SE. Data are available for each year starting six years after a student enrolls in college, up to 10 years after the student enrolls; enrollment dates are estimated based on FAFSA self-reporting, as with the completion rate cohort construction described above.
#
#     Mean earnings are also available disaggregated by FAFSA family income31 (MN_EARN_WNE_INC1_P*, MN_EARN_WNE_INC2_P*, and MN_EARN_WNE_INC3_P*); by dependent status (for dependents, MN_EARN_WNE_INDEP0 _P*; and for independents, MN_EARN_WNE_INDEP1_P*); and by gender (for female, MN_EARN_WNE_MALE0_P*; and for male, MN_EARN_WNE_MALE1_P*).

# %%
# !csvcut -c1,5,6,7,8,17,1740,38,39,61,62,430,431,432,433,1409,1414,1415,1416,1417,1505,1506,1507,1508,1509,1510,1666,1692,1697,1707,1640,1667,1698,1641 Education.csv > FinalEducation.csv

# %%
# %reload_ext sql

# %%
# !createdb -U abhinav incomefinal5

# %%
# %sql postgresql://abhinav:Sigma1991@localhost/incomefinal5
# Out:
# 'Connected: abhinav@incomefinal5'

# %% [markdown]
# ### Load csv to database and add corresponding year for every record

# %%
# !csvstat FinalEducation.csv
# Out:
#   1. group
# 	<class 'int'>
# 	Nulls: False
# 	Values: 2007
#   2. INSTNM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1676
# 	5 most frequent values:
# 		Marinello School of Beauty:	11
# 		ATI Career Training Center:	3
# 		Southeastern University:	2
# 		Glendale Community College:	2
# 		Galen College of Medical and Dental Assistants:	2
# 	Max length: 84
#   3. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 778
# 	5 most frequent values:
# 		Chicago:	60
# 		Los Angeles:	36
# 		San Diego:	24
# 		Atlanta:	24
# 		Phoenix:	21
# 	Max length: 23
#   4. STABBR
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 27
# 	5 most frequent values:
# 		CA:	412
# 		IL:	189
# 		FL:	154
# 		GA:	112
# 		IN:	105
# 	Max length: 2
#   5. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1595
# 	5 most frequent values:
# 		60605:	4
# 		90010:	4
# 		94103:	4
# 		30309:	3
# 		70119:	3
# 	Max length: 10
#   6. HIGHDEG
# 	<class 'int'>
# 	Nulls: False
# 	Values: 0, 1, 2, 3, 4
#   7. ICLEVEL
# 	<class 'int'>
# 	Nulls: False
# 	Values: 1, 2, 3
#   8. ADM_RATE
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.089
# 	Max: 1.0
# 	Sum: 469.2226999999998
# 	Mean: 0.6800328985507244
# 	Median: 0.68975
# 	Standard Deviation: 0.2051785506036881
# 	Unique values: 587
# 	5 most frequent values:
# 		1.0:	60
# 		0.5:	4
# 		0.677:	3
# 		0.8571:	3
# 		0.75:	3
#   9. ADM_RATE_ALL
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.089
# 	Max: 1.0
# 	Sum: 478.58879999999965
# 	Mean: 0.6798136363636359
# 	Median: 0.6890000000000001
# 	Standard Deviation: 0.20095633157582582
# 	Unique values: 586
# 	5 most frequent values:
# 		1.0:	58
# 		0.9212:	6
# 		0.8377:	4
# 		0.5:	3
# 		0.5803:	3
#  10. SAT_AVG
# 	<class 'int'>
# 	Nulls: True
# 	Min: 781
# 	Max: 1517
# 	Sum: 482815
# 	Mean: 1047.3210412147505
# 	Median: 1030
# 	Standard Deviation: 125.3385046596849
# 	Unique values: 277
# 	5 most frequent values:
# 		1010:	12
# 		1030:	10
# 		990:	10
# 		950:	8
# 		1050:	8
#  11. SAT_AVG_ALL
# 	<class 'int'>
# 	Nulls: True
# 	Min: 781
# 	Max: 1517
# 	Sum: 490268
# 	Mean: 1047.5811965811965
# 	Median: 1030.0
# 	Standard Deviation: 125.28794113337482
# 	Unique values: 275
# 	5 most frequent values:
# 		1010:	12
# 		1030:	10
# 		990:	10
# 		950:	8
# 		1050:	8
#  12. RET_FT4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 451.5856000000001
# 	Mean: 0.7001327131782947
# 	Median: 0.7131
# 	Standard Deviation: 0.1571772285603419
# 	Unique values: 559
# 	5 most frequent values:
# 		0.5:	15
# 		0.6667:	8
# 		1.0:	7
# 		0.8571:	4
# 		0.6:	4
#  13. RET_FTL4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 573.8842999999999
# 	Mean: 0.6412115083798882
# 	Median: 0.6345
# 	Standard Deviation: 0.1855282460130384
# 	Unique values: 707
# 	5 most frequent values:
# 		1.0:	42
# 		0.5:	14
# 		0.75:	10
# 		0.6667:	8
# 		0.875:	6
#  14. RET_PT4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 224.44159999999994
# 	Mean: 0.47957606837606825
# 	Median: 0.47675
# 	Standard Deviation: 0.27787385624205974
# 	Unique values: 241
# 	5 most frequent values:
# 		0.0:	47
# 		1.0:	46
# 		0.5:	31
# 		0.6667:	13
# 		0.3333:	12
#  15. RET_PTL4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 293.5661000000002
# 	Mean: 0.4773432520325206
# 	Median: 0.4182
# 	Standard Deviation: 0.22721045446252378
# 	Unique values: 469
# 	5 most frequent values:
# 		1.0:	35
# 		0.75:	14
# 		0.5:	9
# 		0.4:	8
# 		0.3333:	7
#  16. INC_PCT_LO
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1417
# 	5 most frequent values:
# 		PrivacySuppressed:	124
# 		0.9129194403:	38
# 		0.8587822014:	8
# 		0.6717775004:	6
# 		0.75:	5
# 	Max length: 17
#  17. INC_PCT_M1
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1248
# 	5 most frequent values:
# 		PrivacySuppressed:	279
# 		0.07729928:	38
# 		0.106557377:	8
# 		0.139775361:	6
# 		0.1428571429:	6
# 	Max length: 17
#  18. INC_PCT_M2
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1142
# 	5 most frequent values:
# 		PrivacySuppressed:	446
# 		0.024824356:	8
# 		0.1153503298:	6
# 		0.2:	4
# 		0.1328426218:	4
# 	Max length: 17
#  19. INC_PCT_H1
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 922
# 	5 most frequent values:
# 		PrivacySuppressed:	687
# 		0.0547334641:	6
# 		0.0746582545:	4
# 		0.1474654378:	3
# 		0.0907722091:	3
# 	Max length: 17
#  20. INC_PCT_H2
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 914
# 	5 most frequent values:
# 		PrivacySuppressed:	701
# 		0.0183633446:	6
# 		0.037817994:	4
# 		0.1:	3
# 		0.05:	3
# 	Max length: 17
#  21. DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 582
# 	5 most frequent values:
# 		PrivacySuppressed:	313
# 		3500:	132
# 		6625:	108
# 		2625:	82
# 		7500:	39
# 	Max length: 17
#  22. GRAD_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 658
# 	5 most frequent values:
# 		PrivacySuppressed:	448
# 		17125:	101
# 		6625:	72
# 		3500:	34
# 		6125:	31
# 	Max length: 17
#  23. WDRAW_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 433
# 	5 most frequent values:
# 		PrivacySuppressed:	451
# 		3500:	183
# 		2625:	104
# 		3750:	69
# 		5500:	53
# 	Max length: 17
#  24. LO_INC_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 590
# 	5 most frequent values:
# 		PrivacySuppressed:	398
# 		3500:	105
# 		6625:	91
# 		2625:	63
# 		7500:	45
# 	Max length: 17
#  25. MD_INC_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 455
# 	5 most frequent values:
# 		PrivacySuppressed:	591
# 		6625:	101
# 		3500:	92
# 		2625:	72
# 		11000:	30
# 	Max length: 17
#  26. HI_INC_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 414
# 	5 most frequent values:
# 		PrivacySuppressed:	594
# 		2625:	121
# 		3500:	106
# 		6125:	49
# 		6625:	47
# 	Max length: 17
#  27. MN_EARN_WNE_P6
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 404
# 	5 most frequent values:
# 		PrivacySuppressed:	175
# 		27700:	43
# 		27400:	17
# 		29000:	15
# 		24200:	13
# 	Max length: 17
#  28. MN_EARN_WNE_P7
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  29. MN_EARN_WNE_P8
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 438
# 	5 most frequent values:
# 		PrivacySuppressed:	193
# 		29000:	43
# 		26900:	14
# 		33800:	12
# 		37400:	12
# 	Max length: 17
#  30. MN_EARN_WNE_P9
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  31. MN_EARN_WNE_P10
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 462
# 	5 most frequent values:
# 		PrivacySuppressed:	225
# 		31700:	44
# 		36500:	12
# 		36900:	11
# 		33300:	11
# 	Max length: 17
#  32. MD_EARN_WNE_P6
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 395
# 	5 most frequent values:
# 		PrivacySuppressed:	175
# 		24500:	41
# 		26900:	17
# 		28900:	14
# 		28600:	14
# 	Max length: 17
#  33. MD_EARN_WNE_P8
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 423
# 	5 most frequent values:
# 		PrivacySuppressed:	193
# 		26200:	43
# 		24700:	12
# 		25800:	12
# 		24300:	12
# 	Max length: 17
#  34. MD_EARN_WNE_P10
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 442
# 	5 most frequent values:
# 		PrivacySuppressed:	225
# 		28800:	44
# 		37100:	15
# 		33100:	14
# 		31800:	12
# 	Max length: 17
#
# Row count: 1698

# %%
# !csvcut -n FinalEducation.csv
# Out:
#   1: group
#   2: INSTNM
#   3: CITY
#   4: STABBR
#   5: ZIP
#   6: HIGHDEG
#   7: ICLEVEL
#   8: ADM_RATE
#   9: ADM_RATE_ALL
#  10: SAT_AVG
#  11: SAT_AVG_ALL
#  12: RET_FT4
#  13: RET_FTL4
#  14: RET_PT4
#  15: RET_PTL4
#  16: INC_PCT_LO
#  17: INC_PCT_M1
#  18: INC_PCT_M2
#  19: INC_PCT_H1
#  20: INC_PCT_H2
#  21: DEBT_MDN
#  22: GRAD_DEBT_MDN
#  23: WDRAW_DEBT_MDN
#  24: LO_INC_DEBT_MDN
#  25: MD_INC_DEBT_MDN
#  26: HI_INC_DEBT_MDN
#  27: MN_EARN_WNE_P6
#  28: MN_EARN_WNE_P7
#  29: MN_EARN_WNE_P8
#  30: MN_EARN_WNE_P9
#  31: MN_EARN_WNE_P10
#  32: MD_EARN_WNE_P6
#  33: MD_EARN_WNE_P8
#  34: MD_EARN_WNE_P10

# %%
# !csvcut -n Education.csv
# Out:
#   1: group
#   2: ﻿UNITID
#   3: OPEID
#   4: OPEID6
#   5: INSTNM
#   6: CITY
#   7: STABBR
#   8: ZIP
#   9: ACCREDAGENCY
#  10: INSTURL
#  11: NPCURL
#  12: SCH_DEG
#  13: HCM2
#  14: MAIN
#  15: NUMBRANCH
#  16: PREDDEG
#  17: HIGHDEG
#  18: CONTROL
#  19: ST_FIPS
#  20: REGION
#  21: LOCALE
#  22: LOCALE2
#  23: LATITUDE
#  24: LONGITUDE
#  25: CCBASIC
#  26: CCUGPROF
#  27: CCSIZSET
#  28: HBCU
#  29: PBI
#  30: ANNHI
#  31: TRIBAL
#  32: AANAPII
#  33: HSI
#  34: NANTI
#  35: MENONLY
#  36: WOMENONLY
#  37: RELAFFIL
#  38: ADM_RATE
#  39: ADM_RATE_ALL
#  40: SATVR25
#  41: SATVR75
#  42: SATMT25
#  43: SATMT75
#  44: SATWR25
#  45: SATWR75
#  46: SATVRMID
#  47: SATMTMID
#  48: SATWRMID
#  49: ACTCM25
#  50: ACTCM75
#  51: ACTEN25
#  52: ACTEN75
#  53: ACTMT25
#  54: ACTMT75
#  55: ACTWR25
#  56: ACTWR75
#  57: ACTCMMID
#  58: ACTENMID
#  59: ACTMTMID
#  60: ACTWRMID
#  61: SAT_AVG
#  62: SAT_AVG_ALL
#  63: PCIP01
#  64: PCIP03
#  65: PCIP04
#  66: PCIP05
#  67: PCIP09
#  68: PCIP10
#  69: PCIP11
#  70: PCIP12
#  71: PCIP13
#  72: PCIP14
#  73: PCIP15
#  74: PCIP16
#  75: PCIP19
#  76: PCIP22
#  77: PCIP23
#  78: PCIP24
#  79: PCIP25
#  80: PCIP26
#  81: PCIP27
#  82: PCIP29
#  83: PCIP30
#  84: PCIP31
#  85: PCIP38
#  86: PCIP39
#  87: PCIP40
#  88: PCIP41
#  89: PCIP42
#  90: PCIP43
#  91: PCIP44
#  92: PCIP45
#  93: PCIP46
#  94: PCIP47
#  95: PCIP48
#  96: PCIP49
#  97: PCIP50
#  98: PCIP51
#  99: PCIP52
# 100: PCIP54
# 101: CIP01CERT1
# 102: CIP01CERT2
# 103: CIP01ASSOC
# 104: CIP01CERT4
# 105: CIP01BACHL
# 106: CIP03CERT1
# 107: CIP03CERT2
# 108: CIP03ASSOC
# 109: CIP03CERT4
# 110: CIP03BACHL
# 111: CIP04CERT1
# 112: CIP04CERT2
# 113: CIP04ASSOC
# 114: CIP04CERT4
# 115: CIP04BACHL
# 116: CIP05CERT1
# 117: CIP05CERT2
# 118: CIP05ASSOC
# 119: CIP05CERT4
# 120: CIP05BACHL
# 121: CIP09CERT1
# 122: CIP09CERT2
# 123: CIP09ASSOC
# 124: CIP09CERT4
# 125: CIP09BACHL
# 126: CIP10CERT1
# 127: CIP10CERT2
# 128: CIP10ASSOC
# 129: CIP10CERT4
# 130: CIP10BACHL
# 131: CIP11CERT1
# 132: CIP11CERT2
# 133: CIP11ASSOC
# 134: CIP11CERT4
# 135: CIP11BACHL
# 136: CIP12CERT1
# 137: CIP12CERT2
# 138: CIP12ASSOC
# 139: CIP12CERT4
# 140: CIP12BACHL
# 141: CIP13CERT1
# 142: CIP13CERT2
# 143: CIP13ASSOC
# 144: CIP13CERT4
# 145: CIP13BACHL
# 146: CIP14CERT1
# 147: CIP14CERT2
# 148: CIP14ASSOC
# 149: CIP14CERT4
# 150: CIP14BACHL
# 151: CIP15CERT1
# 152: CIP15CERT2
# 153: CIP15ASSOC
# 154: CIP15CERT4
# 155: CIP15BACHL
# 156: CIP16CERT1
# 157: CIP16CERT2
# 158: CIP16ASSOC
# 159: CIP16CERT4
# 160: CIP16BACHL
# 161: CIP19CERT1
# 162: CIP19CERT2
# 163: CIP19ASSOC
# 164: CIP19CERT4
# 165: CIP19BACHL
# 166: CIP22CERT1
# 167: CIP22CERT2
# 168: CIP22ASSOC
# 169: CIP22CERT4
# 170: CIP22BACHL
# 171: CIP23CERT1
# 172: CIP23CERT2
# 173: CIP23ASSOC
# 174: CIP23CERT4
# 175: CIP23BACHL
# 176: CIP24CERT1
# 177: CIP24CERT2
# 178: CIP24ASSOC
# 179: CIP24CERT4
# 180: CIP24BACHL
# 181: CIP25CERT1
# 182: CIP25CERT2
# 183: CIP25ASSOC
# 184: CIP25CERT4
# 185: CIP25BACHL
# 186: CIP26CERT1
# 187: CIP26CERT2
# 188: CIP26ASSOC
# 189: CIP26CERT4
# 190: CIP26BACHL
# 191: CIP27CERT1
# 192: CIP27CERT2
# 193: CIP27ASSOC
# 194: CIP27CERT4
# 195: CIP27BACHL
# 196: CIP29CERT1
# 197: CIP29CERT2
# 198: CIP29ASSOC
# 199: CIP29CERT4
# 200: CIP29BACHL
# 201: CIP30CERT1
# 202: CIP30CERT2
# 203: CIP30ASSOC
# 204: CIP30CERT4
# 205: CIP30BACHL
# 206: CIP31CERT1
# 207: CIP31CERT2
# 208: CIP31ASSOC
# 209: CIP31CERT4
# 210: CIP31BACHL
# 211: CIP38CERT1
# 212: CIP38CERT2
# 213: CIP38ASSOC
# 214: CIP38CERT4
# 215: CIP38BACHL
# 216: CIP39CERT1
# 217: CIP39CERT2
# 218: CIP39ASSOC
# 219: CIP39CERT4
# 220: CIP39BACHL
# 221: CIP40CERT1
# 222: CIP40CERT2
# 223: CIP40ASSOC
# 224: CIP40CERT4
# 225: CIP40BACHL
# 226: CIP41CERT1
# 227: CIP41CERT2
# 228: CIP41ASSOC
# 229: CIP41CERT4
# 230: CIP41BACHL
# 231: CIP42CERT1
# 232: CIP42CERT2
# 233: CIP42ASSOC
# 234: CIP42CERT4
# 235: CIP42BACHL
# 236: CIP43CERT1
# 237: CIP43CERT2
# 238: CIP43ASSOC
# 239: CIP43CERT4
# 240: CIP43BACHL
# 241: CIP44CERT1
# 242: CIP44CERT2
# 243: CIP44ASSOC
# 244: CIP44CERT4
# 245: CIP44BACHL
# 246: CIP45CERT1
# 247: CIP45CERT2
# 248: CIP45ASSOC
# 249: CIP45CERT4
# 250: CIP45BACHL
# 251: CIP46CERT1
# 252: CIP46CERT2
# 253: CIP46ASSOC
# 254: CIP46CERT4
# 255: CIP46BACHL
# 256: CIP47CERT1
# 257: CIP47CERT2
# 258: CIP47ASSOC
# 259: CIP47CERT4
# 260: CIP47BACHL
# 261: CIP48CERT1
# 262: CIP48CERT2
# 263: CIP48ASSOC
# 264: CIP48CERT4
# 265: CIP48BACHL
# 266: CIP49CERT1
# 267: CIP49CERT2
# 268: CIP49ASSOC
# 269: CIP49CERT4
# 270: CIP49BACHL
# 271: CIP50CERT1
# 272: CIP50CERT2
# 273: CIP50ASSOC
# 274: CIP50CERT4
# 275: CIP50BACHL
# 276: CIP51CERT1
# 277: CIP51CERT2
# 278: CIP51ASSOC
# 279: CIP51CERT4
# 280: CIP51BACHL
# 281: CIP52CERT1
# 282: CIP52CERT2
# 283: CIP52ASSOC
# 284: CIP52CERT4
# 285: CIP52BACHL
# 286: CIP54CERT1
# 287: CIP54CERT2
# 288: CIP54ASSOC
# 289: CIP54CERT4
# 290: CIP54BACHL
# 291: DISTANCEONLY
# 292: UGDS
# 293: UG
# 294: UGDS_WHITE
# 295: UGDS_BLACK
# 296: UGDS_HISP
# 297: UGDS_ASIAN
# 298: UGDS_AIAN
# 299: UGDS_NHPI
# 300: UGDS_2MOR
# 301: UGDS_NRA
# 302: UGDS_UNKN
# 303: UGDS_WHITENH
# 304: UGDS_BLACKNH
# 305: UGDS_API
# 306: UGDS_AIANOLD
# 307: UGDS_HISPOLD
# 308: UG_NRA
# 309: UG_UNKN
# 310: UG_WHITENH
# 311: UG_BLACKNH
# 312: UG_API
# 313: UG_AIANOLD
# 314: UG_HISPOLD
# 315: PPTUG_EF
# 316: PPTUG_EF2
# 317: CURROPER
# 318: NPT4_PUB
# 319: NPT4_PRIV
# 320: NPT4_PROG
# 321: NPT4_OTHER
# 322: NPT41_PUB
# 323: NPT42_PUB
# 324: NPT43_PUB
# 325: NPT44_PUB
# 326: NPT45_PUB
# 327: NPT41_PRIV
# 328: NPT42_PRIV
# 329: NPT43_PRIV
# 330: NPT44_PRIV
# 331: NPT45_PRIV
# 332: NPT41_PROG
# 333: NPT42_PROG
# 334: NPT43_PROG
# 335: NPT44_PROG
# 336: NPT45_PROG
# 337: NPT41_OTHER
# 338: NPT42_OTHER
# 339: NPT43_OTHER
# 340: NPT44_OTHER
# 341: NPT45_OTHER
# 342: NPT4_048_PUB
# 343: NPT4_048_PRIV
# 344: NPT4_048_PROG
# 345: NPT4_048_OTHER
# 346: NPT4_3075_PUB
# 347: NPT4_3075_PRIV
# 348: NPT4_75UP_PUB
# 349: NPT4_75UP_PRIV
# 350: NPT4_3075_PROG
# 351: NPT4_3075_OTHER
# 352: NPT4_75UP_PROG
# 353: NPT4_75UP_OTHER
# 354: NUM4_PUB
# 355: NUM4_PRIV
# 356: NUM4_PROG
# 357: NUM4_OTHER
# 358: NUM41_PUB
# 359: NUM42_PUB
# 360: NUM43_PUB
# 361: NUM44_PUB
# 362: NUM45_PUB
# 363: NUM41_PRIV
# 364: NUM42_PRIV
# 365: NUM43_PRIV
# 366: NUM44_PRIV
# 367: NUM45_PRIV
# 368: NUM41_PROG
# 369: NUM42_PROG
# 370: NUM43_PROG
# 371: NUM44_PROG
# 372: NUM45_PROG
# 373: NUM41_OTHER
# 374: NUM42_OTHER
# 375: NUM43_OTHER
# 376: NUM44_OTHER
# 377: NUM45_OTHER
# 378: COSTT4_A
# 379: COSTT4_P
# 380: TUITIONFEE_IN
# 381: TUITIONFEE_OUT
# 382: TUITIONFEE_PROG
# 383: TUITFTE
# 384: INEXPFTE
# 385: AVGFACSAL
# 386: PFTFAC
# 387: PCTPELL
# 388: C150_4
# 389: C150_L4
# 390: C150_4_POOLED
# 391: C150_L4_POOLED
# 392: POOLYRS
# 393: PFTFTUG1_EF
# 394: D150_4
# 395: D150_L4
# 396: D150_4_POOLED
# 397: D150_L4_POOLED
# 398: C150_4_WHITE
# 399: C150_4_BLACK
# 400: C150_4_HISP
# 401: C150_4_ASIAN
# 402: C150_4_AIAN
# 403: C150_4_NHPI
# 404: C150_4_2MOR
# 405: C150_4_NRA
# 406: C150_4_UNKN
# 407: C150_4_WHITENH
# 408: C150_4_BLACKNH
# 409: C150_4_API
# 410: C150_4_AIANOLD
# 411: C150_4_HISPOLD
# 412: C150_L4_WHITE
# 413: C150_L4_BLACK
# 414: C150_L4_HISP
# 415: C150_L4_ASIAN
# 416: C150_L4_AIAN
# 417: C150_L4_NHPI
# 418: C150_L4_2MOR
# 419: C150_L4_NRA
# 420: C150_L4_UNKN
# 421: C150_L4_WHITENH
# 422: C150_L4_BLACKNH
# 423: C150_L4_API
# 424: C150_L4_AIANOLD
# 425: C150_L4_HISPOLD
# 426: C200_4
# 427: C200_L4
# 428: D200_4
# 429: D200_L4
# 430: RET_FT4
# 431: RET_FTL4
# 432: RET_PT4
# 433: RET_PTL4
# 434: C200_4_POOLED
# 435: C200_L4_POOLED
# 436: POOLYRS200
# 437: D200_4_POOLED
# 438: D200_L4_POOLED
# 439: PCTFLOAN
# 440: UG25ABV
# 441: CDR2
# 442: CDR3
# 443: DEATH_YR2_RT
# 444: COMP_ORIG_YR2_RT
# 445: COMP_4YR_TRANS_YR2_RT
# 446: COMP_2YR_TRANS_YR2_RT
# 447: WDRAW_ORIG_YR2_RT
# 448: WDRAW_4YR_TRANS_YR2_RT
# 449: WDRAW_2YR_TRANS_YR2_RT
# 450: ENRL_ORIG_YR2_RT
# 451: ENRL_4YR_TRANS_YR2_RT
# 452: ENRL_2YR_TRANS_YR2_RT
# 453: UNKN_ORIG_YR2_RT
# 454: UNKN_4YR_TRANS_YR2_RT
# 455: UNKN_2YR_TRANS_YR2_RT
# 456: LO_INC_DEATH_YR2_RT
# 457: LO_INC_COMP_ORIG_YR2_RT
# 458: LO_INC_COMP_4YR_TRANS_YR2_RT
# 459: LO_INC_COMP_2YR_TRANS_YR2_RT
# 460: LO_INC_WDRAW_ORIG_YR2_RT
# 461: LO_INC_WDRAW_4YR_TRANS_YR2_RT
# 462: LO_INC_WDRAW_2YR_TRANS_YR2_RT
# 463: LO_INC_ENRL_ORIG_YR2_RT
# 464: LO_INC_ENRL_4YR_TRANS_YR2_RT
# 465: LO_INC_ENRL_2YR_TRANS_YR2_RT
# 466: LO_INC_UNKN_ORIG_YR2_RT
# 467: LO_INC_UNKN_4YR_TRANS_YR2_RT
# 468: LO_INC_UNKN_2YR_TRANS_YR2_RT
# 469: MD_INC_DEATH_YR2_RT
# 470: MD_INC_COMP_ORIG_YR2_RT
# 471: MD_INC_COMP_4YR_TRANS_YR2_RT
# 472: MD_INC_COMP_2YR_TRANS_YR2_RT
# 473: MD_INC_WDRAW_ORIG_YR2_RT
# 474: MD_INC_WDRAW_4YR_TRANS_YR2_RT
# 475: MD_INC_WDRAW_2YR_TRANS_YR2_RT
# 476: MD_INC_ENRL_ORIG_YR2_RT
# 477: MD_INC_ENRL_4YR_TRANS_YR2_RT
# 478: MD_INC_ENRL_2YR_TRANS_YR2_RT
# 479: MD_INC_UNKN_ORIG_YR2_RT
# 480: MD_INC_UNKN_4YR_TRANS_YR2_RT
# 481: MD_INC_UNKN_2YR_TRANS_YR2_RT
# 482: HI_INC_DEATH_YR2_RT
# 483: HI_INC_COMP_ORIG_YR2_RT
# 484: HI_INC_COMP_4YR_TRANS_YR2_RT
# 485: HI_INC_COMP_2YR_TRANS_YR2_RT
# 486: HI_INC_WDRAW_ORIG_YR2_RT
# 487: HI_INC_WDRAW_4YR_TRANS_YR2_RT
# 488: HI_INC_WDRAW_2YR_TRANS_YR2_RT
# 489: HI_INC_ENRL_ORIG_YR2_RT
# 490: HI_INC_ENRL_4YR_TRANS_YR2_RT
# 491: HI_INC_ENRL_2YR_TRANS_YR2_RT
# 492: HI_INC_UNKN_ORIG_YR2_RT
# 493: HI_INC_UNKN_4YR_TRANS_YR2_RT
# 494: HI_INC_UNKN_2YR_TRANS_YR2_RT
# 495: DEP_DEATH_YR2_RT
# 496: DEP_COMP_ORIG_YR2_RT
# 497: DEP_COMP_4YR_TRANS_YR2_RT
# 498: DEP_COMP_2YR_TRANS_YR2_RT
# 499: DEP_WDRAW_ORIG_YR2_RT
# 500: DEP_WDRAW_4YR_TRANS_YR2_RT
# 501: DEP_WDRAW_2YR_TRANS_YR2_RT
# 502: DEP_ENRL_ORIG_YR2_RT
# 503: DEP_ENRL_4YR_TRANS_YR2_RT
# 504: DEP_ENRL_2YR_TRANS_YR2_RT
# 505: DEP_UNKN_ORIG_YR2_RT
# 506: DEP_UNKN_4YR_TRANS_YR2_RT
# 507: DEP_UNKN_2YR_TRANS_YR2_RT
# 508: IND_DEATH_YR2_RT
# 509: IND_COMP_ORIG_YR2_RT
# 510: IND_COMP_4YR_TRANS_YR2_RT
# 511: IND_COMP_2YR_TRANS_YR2_RT
# 512: IND_WDRAW_ORIG_YR2_RT
# 513: IND_WDRAW_4YR_TRANS_YR2_RT
# 514: IND_WDRAW_2YR_TRANS_YR2_RT
# 515: IND_ENRL_ORIG_YR2_RT
# 516: IND_ENRL_4YR_TRANS_YR2_RT
# 517: IND_ENRL_2YR_TRANS_YR2_RT
# 518: IND_UNKN_ORIG_YR2_RT
# 519: IND_UNKN_4YR_TRANS_YR2_RT
# 520: IND_UNKN_2YR_TRANS_YR2_RT
# 521: FEMALE_DEATH_YR2_RT
# 522: FEMALE_COMP_ORIG_YR2_RT
# 523: FEMALE_COMP_4YR_TRANS_YR2_RT
# 524: FEMALE_COMP_2YR_TRANS_YR2_RT
# 525: FEMALE_WDRAW_ORIG_YR2_RT
# 526: FEMALE_WDRAW_4YR_TRANS_YR2_RT
# 527: FEMALE_WDRAW_2YR_TRANS_YR2_RT
# 528: FEMALE_ENRL_ORIG_YR2_RT
# 529: FEMALE_ENRL_4YR_TRANS_YR2_RT
# 530: FEMALE_ENRL_2YR_TRANS_YR2_RT
# 531: FEMALE_UNKN_ORIG_YR2_RT
# 532: FEMALE_UNKN_4YR_TRANS_YR2_RT
# 533: FEMALE_UNKN_2YR_TRANS_YR2_RT
# 534: MALE_DEATH_YR2_RT
# 535: MALE_COMP_ORIG_YR2_RT
# 536: MALE_COMP_4YR_TRANS_YR2_RT
# 537: MALE_COMP_2YR_TRANS_YR2_RT
# 538: MALE_WDRAW_ORIG_YR2_RT
# 539: MALE_WDRAW_4YR_TRANS_YR2_RT
# 540: MALE_WDRAW_2YR_TRANS_YR2_RT
# 541: MALE_ENRL_ORIG_YR2_RT
# 542: MALE_ENRL_4YR_TRANS_YR2_RT
# 543: MALE_ENRL_2YR_TRANS_YR2_RT
# 544: MALE_UNKN_ORIG_YR2_RT
# 545: MALE_UNKN_4YR_TRANS_YR2_RT
# 546: MALE_UNKN_2YR_TRANS_YR2_RT
# 547: PELL_DEATH_YR2_RT
# 548: PELL_COMP_ORIG_YR2_RT
# 549: PELL_COMP_4YR_TRANS_YR2_RT
# 550: PELL_COMP_2YR_TRANS_YR2_RT
# 551: PELL_WDRAW_ORIG_YR2_RT
# 552: PELL_WDRAW_4YR_TRANS_YR2_RT
# 553: PELL_WDRAW_2YR_TRANS_YR2_RT
# 554: PELL_ENRL_ORIG_YR2_RT
# 555: PELL_ENRL_4YR_TRANS_YR2_RT
# 556: PELL_ENRL_2YR_TRANS_YR2_RT
# 557: PELL_UNKN_ORIG_YR2_RT
# 558: PELL_UNKN_4YR_TRANS_YR2_RT
# 559: PELL_UNKN_2YR_TRANS_YR2_RT
# 560: NOPELL_DEATH_YR2_RT
# 561: NOPELL_COMP_ORIG_YR2_RT
# 562: NOPELL_COMP_4YR_TRANS_YR2_RT
# 563: NOPELL_COMP_2YR_TRANS_YR2_RT
# 564: NOPELL_WDRAW_ORIG_YR2_RT
# 565: NOPELL_WDRAW_4YR_TRANS_YR2_RT
# 566: NOPELL_WDRAW_2YR_TRANS_YR2_RT
# 567: NOPELL_ENRL_ORIG_YR2_RT
# 568: NOPELL_ENRL_4YR_TRANS_YR2_RT
# 569: NOPELL_ENRL_2YR_TRANS_YR2_RT
# 570: NOPELL_UNKN_ORIG_YR2_RT
# 571: NOPELL_UNKN_4YR_TRANS_YR2_RT
# 572: NOPELL_UNKN_2YR_TRANS_YR2_RT
# 573: LOAN_DEATH_YR2_RT
# 574: LOAN_COMP_ORIG_YR2_RT
# 575: LOAN_COMP_4YR_TRANS_YR2_RT
# 576: LOAN_COMP_2YR_TRANS_YR2_RT
# 577: LOAN_WDRAW_ORIG_YR2_RT
# 578: LOAN_WDRAW_4YR_TRANS_YR2_RT
# 579: LOAN_WDRAW_2YR_TRANS_YR2_RT
# 580: LOAN_ENRL_ORIG_YR2_RT
# 581: LOAN_ENRL_4YR_TRANS_YR2_RT
# 582: LOAN_ENRL_2YR_TRANS_YR2_RT
# 583: LOAN_UNKN_ORIG_YR2_RT
# 584: LOAN_UNKN_4YR_TRANS_YR2_RT
# 585: LOAN_UNKN_2YR_TRANS_YR2_RT
# 586: NOLOAN_DEATH_YR2_RT
# 587: NOLOAN_COMP_ORIG_YR2_RT
# 588: NOLOAN_COMP_4YR_TRANS_YR2_RT
# 589: NOLOAN_COMP_2YR_TRANS_YR2_RT
# 590: NOLOAN_WDRAW_ORIG_YR2_RT
# 591: NOLOAN_WDRAW_4YR_TRANS_YR2_RT
# 592: NOLOAN_WDRAW_2YR_TRANS_YR2_RT
# 593: NOLOAN_ENRL_ORIG_YR2_RT
# 594: NOLOAN_ENRL_4YR_TRANS_YR2_RT
# 595: NOLOAN_ENRL_2YR_TRANS_YR2_RT
# 596: NOLOAN_UNKN_ORIG_YR2_RT
# 597: NOLOAN_UNKN_4YR_TRANS_YR2_RT
# 598: NOLOAN_UNKN_2YR_TRANS_YR2_RT
# 599: FIRSTGEN_DEATH_YR2_RT
# 600: FIRSTGEN_COMP_ORIG_YR2_RT
# 601: FIRSTGEN_COMP_4YR_TRANS_YR2_RT
# 602: FIRSTGEN_COMP_2YR_TRANS_YR2_RT
# 603: FIRSTGEN_WDRAW_ORIG_YR2_RT
# 604: FIRSTGEN_WDRAW_4YR_TRANS_YR2_RT
# 605: FIRSTGEN_WDRAW_2YR_TRANS_YR2_RT
# 606: FIRSTGEN_ENRL_ORIG_YR2_RT
# 607: FIRSTGEN_ENRL_4YR_TRANS_YR2_RT
# 608: FIRSTGEN_ENRL_2YR_TRANS_YR2_RT
# 609: FIRSTGEN_UNKN_ORIG_YR2_RT
# 610: FIRSTGEN_UNKN_4YR_TRANS_YR2_RT
# 611: FIRSTGEN_UNKN_2YR_TRANS_YR2_RT
# 612: NOT1STGEN_DEATH_YR2_RT
# 613: NOT1STGEN_COMP_ORIG_YR2_RT
# 614: NOT1STGEN_COMP_4YR_TRANS_YR2_RT
# 615: NOT1STGEN_COMP_2YR_TRANS_YR2_RT
# 616: NOT1STGEN_WDRAW_ORIG_YR2_RT
# 617: NOT1STGEN_WDRAW_4YR_TRANS_YR2_RT
# 618: NOT1STGEN_WDRAW_2YR_TRANS_YR2_RT
# 619: NOT1STGEN_ENRL_ORIG_YR2_RT
# 620: NOT1STGEN_ENRL_4YR_TRANS_YR2_RT
# 621: NOT1STGEN_ENRL_2YR_TRANS_YR2_RT
# 622: NOT1STGEN_UNKN_ORIG_YR2_RT
# 623: NOT1STGEN_UNKN_4YR_TRANS_YR2_RT
# 624: NOT1STGEN_UNKN_2YR_TRANS_YR2_RT
# 625: DEATH_YR3_RT
# 626: COMP_ORIG_YR3_RT
# 627: COMP_4YR_TRANS_YR3_RT
# 628: COMP_2YR_TRANS_YR3_RT
# 629: WDRAW_ORIG_YR3_RT
# 630: WDRAW_4YR_TRANS_YR3_RT
# 631: WDRAW_2YR_TRANS_YR3_RT
# 632: ENRL_ORIG_YR3_RT
# 633: ENRL_4YR_TRANS_YR3_RT
# 634: ENRL_2YR_TRANS_YR3_RT
# 635: UNKN_ORIG_YR3_RT
# 636: UNKN_4YR_TRANS_YR3_RT
# 637: UNKN_2YR_TRANS_YR3_RT
# 638: LO_INC_DEATH_YR3_RT
# 639: LO_INC_COMP_ORIG_YR3_RT
# 640: LO_INC_COMP_4YR_TRANS_YR3_RT
# 641: LO_INC_COMP_2YR_TRANS_YR3_RT
# 642: LO_INC_WDRAW_ORIG_YR3_RT
# 643: LO_INC_WDRAW_4YR_TRANS_YR3_RT
# 644: LO_INC_WDRAW_2YR_TRANS_YR3_RT
# 645: LO_INC_ENRL_ORIG_YR3_RT
# 646: LO_INC_ENRL_4YR_TRANS_YR3_RT
# 647: LO_INC_ENRL_2YR_TRANS_YR3_RT
# 648: LO_INC_UNKN_ORIG_YR3_RT
# 649: LO_INC_UNKN_4YR_TRANS_YR3_RT
# 650: LO_INC_UNKN_2YR_TRANS_YR3_RT
# 651: MD_INC_DEATH_YR3_RT
# 652: MD_INC_COMP_ORIG_YR3_RT
# 653: MD_INC_COMP_4YR_TRANS_YR3_RT
# 654: MD_INC_COMP_2YR_TRANS_YR3_RT
# 655: MD_INC_WDRAW_ORIG_YR3_RT
# 656: MD_INC_WDRAW_4YR_TRANS_YR3_RT
# 657: MD_INC_WDRAW_2YR_TRANS_YR3_RT
# 658: MD_INC_ENRL_ORIG_YR3_RT
# 659: MD_INC_ENRL_4YR_TRANS_YR3_RT
# 660: MD_INC_ENRL_2YR_TRANS_YR3_RT
# 661: MD_INC_UNKN_ORIG_YR3_RT
# 662: MD_INC_UNKN_4YR_TRANS_YR3_RT
# 663: MD_INC_UNKN_2YR_TRANS_YR3_RT
# 664: HI_INC_DEATH_YR3_RT
# 665: HI_INC_COMP_ORIG_YR3_RT
# 666: HI_INC_COMP_4YR_TRANS_YR3_RT
# 667: HI_INC_COMP_2YR_TRANS_YR3_RT
# 668: HI_INC_WDRAW_ORIG_YR3_RT
# 669: HI_INC_WDRAW_4YR_TRANS_YR3_RT
# 670: HI_INC_WDRAW_2YR_TRANS_YR3_RT
# 671: HI_INC_ENRL_ORIG_YR3_RT
# 672: HI_INC_ENRL_4YR_TRANS_YR3_RT
# 673: HI_INC_ENRL_2YR_TRANS_YR3_RT
# 674: HI_INC_UNKN_ORIG_YR3_RT
# 675: HI_INC_UNKN_4YR_TRANS_YR3_RT
# 676: HI_INC_UNKN_2YR_TRANS_YR3_RT
# 677: DEP_DEATH_YR3_RT
# 678: DEP_COMP_ORIG_YR3_RT
# 679: DEP_COMP_4YR_TRANS_YR3_RT
# 680: DEP_COMP_2YR_TRANS_YR3_RT
# 681: DEP_WDRAW_ORIG_YR3_RT
# 682: DEP_WDRAW_4YR_TRANS_YR3_RT
# 683: DEP_WDRAW_2YR_TRANS_YR3_RT
# 684: DEP_ENRL_ORIG_YR3_RT
# 685: DEP_ENRL_4YR_TRANS_YR3_RT
# 686: DEP_ENRL_2YR_TRANS_YR3_RT
# 687: DEP_UNKN_ORIG_YR3_RT
# 688: DEP_UNKN_4YR_TRANS_YR3_RT
# 689: DEP_UNKN_2YR_TRANS_YR3_RT
# 690: IND_DEATH_YR3_RT
# 691: IND_COMP_ORIG_YR3_RT
# 692: IND_COMP_4YR_TRANS_YR3_RT
# 693: IND_COMP_2YR_TRANS_YR3_RT
# 694: IND_WDRAW_ORIG_YR3_RT
# 695: IND_WDRAW_4YR_TRANS_YR3_RT
# 696: IND_WDRAW_2YR_TRANS_YR3_RT
# 697: IND_ENRL_ORIG_YR3_RT
# 698: IND_ENRL_4YR_TRANS_YR3_RT
# 699: IND_ENRL_2YR_TRANS_YR3_RT
# 700: IND_UNKN_ORIG_YR3_RT
# 701: IND_UNKN_4YR_TRANS_YR3_RT
# 702: IND_UNKN_2YR_TRANS_YR3_RT
# 703: FEMALE_DEATH_YR3_RT
# 704: FEMALE_COMP_ORIG_YR3_RT
# 705: FEMALE_COMP_4YR_TRANS_YR3_RT
# 706: FEMALE_COMP_2YR_TRANS_YR3_RT
# 707: FEMALE_WDRAW_ORIG_YR3_RT
# 708: FEMALE_WDRAW_4YR_TRANS_YR3_RT
# 709: FEMALE_WDRAW_2YR_TRANS_YR3_RT
# 710: FEMALE_ENRL_ORIG_YR3_RT
# 711: FEMALE_ENRL_4YR_TRANS_YR3_RT
# 712: FEMALE_ENRL_2YR_TRANS_YR3_RT
# 713: FEMALE_UNKN_ORIG_YR3_RT
# 714: FEMALE_UNKN_4YR_TRANS_YR3_RT
# 715: FEMALE_UNKN_2YR_TRANS_YR3_RT
# 716: MALE_DEATH_YR3_RT
# 717: MALE_COMP_ORIG_YR3_RT
# 718: MALE_COMP_4YR_TRANS_YR3_RT
# 719: MALE_COMP_2YR_TRANS_YR3_RT
# 720: MALE_WDRAW_ORIG_YR3_RT
# 721: MALE_WDRAW_4YR_TRANS_YR3_RT
# 722: MALE_WDRAW_2YR_TRANS_YR3_RT
# 723: MALE_ENRL_ORIG_YR3_RT
# 724: MALE_ENRL_4YR_TRANS_YR3_RT
# 725: MALE_ENRL_2YR_TRANS_YR3_RT
# 726: MALE_UNKN_ORIG_YR3_RT
# 727: MALE_UNKN_4YR_TRANS_YR3_RT
# 728: MALE_UNKN_2YR_TRANS_YR3_RT
# 729: PELL_DEATH_YR3_RT
# 730: PELL_COMP_ORIG_YR3_RT
# 731: PELL_COMP_4YR_TRANS_YR3_RT
# 732: PELL_COMP_2YR_TRANS_YR3_RT
# 733: PELL_WDRAW_ORIG_YR3_RT
# 734: PELL_WDRAW_4YR_TRANS_YR3_RT
# 735: PELL_WDRAW_2YR_TRANS_YR3_RT
# 736: PELL_ENRL_ORIG_YR3_RT
# 737: PELL_ENRL_4YR_TRANS_YR3_RT
# 738: PELL_ENRL_2YR_TRANS_YR3_RT
# 739: PELL_UNKN_ORIG_YR3_RT
# 740: PELL_UNKN_4YR_TRANS_YR3_RT
# 741: PELL_UNKN_2YR_TRANS_YR3_RT
# 742: NOPELL_DEATH_YR3_RT
# 743: NOPELL_COMP_ORIG_YR3_RT
# 744: NOPELL_COMP_4YR_TRANS_YR3_RT
# 745: NOPELL_COMP_2YR_TRANS_YR3_RT
# 746: NOPELL_WDRAW_ORIG_YR3_RT
# 747: NOPELL_WDRAW_4YR_TRANS_YR3_RT
# 748: NOPELL_WDRAW_2YR_TRANS_YR3_RT
# 749: NOPELL_ENRL_ORIG_YR3_RT
# 750: NOPELL_ENRL_4YR_TRANS_YR3_RT
# 751: NOPELL_ENRL_2YR_TRANS_YR3_RT
# 752: NOPELL_UNKN_ORIG_YR3_RT
# 753: NOPELL_UNKN_4YR_TRANS_YR3_RT
# 754: NOPELL_UNKN_2YR_TRANS_YR3_RT
# 755: LOAN_DEATH_YR3_RT
# 756: LOAN_COMP_ORIG_YR3_RT
# 757: LOAN_COMP_4YR_TRANS_YR3_RT
# 758: LOAN_COMP_2YR_TRANS_YR3_RT
# 759: LOAN_WDRAW_ORIG_YR3_RT
# 760: LOAN_WDRAW_4YR_TRANS_YR3_RT
# 761: LOAN_WDRAW_2YR_TRANS_YR3_RT
# 762: LOAN_ENRL_ORIG_YR3_RT
# 763: LOAN_ENRL_4YR_TRANS_YR3_RT
# 764: LOAN_ENRL_2YR_TRANS_YR3_RT
# 765: LOAN_UNKN_ORIG_YR3_RT
# 766: LOAN_UNKN_4YR_TRANS_YR3_RT
# 767: LOAN_UNKN_2YR_TRANS_YR3_RT
# 768: NOLOAN_DEATH_YR3_RT
# 769: NOLOAN_COMP_ORIG_YR3_RT
# 770: NOLOAN_COMP_4YR_TRANS_YR3_RT
# 771: NOLOAN_COMP_2YR_TRANS_YR3_RT
# 772: NOLOAN_WDRAW_ORIG_YR3_RT
# 773: NOLOAN_WDRAW_4YR_TRANS_YR3_RT
# 774: NOLOAN_WDRAW_2YR_TRANS_YR3_RT
# 775: NOLOAN_ENRL_ORIG_YR3_RT
# 776: NOLOAN_ENRL_4YR_TRANS_YR3_RT
# 777: NOLOAN_ENRL_2YR_TRANS_YR3_RT
# 778: NOLOAN_UNKN_ORIG_YR3_RT
# 779: NOLOAN_UNKN_4YR_TRANS_YR3_RT
# 780: NOLOAN_UNKN_2YR_TRANS_YR3_RT
# 781: FIRSTGEN_DEATH_YR3_RT
# 782: FIRSTGEN_COMP_ORIG_YR3_RT
# 783: FIRSTGEN_COMP_4YR_TRANS_YR3_RT
# 784: FIRSTGEN_COMP_2YR_TRANS_YR3_RT
# 785: FIRSTGEN_WDRAW_ORIG_YR3_RT
# 786: FIRSTGEN_WDRAW_4YR_TRANS_YR3_RT
# 787: FIRSTGEN_WDRAW_2YR_TRANS_YR3_RT
# 788: FIRSTGEN_ENRL_ORIG_YR3_RT
# 789: FIRSTGEN_ENRL_4YR_TRANS_YR3_RT
# 790: FIRSTGEN_ENRL_2YR_TRANS_YR3_RT
# 791: FIRSTGEN_UNKN_ORIG_YR3_RT
# 792: FIRSTGEN_UNKN_4YR_TRANS_YR3_RT
# 793: FIRSTGEN_UNKN_2YR_TRANS_YR3_RT
# 794: NOT1STGEN_DEATH_YR3_RT
# 795: NOT1STGEN_COMP_ORIG_YR3_RT
# 796: NOT1STGEN_COMP_4YR_TRANS_YR3_RT
# 797: NOT1STGEN_COMP_2YR_TRANS_YR3_RT
# 798: NOT1STGEN_WDRAW_ORIG_YR3_RT
# 799: NOT1STGEN_WDRAW_4YR_TRANS_YR3_RT
# 800: NOT1STGEN_WDRAW_2YR_TRANS_YR3_RT
# 801: NOT1STGEN_ENRL_ORIG_YR3_RT
# 802: NOT1STGEN_ENRL_4YR_TRANS_YR3_RT
# 803: NOT1STGEN_ENRL_2YR_TRANS_YR3_RT
# 804: NOT1STGEN_UNKN_ORIG_YR3_RT
# 805: NOT1STGEN_UNKN_4YR_TRANS_YR3_RT
# 806: NOT1STGEN_UNKN_2YR_TRANS_YR3_RT
# 807: DEATH_YR4_RT
# 808: COMP_ORIG_YR4_RT
# 809: COMP_4YR_TRANS_YR4_RT
# 810: COMP_2YR_TRANS_YR4_RT
# 811: WDRAW_ORIG_YR4_RT
# 812: WDRAW_4YR_TRANS_YR4_RT
# 813: WDRAW_2YR_TRANS_YR4_RT
# 814: ENRL_ORIG_YR4_RT
# 815: ENRL_4YR_TRANS_YR4_RT
# 816: ENRL_2YR_TRANS_YR4_RT
# 817: UNKN_ORIG_YR4_RT
# 818: UNKN_4YR_TRANS_YR4_RT
# 819: UNKN_2YR_TRANS_YR4_RT
# 820: LO_INC_DEATH_YR4_RT
# 821: LO_INC_COMP_ORIG_YR4_RT
# 822: LO_INC_COMP_4YR_TRANS_YR4_RT
# 823: LO_INC_COMP_2YR_TRANS_YR4_RT
# 824: LO_INC_WDRAW_ORIG_YR4_RT
# 825: LO_INC_WDRAW_4YR_TRANS_YR4_RT
# 826: LO_INC_WDRAW_2YR_TRANS_YR4_RT
# 827: LO_INC_ENRL_ORIG_YR4_RT
# 828: LO_INC_ENRL_4YR_TRANS_YR4_RT
# 829: LO_INC_ENRL_2YR_TRANS_YR4_RT
# 830: LO_INC_UNKN_ORIG_YR4_RT
# 831: LO_INC_UNKN_4YR_TRANS_YR4_RT
# 832: LO_INC_UNKN_2YR_TRANS_YR4_RT
# 833: MD_INC_DEATH_YR4_RT
# 834: MD_INC_COMP_ORIG_YR4_RT
# 835: MD_INC_COMP_4YR_TRANS_YR4_RT
# 836: MD_INC_COMP_2YR_TRANS_YR4_RT
# 837: MD_INC_WDRAW_ORIG_YR4_RT
# 838: MD_INC_WDRAW_4YR_TRANS_YR4_RT
# 839: MD_INC_WDRAW_2YR_TRANS_YR4_RT
# 840: MD_INC_ENRL_ORIG_YR4_RT
# 841: MD_INC_ENRL_4YR_TRANS_YR4_RT
# 842: MD_INC_ENRL_2YR_TRANS_YR4_RT
# 843: MD_INC_UNKN_ORIG_YR4_RT
# 844: MD_INC_UNKN_4YR_TRANS_YR4_RT
# 845: MD_INC_UNKN_2YR_TRANS_YR4_RT
# 846: HI_INC_DEATH_YR4_RT
# 847: HI_INC_COMP_ORIG_YR4_RT
# 848: HI_INC_COMP_4YR_TRANS_YR4_RT
# 849: HI_INC_COMP_2YR_TRANS_YR4_RT
# 850: HI_INC_WDRAW_ORIG_YR4_RT
# 851: HI_INC_WDRAW_4YR_TRANS_YR4_RT
# 852: HI_INC_WDRAW_2YR_TRANS_YR4_RT
# 853: HI_INC_ENRL_ORIG_YR4_RT
# 854: HI_INC_ENRL_4YR_TRANS_YR4_RT
# 855: HI_INC_ENRL_2YR_TRANS_YR4_RT
# 856: HI_INC_UNKN_ORIG_YR4_RT
# 857: HI_INC_UNKN_4YR_TRANS_YR4_RT
# 858: HI_INC_UNKN_2YR_TRANS_YR4_RT
# 859: DEP_DEATH_YR4_RT
# 860: DEP_COMP_ORIG_YR4_RT
# 861: DEP_COMP_4YR_TRANS_YR4_RT
# 862: DEP_COMP_2YR_TRANS_YR4_RT
# 863: DEP_WDRAW_ORIG_YR4_RT
# 864: DEP_WDRAW_4YR_TRANS_YR4_RT
# 865: DEP_WDRAW_2YR_TRANS_YR4_RT
# 866: DEP_ENRL_ORIG_YR4_RT
# 867: DEP_ENRL_4YR_TRANS_YR4_RT
# 868: DEP_ENRL_2YR_TRANS_YR4_RT
# 869: DEP_UNKN_ORIG_YR4_RT
# 870: DEP_UNKN_4YR_TRANS_YR4_RT
# 871: DEP_UNKN_2YR_TRANS_YR4_RT
# 872: IND_DEATH_YR4_RT
# 873: IND_COMP_ORIG_YR4_RT
# 874: IND_COMP_4YR_TRANS_YR4_RT
# 875: IND_COMP_2YR_TRANS_YR4_RT
# 876: IND_WDRAW_ORIG_YR4_RT
# 877: IND_WDRAW_4YR_TRANS_YR4_RT
# 878: IND_WDRAW_2YR_TRANS_YR4_RT
# 879: IND_ENRL_ORIG_YR4_RT
# 880: IND_ENRL_4YR_TRANS_YR4_RT
# 881: IND_ENRL_2YR_TRANS_YR4_RT
# 882: IND_UNKN_ORIG_YR4_RT
# 883: IND_UNKN_4YR_TRANS_YR4_RT
# 884: IND_UNKN_2YR_TRANS_YR4_RT
# 885: FEMALE_DEATH_YR4_RT
# 886: FEMALE_COMP_ORIG_YR4_RT
# 887: FEMALE_COMP_4YR_TRANS_YR4_RT
# 888: FEMALE_COMP_2YR_TRANS_YR4_RT
# 889: FEMALE_WDRAW_ORIG_YR4_RT
# 890: FEMALE_WDRAW_4YR_TRANS_YR4_RT
# 891: FEMALE_WDRAW_2YR_TRANS_YR4_RT
# 892: FEMALE_ENRL_ORIG_YR4_RT
# 893: FEMALE_ENRL_4YR_TRANS_YR4_RT
# 894: FEMALE_ENRL_2YR_TRANS_YR4_RT
# 895: FEMALE_UNKN_ORIG_YR4_RT
# 896: FEMALE_UNKN_4YR_TRANS_YR4_RT
# 897: FEMALE_UNKN_2YR_TRANS_YR4_RT
# 898: MALE_DEATH_YR4_RT
# 899: MALE_COMP_ORIG_YR4_RT
# 900: MALE_COMP_4YR_TRANS_YR4_RT
# 901: MALE_COMP_2YR_TRANS_YR4_RT
# 902: MALE_WDRAW_ORIG_YR4_RT
# 903: MALE_WDRAW_4YR_TRANS_YR4_RT
# 904: MALE_WDRAW_2YR_TRANS_YR4_RT
# 905: MALE_ENRL_ORIG_YR4_RT
# 906: MALE_ENRL_4YR_TRANS_YR4_RT
# 907: MALE_ENRL_2YR_TRANS_YR4_RT
# 908: MALE_UNKN_ORIG_YR4_RT
# 909: MALE_UNKN_4YR_TRANS_YR4_RT
# 910: MALE_UNKN_2YR_TRANS_YR4_RT
# 911: PELL_DEATH_YR4_RT
# 912: PELL_COMP_ORIG_YR4_RT
# 913: PELL_COMP_4YR_TRANS_YR4_RT
# 914: PELL_COMP_2YR_TRANS_YR4_RT
# 915: PELL_WDRAW_ORIG_YR4_RT
# 916: PELL_WDRAW_4YR_TRANS_YR4_RT
# 917: PELL_WDRAW_2YR_TRANS_YR4_RT
# 918: PELL_ENRL_ORIG_YR4_RT
# 919: PELL_ENRL_4YR_TRANS_YR4_RT
# 920: PELL_ENRL_2YR_TRANS_YR4_RT
# 921: PELL_UNKN_ORIG_YR4_RT
# 922: PELL_UNKN_4YR_TRANS_YR4_RT
# 923: PELL_UNKN_2YR_TRANS_YR4_RT
# 924: NOPELL_DEATH_YR4_RT
# 925: NOPELL_COMP_ORIG_YR4_RT
# 926: NOPELL_COMP_4YR_TRANS_YR4_RT
# 927: NOPELL_COMP_2YR_TRANS_YR4_RT
# 928: NOPELL_WDRAW_ORIG_YR4_RT
# 929: NOPELL_WDRAW_4YR_TRANS_YR4_RT
# 930: NOPELL_WDRAW_2YR_TRANS_YR4_RT
# 931: NOPELL_ENRL_ORIG_YR4_RT
# 932: NOPELL_ENRL_4YR_TRANS_YR4_RT
# 933: NOPELL_ENRL_2YR_TRANS_YR4_RT
# 934: NOPELL_UNKN_ORIG_YR4_RT
# 935: NOPELL_UNKN_4YR_TRANS_YR4_RT
# 936: NOPELL_UNKN_2YR_TRANS_YR4_RT
# 937: LOAN_DEATH_YR4_RT
# 938: LOAN_COMP_ORIG_YR4_RT
# 939: LOAN_COMP_4YR_TRANS_YR4_RT
# 940: LOAN_COMP_2YR_TRANS_YR4_RT
# 941: LOAN_WDRAW_ORIG_YR4_RT
# 942: LOAN_WDRAW_4YR_TRANS_YR4_RT
# 943: LOAN_WDRAW_2YR_TRANS_YR4_RT
# 944: LOAN_ENRL_ORIG_YR4_RT
# 945: LOAN_ENRL_4YR_TRANS_YR4_RT
# 946: LOAN_ENRL_2YR_TRANS_YR4_RT
# 947: LOAN_UNKN_ORIG_YR4_RT
# 948: LOAN_UNKN_4YR_TRANS_YR4_RT
# 949: LOAN_UNKN_2YR_TRANS_YR4_RT
# 950: NOLOAN_DEATH_YR4_RT
# 951: NOLOAN_COMP_ORIG_YR4_RT
# 952: NOLOAN_COMP_4YR_TRANS_YR4_RT
# 953: NOLOAN_COMP_2YR_TRANS_YR4_RT
# 954: NOLOAN_WDRAW_ORIG_YR4_RT
# 955: NOLOAN_WDRAW_4YR_TRANS_YR4_RT
# 956: NOLOAN_WDRAW_2YR_TRANS_YR4_RT
# 957: NOLOAN_ENRL_ORIG_YR4_RT
# 958: NOLOAN_ENRL_4YR_TRANS_YR4_RT
# 959: NOLOAN_ENRL_2YR_TRANS_YR4_RT
# 960: NOLOAN_UNKN_ORIG_YR4_RT
# 961: NOLOAN_UNKN_4YR_TRANS_YR4_RT
# 962: NOLOAN_UNKN_2YR_TRANS_YR4_RT
# 963: FIRSTGEN_DEATH_YR4_RT
# 964: FIRSTGEN_COMP_ORIG_YR4_RT
# 965: FIRSTGEN_COMP_4YR_TRANS_YR4_RT
# 966: FIRSTGEN_COMP_2YR_TRANS_YR4_RT
# 967: FIRSTGEN_WDRAW_ORIG_YR4_RT
# 968: FIRSTGEN_WDRAW_4YR_TRANS_YR4_RT
# 969: FIRSTGEN_WDRAW_2YR_TRANS_YR4_RT
# 970: FIRSTGEN_ENRL_ORIG_YR4_RT
# 971: FIRSTGEN_ENRL_4YR_TRANS_YR4_RT
# 972: FIRSTGEN_ENRL_2YR_TRANS_YR4_RT
# 973: FIRSTGEN_UNKN_ORIG_YR4_RT
# 974: FIRSTGEN_UNKN_4YR_TRANS_YR4_RT
# 975: FIRSTGEN_UNKN_2YR_TRANS_YR4_RT
# 976: NOT1STGEN_DEATH_YR4_RT
# 977: NOT1STGEN_COMP_ORIG_YR4_RT
# 978: NOT1STGEN_COMP_4YR_TRANS_YR4_RT
# 979: NOT1STGEN_COMP_2YR_TRANS_YR4_RT
# 980: NOT1STGEN_WDRAW_ORIG_YR4_RT
# 981: NOT1STGEN_WDRAW_4YR_TRANS_YR4_RT
# 982: NOT1STGEN_WDRAW_2YR_TRANS_YR4_RT
# 983: NOT1STGEN_ENRL_ORIG_YR4_RT
# 984: NOT1STGEN_ENRL_4YR_TRANS_YR4_RT
# 985: NOT1STGEN_ENRL_2YR_TRANS_YR4_RT
# 986: NOT1STGEN_UNKN_ORIG_YR4_RT
# 987: NOT1STGEN_UNKN_4YR_TRANS_YR4_RT
# 988: NOT1STGEN_UNKN_2YR_TRANS_YR4_RT
# 989: DEATH_YR6_RT
# 990: COMP_ORIG_YR6_RT
# 991: COMP_4YR_TRANS_YR6_RT
# 992: COMP_2YR_TRANS_YR6_RT
# 993: WDRAW_ORIG_YR6_RT
# 994: WDRAW_4YR_TRANS_YR6_RT
# 995: WDRAW_2YR_TRANS_YR6_RT
# 996: ENRL_ORIG_YR6_RT
# 997: ENRL_4YR_TRANS_YR6_RT
# 998: ENRL_2YR_TRANS_YR6_RT
# 999: UNKN_ORIG_YR6_RT
# 1000: UNKN_4YR_TRANS_YR6_RT
# 1001: UNKN_2YR_TRANS_YR6_RT
# 1002: LO_INC_DEATH_YR6_RT
# 1003: LO_INC_COMP_ORIG_YR6_RT
# 1004: LO_INC_COMP_4YR_TRANS_YR6_RT
# 1005: LO_INC_COMP_2YR_TRANS_YR6_RT
# 1006: LO_INC_WDRAW_ORIG_YR6_RT
# 1007: LO_INC_WDRAW_4YR_TRANS_YR6_RT
# 1269: MALE_ENRL_ORIG_YR8_RT
# 1270: MALE_ENRL_4YR_TRANS_YR8_RT
# 1271: MALE_ENRL_2YR_TRANS_YR8_RT
# 1272: MALE_UNKN_ORIG_YR8_RT
# 1273: MALE_UNKN_4YR_TRANS_YR8_RT
# 1274: MALE_UNKN_2YR_TRANS_YR8_RT
# 1275: PELL_DEATH_YR8_RT
# 1276: PELL_COMP_ORIG_YR8_RT
# 1277: PELL_COMP_4YR_TRANS_YR8_RT
# 1278: PELL_COMP_2YR_TRANS_YR8_RT
# 1279: PELL_WDRAW_ORIG_YR8_RT
# 1280: PELL_WDRAW_4YR_TRANS_YR8_RT
# 1281: PELL_WDRAW_2YR_TRANS_YR8_RT
# 1282: PELL_ENRL_ORIG_YR8_RT
# 1283: PELL_ENRL_4YR_TRANS_YR8_RT
# 1284: PELL_ENRL_2YR_TRANS_YR8_RT
# 1285: PELL_UNKN_ORIG_YR8_RT
# 1286: PELL_UNKN_4YR_TRANS_YR8_RT
# 1287: PELL_UNKN_2YR_TRANS_YR8_RT
# 1288: NOPELL_DEATH_YR8_RT
# 1289: NOPELL_COMP_ORIG_YR8_RT
# 1290: NOPELL_COMP_4YR_TRANS_YR8_RT
# 1291: NOPELL_COMP_2YR_TRANS_YR8_RT
# 1292: NOPELL_WDRAW_ORIG_YR8_RT
# 1293: NOPELL_WDRAW_4YR_TRANS_YR8_RT
# 1294: NOPELL_WDRAW_2YR_TRANS_YR8_RT
# 1295: NOPELL_ENRL_ORIG_YR8_RT
# 1296: NOPELL_ENRL_4YR_TRANS_YR8_RT
# 1297: NOPELL_ENRL_2YR_TRANS_YR8_RT
# 1298: NOPELL_UNKN_ORIG_YR8_RT
# 1299: NOPELL_UNKN_4YR_TRANS_YR8_RT
# 1300: NOPELL_UNKN_2YR_TRANS_YR8_RT
# 1301: LOAN_DEATH_YR8_RT
# 1302: LOAN_COMP_ORIG_YR8_RT
# 1303: LOAN_COMP_4YR_TRANS_YR8_RT
# 1304: LOAN_COMP_2YR_TRANS_YR8_RT
# 1305: LOAN_WDRAW_ORIG_YR8_RT
# 1306: LOAN_WDRAW_4YR_TRANS_YR8_RT
# 1307: LOAN_WDRAW_2YR_TRANS_YR8_RT
# 1308: LOAN_ENRL_ORIG_YR8_RT
# 1309: LOAN_ENRL_4YR_TRANS_YR8_RT
# 1310: LOAN_ENRL_2YR_TRANS_YR8_RT
# 1311: LOAN_UNKN_ORIG_YR8_RT
# 1312: LOAN_UNKN_4YR_TRANS_YR8_RT
# 1313: LOAN_UNKN_2YR_TRANS_YR8_RT
# 1314: NOLOAN_DEATH_YR8_RT
# 1315: NOLOAN_COMP_ORIG_YR8_RT
# 1316: NOLOAN_COMP_4YR_TRANS_YR8_RT
# 1317: NOLOAN_COMP_2YR_TRANS_YR8_RT
# 1318: NOLOAN_WDRAW_ORIG_YR8_RT
# 1319: NOLOAN_WDRAW_4YR_TRANS_YR8_RT
# 1320: NOLOAN_WDRAW_2YR_TRANS_YR8_RT
# 1321: NOLOAN_ENRL_ORIG_YR8_RT
# 1322: NOLOAN_ENRL_4YR_TRANS_YR8_RT
# 1323: NOLOAN_ENRL_2YR_TRANS_YR8_RT
# 1324: NOLOAN_UNKN_ORIG_YR8_RT
# 1325: NOLOAN_UNKN_4YR_TRANS_YR8_RT
# 1326: NOLOAN_UNKN_2YR_TRANS_YR8_RT
# 1327: FIRSTGEN_DEATH_YR8_RT
# 1328: FIRSTGEN_COMP_ORIG_YR8_RT
# 1329: FIRSTGEN_COMP_4YR_TRANS_YR8_RT
# 1330: FIRSTGEN_COMP_2YR_TRANS_YR8_RT
# 1331: FIRSTGEN_WDRAW_ORIG_YR8_RT
# 1332: FIRSTGEN_WDRAW_4YR_TRANS_YR8_RT
# 1333: FIRSTGEN_WDRAW_2YR_TRANS_YR8_RT
# 1334: FIRSTGEN_ENRL_ORIG_YR8_RT
# 1335: FIRSTGEN_ENRL_4YR_TRANS_YR8_RT
# 1336: FIRSTGEN_ENRL_2YR_TRANS_YR8_RT
# 1337: FIRSTGEN_UNKN_ORIG_YR8_RT
# 1338: FIRSTGEN_UNKN_4YR_TRANS_YR8_RT
# 1339: FIRSTGEN_UNKN_2YR_TRANS_YR8_RT
# 1340: NOT1STGEN_DEATH_YR8_RT
# 1341: NOT1STGEN_COMP_ORIG_YR8_RT
# 1342: NOT1STGEN_COMP_4YR_TRANS_YR8_RT
# 1343: NOT1STGEN_COMP_2YR_TRANS_YR8_RT
# 1344: NOT1STGEN_WDRAW_ORIG_YR8_RT
# 1345: NOT1STGEN_WDRAW_4YR_TRANS_YR8_RT
# 1346: NOT1STGEN_WDRAW_2YR_TRANS_YR8_RT
# 1347: NOT1STGEN_ENRL_ORIG_YR8_RT
# 1348: NOT1STGEN_ENRL_4YR_TRANS_YR8_RT
# 1349: NOT1STGEN_ENRL_2YR_TRANS_YR8_RT
# 1350: NOT1STGEN_UNKN_ORIG_YR8_RT
# 1351: NOT1STGEN_UNKN_4YR_TRANS_YR8_RT
# 1352: NOT1STGEN_UNKN_2YR_TRANS_YR8_RT
# 1353: RPY_1YR_RT
# 1354: COMPL_RPY_1YR_RT
# 1355: NONCOM_RPY_1YR_RT
# 1356: LO_INC_RPY_1YR_RT
# 1357: MD_INC_RPY_1YR_RT
# 1358: HI_INC_RPY_1YR_RT
# 1359: DEP_RPY_1YR_RT
# 1360: IND_RPY_1YR_RT
# 1361: PELL_RPY_1YR_RT
# 1362: NOPELL_RPY_1YR_RT
# 1363: FEMALE_RPY_1YR_RT
# 1364: MALE_RPY_1YR_RT
# 1365: FIRSTGEN_RPY_1YR_RT
# 1366: NOTFIRSTGEN_RPY_1YR_RT
# 1367: RPY_3YR_RT
# 1368: COMPL_RPY_3YR_RT
# 1369: NONCOM_RPY_3YR_RT
# 1370: LO_INC_RPY_3YR_RT
# 1371: MD_INC_RPY_3YR_RT
# 1372: HI_INC_RPY_3YR_RT
# 1373: DEP_RPY_3YR_RT
# 1374: IND_RPY_3YR_RT
# 1375: PELL_RPY_3YR_RT
# 1376: NOPELL_RPY_3YR_RT
# 1377: FEMALE_RPY_3YR_RT
# 1378: MALE_RPY_3YR_RT
# 1379: FIRSTGEN_RPY_3YR_RT
# 1380: NOTFIRSTGEN_RPY_3YR_RT
# 1381: RPY_5YR_RT
# 1382: COMPL_RPY_5YR_RT
# 1383: NONCOM_RPY_5YR_RT
# 1384: LO_INC_RPY_5YR_RT
# 1385: MD_INC_RPY_5YR_RT
# 1386: HI_INC_RPY_5YR_RT
# 1387: DEP_RPY_5YR_RT
# 1388: IND_RPY_5YR_RT
# 1389: PELL_RPY_5YR_RT
# 1390: NOPELL_RPY_5YR_RT
# 1391: FEMALE_RPY_5YR_RT
# 1392: MALE_RPY_5YR_RT
# 1393: FIRSTGEN_RPY_5YR_RT
# 1394: NOTFIRSTGEN_RPY_5YR_RT
# 1395: RPY_7YR_RT
# 1396: COMPL_RPY_7YR_RT
# 1397: NONCOM_RPY_7YR_RT
# 1398: LO_INC_RPY_7YR_RT
# 1399: MD_INC_RPY_7YR_RT
# 1400: HI_INC_RPY_7YR_RT
# 1401: DEP_RPY_7YR_RT
# 1402: IND_RPY_7YR_RT
# 1403: PELL_RPY_7YR_RT
# 1404: NOPELL_RPY_7YR_RT
# 1405: FEMALE_RPY_7YR_RT
# 1406: MALE_RPY_7YR_RT
# 1407: FIRSTGEN_RPY_7YR_RT
# 1408: NOTFIRSTGEN_RPY_7YR_RT
# 1409: INC_PCT_LO
# 1410: DEP_STAT_PCT_IND
# 1411: DEP_INC_PCT_LO
# 1412: IND_INC_PCT_LO
# 1413: PAR_ED_PCT_1STGEN
# 1414: INC_PCT_M1
# 1415: INC_PCT_M2
# 1416: INC_PCT_H1
# 1417: INC_PCT_H2
# 1418: DEP_INC_PCT_M1
# 1419: DEP_INC_PCT_M2
# 1420: DEP_INC_PCT_H1
# 1421: DEP_INC_PCT_H2
# 1422: IND_INC_PCT_M1
# 1423: IND_INC_PCT_M2
# 1424: IND_INC_PCT_H1
# 1425: IND_INC_PCT_H2
# 1426: PAR_ED_PCT_MS
# 1427: PAR_ED_PCT_HS
# 1428: PAR_ED_PCT_PS
# 1429: APPL_SCH_PCT_GE2
# 1430: APPL_SCH_PCT_GE3
# 1431: APPL_SCH_PCT_GE4
# 1432: APPL_SCH_PCT_GE5
# 1433: DEP_INC_AVG
# 1434: IND_INC_AVG
# 1435: OVERALL_YR2_N
# 1436: LO_INC_YR2_N
# 1437: MD_INC_YR2_N
# 1438: HI_INC_YR2_N
# 1439: DEP_YR2_N
# 1440: IND_YR2_N
# 1441: FEMALE_YR2_N
# 1442: MALE_YR2_N
# 1443: PELL_YR2_N
# 1444: NOPELL_YR2_N
# 1445: LOAN_YR2_N
# 1446: NOLOAN_YR2_N
# 1447: FIRSTGEN_YR2_N
# 1448: NOT1STGEN_YR2_N
# 1449: OVERALL_YR3_N
# 1450: LO_INC_YR3_N
# 1451: MD_INC_YR3_N
# 1452: HI_INC_YR3_N
# 1453: DEP_YR3_N
# 1454: IND_YR3_N
# 1455: FEMALE_YR3_N
# 1628: MEDIAN_HH_INC
# 1629: POVERTY_RATE
# 1630: UNEMP_RATE
# 1631: LN_MEDIAN_HH_INC
# 1632: FSEND_COUNT
# 1633: FSEND_1
# 1634: FSEND_2
# 1635: FSEND_3
# 1636: FSEND_4
# 1637: FSEND_5
# 1638: COUNT_NWNE_P10
# 1639: COUNT_WNE_P10
# 1640: MN_EARN_WNE_P10
# 1641: MD_EARN_WNE_P10
# 1642: PCT10_EARN_WNE_P10
# 1643: PCT25_EARN_WNE_P10
# 1644: PCT75_EARN_WNE_P10
# 1645: PCT90_EARN_WNE_P10
# 1646: SD_EARN_WNE_P10
# 1647: COUNT_WNE_INC1_P10
# 1648: COUNT_WNE_INC2_P10
# 1649: COUNT_WNE_INC3_P10
# 1650: COUNT_WNE_INDEP0_INC1_P10
# 1651: COUNT_WNE_INDEP0_P10
# 1652: COUNT_WNE_INDEP1_P10
# 1653: COUNT_WNE_MALE0_P10
# 1654: COUNT_WNE_MALE1_P10
# 1655: GT_25K_P10
# 1656: MN_EARN_WNE_INC1_P10
# 1657: MN_EARN_WNE_INC2_P10
# 1658: MN_EARN_WNE_INC3_P10
# 1659: MN_EARN_WNE_INDEP0_INC1_P10
# 1660: MN_EARN_WNE_INDEP0_P10
# 1661: MN_EARN_WNE_INDEP1_P10
# 1662: MN_EARN_WNE_MALE0_P10
# 1663: MN_EARN_WNE_MALE1_P10
# 1664: COUNT_NWNE_P6
# 1665: COUNT_WNE_P6
# 1666: MN_EARN_WNE_P6
# 1667: MD_EARN_WNE_P6
# 1668: PCT10_EARN_WNE_P6
# 1669: PCT25_EARN_WNE_P6
# 1670: PCT75_EARN_WNE_P6
# 1671: PCT90_EARN_WNE_P6
# 1672: SD_EARN_WNE_P6
# 1673: COUNT_WNE_INC1_P6
# 1674: COUNT_WNE_INC2_P6
# 1675: COUNT_WNE_INC3_P6
# 1676: COUNT_WNE_INDEP0_INC1_P6
# 1677: COUNT_WNE_INDEP0_P6
# 1678: COUNT_WNE_INDEP1_P6
# 1679: COUNT_WNE_MALE0_P6
# 1680: COUNT_WNE_MALE1_P6
# 1681: GT_25K_P6
# 1682: MN_EARN_WNE_INC1_P6
# 1683: MN_EARN_WNE_INC2_P6
# 1684: MN_EARN_WNE_INC3_P6
# 1685: MN_EARN_WNE_INDEP0_INC1_P6
# 1686: MN_EARN_WNE_INDEP0_P6
# 1687: MN_EARN_WNE_INDEP1_P6
# 1688: MN_EARN_WNE_MALE0_P6
# 1689: MN_EARN_WNE_MALE1_P6
# 1690: COUNT_NWNE_P7
# 1691: COUNT_WNE_P7
# 1692: MN_EARN_WNE_P7
# 1693: SD_EARN_WNE_P7
# 1694: GT_25K_P7
# 1695: COUNT_NWNE_P8
# 1696: COUNT_WNE_P8
# 1697: MN_EARN_WNE_P8
# 1698: MD_EARN_WNE_P8
# 1699: PCT10_EARN_WNE_P8
# 1700: PCT25_EARN_WNE_P8
# 1701: PCT75_EARN_WNE_P8
# 1702: PCT90_EARN_WNE_P8
# 1703: SD_EARN_WNE_P8
# 1704: GT_25K_P8
# 1705: COUNT_NWNE_P9
# 1706: COUNT_WNE_P9
# 1707: MN_EARN_WNE_P9
# 1708: SD_EARN_WNE_P9
# 1709: GT_25K_P9
# 1710: DEBT_MDN_SUPP
# 1711: GRAD_DEBT_MDN_SUPP
# 1712: GRAD_DEBT_MDN10YR_SUPP
# 1713: RPY_3YR_RT_SUPP
# 1714: LO_INC_RPY_3YR_RT_SUPP
# 1715: MD_INC_RPY_3YR_RT_SUPP
# 1716: HI_INC_RPY_3YR_RT_SUPP
# 1717: COMPL_RPY_3YR_RT_SUPP
# 1718: NONCOM_RPY_3YR_RT_SUPP
# 1719: DEP_RPY_3YR_RT_SUPP
# 1720: IND_RPY_3YR_RT_SUPP
# 1721: PELL_RPY_3YR_RT_SUPP
# 1722: NOPELL_RPY_3YR_RT_SUPP
# 1723: FEMALE_RPY_3YR_RT_SUPP
# 1724: MALE_RPY_3YR_RT_SUPP
# 1725: FIRSTGEN_RPY_3YR_RT_SUPP
# 1726: NOTFIRSTGEN_RPY_3YR_RT_SUPP
# 1727: C150_L4_POOLED_SUPP
# 1728: C150_4_POOLED_SUPP
# 1729: C200_L4_POOLED_SUPP
# 1730: C200_4_POOLED_SUPP
# 1731: ALIAS
# 1732: C100_4
# 1733: D100_4
# 1734: C100_L4
# 1735: D100_L4
# 1736: TRANS_4
# 1737: DTRANS_4
# 1738: TRANS_L4
# 1739: DTRANS_L4
# 1740: ICLEVEL
# 1741: UGDS_MEN
# 1742: UGDS_WOMEN
# 1743: CDR3_DENOM
# 1744: CDR2_DENOM

# %%
# %%sql
# DROP TABLE IF EXISTS education15;
# CREATE TABLE education15 (
#     YEAR INT,
#     INSTITUTION VARCHAR(94),
#     CITY VARCHAR(25),
#     STABBR VARCHAR(2),
#     ZIP VARCHAR(11),
#     HIGHDEG INT,
#     ICLEVEL VARCHAR(11),
#     ADM_RATE VARCHAR(18),
#     ADM_RATE_ALL VARCHAR(18),
#     SAT_AVG VARCHAR(8),
#     SAT_AVG_ALL VARCHAR(8),
#     RET_FT4 VARCHAR(18),
#     RET_FTL4 VARCHAR(18),
#     RET_PT4 VARCHAR(18),
#     RET_PTL4 VARCHAR(18),
#     INC_PCT_LO VARCHAR(18),
#     INC_PCT_M1 VARCHAR(18),
#     INC_PCT_M2 VARCHAR(18),
#     INC_PCT_H1 VARCHAR(18),
#     INC_PCT_H2 VARCHAR(18),
#     DEBT_MDN VARCHAR(18),
#     GRAD_DEBT_MDN VARCHAR(18),
#     WDRAW_DEBT_MDN VARCHAR(18),
#     LO_INC_DEBT_MDN VARCHAR(18),
#     MD_INC_DEBT_MDN VARCHAR(18),
#     HI_INC_DEBT_MDN VARCHAR(18),
#     MN_EARN_WNE_P6 VARCHAR(18),
#     MN_EARN_WNE_P7 VARCHAR(18),
#     MN_EARN_WNE_P8 VARCHAR(18),
#     MN_EARN_WNE_P9 VARCHAR(18),
#     MN_EARN_WNE_P10 VARCHAR(18),
#     MD_EARN_WNE_P6 VARCHAR(18),
#     MD_EARN_WNE_P8 VARCHAR(18),
#     MD_EARN_WNE_P10 VARCHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
#  (2008, 'University of Alaska Fairbanks', 'Fairbanks', 'AK', '99775-7500', 4, '1', '0.7084', '0.7084', '999', '999', '0.7266', 'NULL', '0.5455', 'NULL', '0.4537937743', '0.170233463', '0.15807393', '0.1259727626', '0.09192607', '5500', '9000', '4750', '6250', '5258', '4625', 'NULL', '36200', 'NULL', '38300', 'NULL', 'NULL', 'NULL', 'NULL'),
#  (2009, 'University of Alaska Fairbanks', 'Fairbanks', 'AK', '99775-7500', 4, '1', '0.7446', '0.7446', '1023', '1023', '0.802', 'NULL', '0.5333', 'NULL', '0.4576828266', '0.1610517666', '0.1585866886', '0.1273623665', '0.0953163517', '5500', '11062.5', '5500', '7007', '5500', '5500', '34800', 'NULL', '38300', 'NULL', '40100', '31100', '34200', '36200'),
#  (2008, 'Ilisagvik College', 'Barrow', 'AK', '99723', 2, '2', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '0.5', 'NULL', '0.48', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'NULL', 'PrivacySuppressed', 'NULL', 'PrivacySuppressed', 'NULL', 'NULL', 'NULL', 'NULL'),
#  (2007, 'Ilisagvik College', 'Barrow', 'AK', '99723', 2, '2', 'NULL', 'NULL', 'NULL', 'NULL', 'NULL', '0.8182', 'NULL', '0.8571', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'PrivacySuppressed', 'NULL', 'PrivacySuppressed', 'NULL', 'NULL', 'PrivacySuppressed', 'PrivacySuppressed', 'NULL')]

# %% [markdown]
# # Creating the StarSchema

# %% [markdown]
# ![](https://raw.githubusercontent.com/abhinav-91/DataManagement/master/Images/StarSchema.png)

# %%
# %%sql
# DROP TABLE IF EXISTS location_D;
# CREATE TABLE location_D(
#   City VARCHAR(90),
#   State VARCHAR(90),
#   Zip VARCHAR(10)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO location_D
# SELECT DISTINCT City,Stabbr,Zip from education15;
# Out:
# 6602 rows affected.
# []

# %%
# %%sql
# ALTER TABLE location_D
# ADD COLUMN location_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS sat_D;
# CREATE TABLE sat_D (
#     sat_avg VARCHAR(25),
#     sat_avg_all VARCHAR(10)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO sat_D
# SELECT DISTINCT sat_avg,sat_avg_all from education15;
# Out:
# 1115 rows affected.
# []

# %%
# %%sql
# ALTER TABLE sat_D
# ADD COLUMN sat_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS retention_D;
# CREATE TABLE retention_D (
#     ret_ft4 VARCHAR(18),
#     ret_ftl4_all VARCHAR(18),
#     ret_pt4 VARCHAR(18),
#     ret_ptl4 VARCHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO retention_D
# SELECT DISTINCT ret_ft4,ret_ftl4,ret_pt4,ret_ptl4 from education15;
# Out:
# 17995 rows affected.
# []

# %%
# %%sql
# ALTER TABLE retention_D
# ADD COLUMN retention_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS fam_income_D;
# CREATE TABLE fam_income_D (
#     inc_pct_lo VARCHAR(18),
#     inc_pct_m1 VARCHAR(18),
#     inc_pct_m2 VARCHAR(18),
#     inc_pct_h1 VARCHAR(18),
#     inc_pct_h2 VARCHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO fam_income_D
# SELECT DISTINCT inc_pct_lo,inc_pct_m1,inc_pct_m2,inc_pct_h1,inc_pct_h2 from education15;
# Out:
# 19084 rows affected.
# []

# %%
# %%sql
# ALTER TABLE fam_income_D
# ADD COLUMN fam_income_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS debt_D;
# CREATE TABLE debt_D (
#     DEBT_MD VARCHAR(18),
#     GRAD_DEBT_MD VARCHAR(18),
#     WDRAW_DEBT_MD VARCHAR(18),
#     LO_INC_DEBT_MD VARCHAR(18),
#     MD_INC_DEBT_MD VARCHAR(18),
#     HI_INC_DEBT_MD VARCHAR(18)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO debt_D
# SELECT DISTINCT debt_mdn,grad_debt_mdn,wdraw_debt_mdn,lo_inc_debt_mdn,md_inc_debt_mdn,hi_inc_debt_mdn from education15;
# Out:
# 17182 rows affected.
# []

# %%
# %%sql
# ALTER TABLE debt_D
# ADD COLUMN debt_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS year_D;
# CREATE TABLE year_D (
#    year INT
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO year_D
# SELECT DISTINCT year from education15;
# Out:
# 4 rows affected.
# []

# %%
# %%sql
# ALTER TABLE year_D
# ADD COLUMN year_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS admission_D;
# CREATE TABLE admission_D (
#    adm_rate VARCHAR(18),
#    adm_rate_all VARCHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO admission_D
# SELECT DISTINCT adm_rate,adm_rate_all from education15;
# Out:
# 7026 rows affected.
# []

# %%
# %%sql
# ALTER TABLE admission_D
# ADD COLUMN admission_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education_fact;
# CREATE TABLE education_fact (
#     INS_name VARCHAR(94),
#     year_id INT,
#     location_id INT,
#     admission_id INT,
#     retention_id INT,
#     sat_id INT,
#     debt_id INT,
#     fam_income_id INT,
#     FOREIGN KEY (year_id) REFERENCES year_D(year_id),
#     FOREIGN KEY (location_id) REFERENCES location_D(location_id),
#     FOREIGN KEY (admission_id) REFERENCES admission_D(admission_id),
#     FOREIGN KEY (retention_id) REFERENCES retention_D(retention_id),
#     FOREIGN KEY (sat_id) REFERENCES sat_D(sat_id),
#     FOREIGN KEY (debt_id) REFERENCES debt_D(debt_id),
#     FOREIGN KEY (fam_income_id) REFERENCES fam_income_D(fam_income_id)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO education_fact
# SELECT education15.institution,year_D.year_id,location_D.location_id,admission_D.admission_id,retention_D.retention_id,sat_D.sat_id,debt_D.debt_id,fam_income_D.fam_income_id
# FROM education15
# JOIN
# year_D
# ON education15.year=year_D.year
# JOIN
# location_D
# ON
# education15.city=location_D.city
# AND education15.stabbr=location_D.state
# AND education15.zip=location_D.zip
# JOIN
# admission_D
# ON
# education15.adm_rate=admission_D.adm_rate
# AND education15.adm_rate_all=admission_D.adm_rate_all
# JOIN
# retention_D
# ON
# education15.ret_ft4=retention_D.ret_ft4
# AND education15.ret_ftl4=retention_D.ret_ftl4_all
# AND education15.ret_pt4=retention_D.ret_pt4
# AND education15.ret_ptl4=retention_D.ret_ptl4
# JOIN
# sat_D
# ON
# education15.sat_avg=sat_d.sat_avg
# AND education15.sat_avg_all=sat_d.sat_avg_all
# JOIN
# debt_d
# ON
# education15.debt_mdn=debt_D.debt_md
# AND education15.grad_debt_mdn=debt_D.grad_debt_md
# AND education15.wdraw_debt_mdn=debt_D.wdraw_debt_md
# AND education15.lo_inc_debt_mdn=debt_D.lo_inc_debt_md
# AND education15.md_inc_debt_mdn=debt_D.md_inc_debt_md
# AND education15.hi_inc_debt_mdn=debt_D.hi_inc_debt_md
# JOIN
# fam_income_D
# ON
# education15.inc_pct_lo=fam_income_D.inc_pct_lo
# AND education15.inc_pct_m1=fam_income_D.inc_pct_m1
# AND education15.inc_pct_m2=fam_income_D.inc_pct_m2
# AND education15.inc_pct_h1=fam_income_D.inc_pct_h1
# AND education15.inc_pct_h2=fam_income_D.inc_pct_h2
# Out:
# 28428 rows affected.
# []

# %%
# %%sql
# DROP TABLE education15;
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * from education_fact where ins_name='University of Idaho';
# Out:
# 4 rows affected.
# [('University of Idaho', 4, 6512, 397, 2529, 70, 16093, 1921),
#  ('University of Idaho', 1, 6512, 6351, 2799, 61, 10251, 6369),
#  ('University of Idaho', 3, 6512, 6275, 9557, 70, 1816, 8772),
#  ('University of Idaho', 2, 6512, 4100, 12878, 70, 16595, 251)]

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="81290936-5a88-4270-a1a1-a466f0ebb1fc">Loading BokehJS ...</span>
#     </div>

# %%
# %%sql
# select SUM(CAST(debt_D.DEBT_MD AS FLOAT))AS DEBT,CAST(location_D.state AS VARCHAR(2))
#
# FROM debt_D
# JOIN
# education_fact
# ON
# debt_D.debt_id=education_fact.debt_id
#
# JOIN
# location_D
# ON education_fact.location_id=location_D.location_id
# WHERE debt_md NOT LIKE 'PrivacySuppressed' AND debt_md NOT LIKE 'NULL'
#
#
# GROUP BY location_D.state
# Out:
# 54 rows affected.
# [(14983160.5, 'PA'),
#  (9435204.0, 'FL'),
#  (2984864.5, 'AZ'),
#  (2516267.5, 'LA'),
#  (609819.5, 'MT'),
#  (31479.5, 'GU'),
#  (1170657.5, 'NM'),
#  (211359.5, 'AK'),
#  (4221467.0, 'NC'),
#  (2812021.5, 'OR'),
#  (1148337.5, 'VT'),
#  (1159239.0, 'MS'),
#  (1842566.0, 'AR'),
#  (5674849.0, 'MO'),
#  (7575411.0, 'IL'),
#  (4646600.5, 'IN'),
#  (455115.5, 'HI'),
#  (247836.0, 'WY'),
#  (1654210.5, 'UT'),
#  (4924538.5, 'MI'),
#  (2605414.5, 'KS'),
#  (2660848.5, 'MD'),
#  (32104.0, 'VI'),
#  (4481482.5, 'GA'),
#  (4369666.5, 'MN'),
#  (3157085.0, 'WI'),
#  (684185.5, 'DC'),
#  (9694612.5, 'OH'),
#  (1629318.5, 'NE'),
#  (2813390.5, 'CT'),
#  (1098013.0, 'NV'),
#  (931586.5, 'PR'),
#  (2578460.0, 'OK'),
#  (1953015.0, 'AL'),
#  (17820681.0, 'CA'),
#  (3227015.5, 'CO'),
#  (1579379.0, 'WV'),
#  (494625.0, 'DE'),
#  (738303.0, 'ND'),
#  (3395335.5, 'WA'),
#  (2563087.0, 'KY'),
#  (1371867.0, 'ME'),
#  (979055.0, 'RI'),
#  (4192042.0, 'TN'),
#  (791442.0, 'SD'),
#  (4749362.0, 'VA'),
#  (1426124.5, 'NH'),
#  (3104968.5, 'IA'),
#  (2686738.5, 'SC'),
#  (12191716.0, 'NY'),
#  (6073235.0, 'MA'),
#  (10099973.5, 'TX'),
#  (4069089.0, 'NJ'),
#  (844710.5, 'ID')]

# %%
from bokeh.charts import Bar, output_file, show
from bokeh.charts import defaults
from bokeh.plotting import figure, output_file, show

defaults.width = 1000
defaults.height = 350

result= _
df=result.DataFrame()

p = Bar(df, 'state', values='debt', title="Total Debt by State")
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color
-50cf8b0a78aa","type":"GlyphRenderer"}]],["MT",[{"id":"0a88436c-acdd-4952-aafd-35f022a64561","type":"GlyphRenderer"}]],["GU",[{"id":"d367f1a7-59f5-48c2-809e-212bf395e453","type":"GlyphRenderer"}]],["NM",[{"id":"8592a789-828f-4548-acb0-ccfb4ae483af","type":"GlyphRenderer"}]],["AK",[{"id":"d429442b-77fa-4116-80f2-cb0a09f6bab9","type":"GlyphRenderer"}]],["NC",[{"id":"67ac91a1-c3eb-45eb-820c ...

# %%
# %%sql
# SELECT year_D.year, round(AVG(CAST(admission_D.adm_rate_all AS NUMERIC)),2) AS Admission_rate, ROUND(AVG(CAST(sat_D.sat_avg_all AS INT)),0) AS Average_SAT_score,
#     ROUND(AVG(CAST(retention_D.RET_FT4 AS NUMERIC)),2) AS Average_retention_rate
#
# FROM admission_D
# JOIN
# education_fact
# ON
# admission_D.admission_id=education_fact.admission_id
#
# JOIN
# sat_D
# ON sat_D.sat_id=education_fact.sat_id
#
# JOIN
# retention_D
# ON education_fact.retention_id=retention_D.retention_id
#
# JOIN
# year_D
# ON education_fact.year_id=year_D.year_id
#
# WHERE adm_rate_all NOT LIKE 'NULL' AND RET_FT4 NOT LIKE 'NULL' AND sat_avg_all NOT LIKE 'NULL'
# GROUP BY year;
# Out:
# 4 rows affected.
# [(2010, Decimal('0.64'), Decimal('1063'), Decimal('0.75')),
#  (2007, Decimal('0.66'), Decimal('1058'), Decimal('0.75')),
#  (2009, Decimal('0.65'), Decimal('1061'), Decimal('0.75')),
#  (2008, Decimal('0.65'), Decimal('1060'), Decimal('0.75'))]

# %%
import numpy as np

from bokeh.io import output_file, show, vplot, hplot
from bokeh.plotting import figure

result= _
df=result.DataFrame()

x = df['year'].values.tolist()
y = df['admission_rate'].values.tolist()
y1 = df['average_retention_rate'].values.tolist()
y2 = df['average_sat_score'].values.tolist()

# create a new plot
s1 = figure(width=400, plot_height=400, title='Avg. Admission Rate')
s1.circle(x, y, size=10, color="navy", alpha=0.5)
s1.background_fill_color = "beige"
s1.background_fill_alpha = 0.5
s1.outline_line_width = 7
s1.outline_line_alpha = 0.3
s1.outline_line_color = "navy"

# create another one
s2 = figure(width=400, height=400, title='Avg. Retention Rate')
s2.circle(x, y1, size=10, color="red", alpha=0.5)
s2.background_fill_color = "beige"
s2.background_fill_alpha = 0.5
s2.outline_line_width = 7
s2.outline_line_alpha = 0.3
s2.outline_line_color = "navy"

# create and another
s3 = figure(width=400, height=400, title='Avg. SAT Score')
s3.circle(x, y2, size=10, color="green", alpha=0.5)
s3.background_fill_color = "beige"
s3.background_fill_alpha = 0.5
s3.outline_line_width = 7
s3.outline_line_alpha = 0.3
s3.outline_line_color = "navy"

# put all the plots in a VBox
p = vplot(s1, s2, s3)

# show the results
show(p)
# Out:
# /Users/abhinavchandel/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:42: BokehDeprecationWarning: bokeh.io.vplot was deprecated in Bokeh 0.12.0; please use bokeh.models.layouts.Column instead
#     <div class="bk-root">
#         <div class="plotdiv" id="c279e7cb-648f-44b4-b3f3-2673d7ab79f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#
type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"cd0ef820-0abe-4f2c-9df0-e1c86e3e7f13","type":"Circle"},"selection_glyph":null},"id":"94c360c7-7e52-4b52-9dbd-9e33960d9680","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0c1bd5ac-0a6e-4796-b98f-9ee01600d469","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"0e4e2468-ec60-474a-a425-f4a77a810aab","type":"BoxAnnotation"},"plot":{"id":"7ff8e050-5755-46a9-b658-6542e40d2fc6","subtype":"Figure","type":"Plot"}},"id":"10f12ffe-edcb-4672-8ec7-6f88bbfcb211","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"e7095d3c-b245-4e63-a18a-980df3af053a","type":"DataRange1d"},{"attributes":{"plot":{"id":"56e13be1-9714-4b05-8523-ad0b3e1b5727","subtype":"Figure","type":"Plot"}},"id":"334dcf5b-60e4-4073-9aec-48959b6c7edd","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bb5a676d-d9c8-4560-9810-9bccec27c ...

# %%
# %%sql
# SELECT year_D.year, CAST(education_fact.ins_name AS VARCHAR(48)), CAST(ROUND(CAST(admission_D.adm_rate_all AS NUMERIC),2) AS FLOAT) AS Admission_rate, CAST(sat_D.sat_avg_all AS INT) AS SAT_score,
#     CAST(ROUND(CAST(debt_D.DEBT_MD AS NUMERIC))AS INT) AS debt
#
# FROM admission_D
# JOIN
# education_fact
# ON
# admission_D.admission_id=education_fact.admission_id
#
# JOIN
# sat_D
# ON sat_D.sat_id=education_fact.sat_id
#
# JOIN
# debt_D
# ON
# debt_D.debt_id=education_fact.debt_id
#
# JOIN
# year_D
# ON education_fact.year_id=year_D.year_id
#
# WHERE adm_rate_all NOT LIKE 'NULL' AND debt_md NOT LIKE 'NULL' AND debt_md NOT LIKE 'PrivacySuppressed' AND sat_avg_all NOT LIKE 'NULL'
#     AND year = 2010
# ORDER BY Admission_rate
# LIMIT 25;
# Out:
# 25 rows affected.
# [(2010, 'Harvard University', 0.07, 1478, 6000),
#  (2010, 'Alice Lloyd College', 0.07, 953, 4300),
#  (2010, 'Stanford University', 0.07, 1452, 7500),
#  (2010, 'Yale University', 0.08, 1473, 7125),
#  (2010, 'Cooper Union for the Advancement of Science and ', 0.08, 1366, 8125),
#  (2010, 'Brown University', 0.09, 1415, 11000),
#  (2010, 'Princeton University', 0.09, 1485, 7500),
#  (2010, 'Columbia University in the City of New York', 0.1, 1457, 8740),
#  (2010, 'Massachusetts Institute of Technology', 0.1, 1486, 9720),
#  (2010, 'California Institute of Technology', 0.13, 1528, 8461),
#  (2010, 'Dartmouth College', 0.13, 1444, 8119),
#  (2010, 'University of Pennsylvania', 0.14, 1435, 14791),
#  (2010, 'Victory University', 0.14, 780, 15750),
#  (2010, 'West Virginia University Hospital Departments of', 0.14, 1075, 12460),
#  (2010, 'Amherst College', 0.15, 1435, 7000),
#  (2010, 'Pomona College', 0.15, 1461, 7500),
#  (2010, 'Swarthmore College', 0.16, 1419, 13500),
#  (2010, 'Middlebury Institute of International Studies at', 0.17, 1390, 15000),
#  (2010, 'Middlebury College', 0.17, 1390, 15000),
#  (2010, 'Claremont McKenna College', 0.17, 1388, 7750),
76-4c12-413f-b8fc-245fc3ab84ae","type":"GlyphRenderer"}]],["Middlebury College",[{"id":"c03251b4-fffa-48c8-842d-b660c2af3734","type":"GlyphRenderer"}]],["Claremont McKenna College",[{"id":"31553585-c810-4a07-a304-74fa5157fa7d","type":"GlyphRenderer"}]],["Berea College",[{"id":"5caf9b99-a2a2-4cd7-b6dd-e8380a619d64","type":"GlyphRenderer"}]],["Cornell University",[{"id":"959c9f19-eb88-4164-97d8-23e1cf33e839","type":"GlyphRenderer"}]],["Weill Cornell Medical College",[{"id":"f03c3e15-8466-4b02-a1ef-09a6ec1b272c","type":"GlyphRenderer"}]],["Vanderbilt University",[{"id":"b64b163a-7c54-41ca-9a2f-9952f5304c2e","type":"GlyphRenderer"}]],["Alma College",[{"id":"03c339c0-9739-4a8d-a301-899b0e9e3812","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"03981fd5-f5e5-4ec8-9f6f-55848b443a1b","subtype":"Chart","type":"Plot"}},"id":"afc69336-44f1-4fbc-a2ff-537fd5cc61d1","type":"Legend"},{"attributes":{"callback":null,"column_names":["line_alpha","color","height","fill_alpha","line_color","width","label","y","x"],"data":{"chart_index":[{"ins_name":"Dartmouth College"}],"color":["blue"],"fill_alpha":[0.8],"height":[0.13],"ins_name":["Dartmouth College"],"label":[{"ins_name":"Dartmouth College"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Dartmouth College"],"y":[0.065]}},"id":"9299b37e-04d0-4b76-9083-4d8a21961cf6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","color","height","fill_alpha","line_color","width","label","y","x"],"data":{"chart_index":[{"ins_name":"Middlebury College"}],"color":["blue"],"fill_alpha":[0.8],"height":[0.17],"ins_name":["Middlebury College"],"label":[{"ins_name":"Middlebury College"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Middlebury College"],"y":[0.085]}},"id":"311811 ...

# %%
# %%sql
# SELECT year_D.year, CAST(education_fact.ins_name AS VARCHAR(52)), ROUND(CAST(admission_D.adm_rate_all AS NUMERIC),2) AS Admission_rate, CAST(sat_D.sat_avg_all AS INT) AS SAT_score,
#     CAST(ROUND(CAST(debt_D.DEBT_MD AS NUMERIC))AS INT) AS debt
#
# FROM admission_D
# JOIN
# education_fact
# ON
# admission_D.admission_id=education_fact.admission_id
#
# JOIN
# sat_D
# ON sat_D.sat_id=education_fact.sat_id
#
# JOIN
# debt_D
# ON
# debt_D.debt_id=education_fact.debt_id
#
# JOIN
# year_D
# ON education_fact.year_id=year_D.year_id
#
# WHERE adm_rate_all NOT LIKE 'NULL' AND debt_md NOT LIKE 'NULL' AND debt_md NOT LIKE 'PrivacySuppressed' AND sat_avg_all NOT LIKE 'NULL'
#     AND year = 2010
# ORDER BY debt DESC
# LIMIT 25;
# Out:
# 25 rows affected.
# [(2010, 'Lyme Academy College of Fine Arts', Decimal('0.98'), 1010, 22125),
#  (2010, 'Allegheny College', Decimal('0.59'), 1217, 22125),
#  (2010, 'University of the Sciences', Decimal('0.62'), 1179, 22125),
#  (2010, 'Ursinus College', Decimal('0.55'), 1213, 22125),
#  (2010, 'Bryant University', Decimal('0.53'), 1141, 22125),
#  (2010, 'Lycoming College', Decimal('0.64'), 1055, 22110),
#  (2010, "Saint Michael's College", Decimal('0.82'), 1137, 21935),
#  (2010, 'VanderCook College of Music', Decimal('0.98'), 1076, 21875),
#  (2010, 'Aria Health School of Nursing', Decimal('0.57'), 1015, 21667),
#  (2010, 'Gustavus Adolphus College', Decimal('0.70'), 1225, 21629),
#  (2010, "Saint Mary's College", Decimal('0.81'), 1121, 21608),
#  (2010, 'Cedar Crest College', Decimal('0.42'), 1026, 21500),
#  (2010, 'Saint Vincent College', Decimal('0.75'), 1066, 21322),
#  (2010, 'Saint Vincent Seminary', Decimal('0.75'), 1066, 21322),
#  (2010, 'Providence College', Decimal('0.67'), 1161, 21250),
#  (2010, 'Otis College of Art and Design', Decimal('0.50'), 1049, 21000),
#  (2010, 'Luther College', Decimal('0.72'), 1204, 20936),
#  (2010, 'Villanova University', Decimal('0.45'), 1306, 20845),
#  (2010, 'Augustana University', Decimal('0.83'), 1165, 20775),
#  (2010, 'Saint Anselm College', Decimal('0.77'), 1082, 20751),
#  (2010, 'Mount Carmel College of Nursing', Decimal('0.72'), 1050, 20750),
#  (2010, 'Northeastern University', Decimal('0.38'), 1313, 20500),
#  (2010, 'University of Scranton', Decimal('0.74'), 1125, 20500),
#  (2010, 'Baptist Memorial College of Health Sciences', Decimal('0.19'), 1070, 20500),
#  (2010, 'Saint Elizabeth School of Nursing', Decimal('0.53'), 982, 20500)]

# %%
from bokeh.plotting import figure, output_file, show

result= _
df=result.DataFrame()

df.sort('debt')
p = figure(plot_width=1000, plot_height=1000)
p = Bar(df, 'ins_name', values='debt', title="Highest Debt (4YR US Colleges)", color = 'green', y_range=[20000, 24000])
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"
#p.yaxis.bounds = (20000, 24000)
show(p)
# Out:
# /Users/abhinavchandel/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#     <div class="bk-root">
#         <div class="plotdiv" id="ea0d4f30-b330-4187-b3ff-7e5abbc560f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ea0d4f30-b330-4187-b3ff-7e5abbc560f5").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ea0d4f30-b330-4187-b3ff-7e5abbc560f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ea0d4f30-b330-4187-b3ff-7e5abbc560f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e5da0514-61eb-49ea-8b6e-2d8cdfe23c1e":{"roots":{"references":[{"attributes":{"data_source":{"id":"91f13549-c3e2-4625-89c1-6281fc345cec","type":"ColumnDataSource"},"glyph":{"id":"ece166ac-3c54-4e18-a878-6fceb716a376","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9ff6e7e4-b0a9-48e9-902a-a17c72465312","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","color","height","fill_alpha","line_color","width","label","y","x"],"data":{"chart_index":[{"ins_name":"Ursinus College"}],"color":["green"],"fill_alpha":[0.8],"height":[22125.0],"ins_name":["Ursinus College"],"label":[{"ins_name":"Ursinus College"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Ursinus College"],"y":[11062.5]}},"id":"959c6281-5d46-4084-b26a-cf0ced8ace34","type":"ColumnDataSource"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"0813fde4-575b-4bd5-af62-e599effd01f9","type":"CategoricalAxis"}],"height":500,"left":[{"id":"8a84a7b0-b814-4867-9f18-1ff241ee3100","type":"LinearAxis"}],"outline_line_alpha":{"value":0.3},"outline_line_color":{"value":"navy"},"outline_line_width":{"value":7},"renderers":[{"id":"fbf304a4-bea4-403b-8f2a-2dce08daade5","type":"BoxAnnotation"},{"id":"92b6f357-2a42-4ded-b9dc-1a57b3c414be","type":"GlyphRenderer"},{"id":"753393
},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field": ...

# %%
# %%sql
#
# SELECT DISTINCT CAST(ins_name AS VARCHAR(52)), CAST(ROUND(AVG(inc_pct_h2),2)AS FLOAT) AS Average_high_income_pct
# FROM
#     (SELECT  education_fact.ins_name, CAST(fam_income_D.inc_pct_h2 AS NUMERIC)
#         FROM  fam_income_D
#
#
#             JOIN
#             education_fact
#             ON
#             fam_income_D.fam_income_id=education_fact.fam_income_id
#
# WHERE inc_pct_h2 NOT LIKE 'NULL' AND inc_pct_h2 NOT LIKE 'PrivacySuppressed'
# GROUP BY education_fact.ins_name, inc_pct_h2) AS lol
# GROUP BY lol.ins_name
# ORDER BY Average_high_income_pct DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Jewish Theological Seminary of America', 0.53),
#  ('Washington and Lee University', 0.51),
#  ('University of Notre Dame', 0.47),
#  ('Elon University', 0.46),
#  ("Saint Joseph's University", 0.45),
#  ('College of the Holy Cross', 0.44),
#  ('Muhlenberg College', 0.44),
#  ('Villanova University', 0.44),
#  ('Catholic University of America', 0.43),
#  ('Franklin and Marshall College', 0.43)]

# %%
defaults.width = 1000
defaults.height = 600

result= _
df=result.DataFrame()

p = Bar(df, 'ins_name', values='average_high_income_pct', title="% Dist. of Students (High-Inc. Families)")
p.background_fill_color = "beige"
p.background_fill_alpha = 0.5
p.outline_line_width = 7
p.outline_line_alpha = 0.3
p.outline_line_color = "navy"

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a68fe029-6f4a-4f71-b518-1c8b03e81f54"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a68fe029-6f4a-4f71-b518-1c8b03e81f54").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a68fe029-6f4a-4f71-b518-1c8b03e81f54");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a68fe029-6f4a-4f71-b518-1c8b03e81f54' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"16101ac3-ae5c-4c5d-b4ec-c472c9f77b55":{"roots":{"references":[{"attributes":{},"id":"d0711b7c-eab4-4e03-b1a0-21b88ea82889","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"% Dist. of Students (High-Inc. Families)"},"id":"68db6ad4-defc-47d3-b97f-80c22864ca33","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9e69c1d8-b014-4a1f-9c64-2f65f1946c35","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","color","height","fill_alpha","line_color","width","label","y","x"],"data":{"chart_index":[{"ins_name":"Franklin and Marshall College"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.43],"ins_name":["Franklin and Marshall College"],"label":[{"ins_name":"Franklin and Marshall College"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Franklin and Marshall College"],"y":[0.215]}},"id":"189eea9c-3b1c-4274-98ff-599e8039ccb4","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1fb1669a-0e2f-4baf-abb9-9b94ab79fcfb","type":"Rect"},{"attributes":{"data_source":{"id":"da8eb3a3-57f9-4d14-ac7a-acfa217ee6eb","type":"ColumnDataSource"},"glyph":{"id":"052710d9-1413-4fec-904a-31d7d593a170","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"624d15c8-b395-4364-bf04-bf0f6df5caa4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","color","height","fill_alpha","line_color","width","label","y","x"],"data":{"chart_index":[{"ins_name":"University of Notre Dame"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.47],"ins_name":["University of Notre Dame"],"label":[{"ins_name":"University of Notre Dame"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["University of Notre Dame"],"y":[0.235]}},"id":"b1e57cdf-9569-4808-917b-25fbb653fdc5","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1069aa49-5820-4448-a263-817a9d234181","type":"Rect"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"beige"},"below":[{"id":"bd4f9588-f24b-4f58-a13d-cd6417f39dae","type":"CategoricalAxis"}],"height":600,"left":[{"id":"2b33d92f-0f54-4f19-b1b3-ba886b904d62","type":"LinearAxis"}],"outline_line_alpha":{"value":0.3},"outline_line_color":{"value":"navy"},"outline_line_width":{"value":7},"renderers":[{"id":"05b147fd-3d5d-49f2-bea5-c0ef93c74bfb","type":"BoxAnnotation"},{"id":"eec7052f-ddda-4452-9079-44e96cb861e9","type":"GlyphRenderer"},{"id":"e2cf958b-da27-4955-8d00-6cbe4ce2fb60","type":"GlyphRenderer"},{"id":"3a112a87-3089-4e34-98b8-297baa7d4dd2","type":"GlyphRenderer"},{"id":"a03bcdb1-f5a4-464c-a863-661d4d524f58","type":"GlyphRenderer"},{"id":"5b826380-e1b4-4544-9f0d-4658e9bf1a52","type":"GlyphRenderer"},{"id":"624d15c8-b395-4364-bf04-bf0f6df5caa4","type":"GlyphRenderer"},{"id":"2497e984-986f-4bc4-84a7-edeee7747ab1","type":"GlyphRenderer"},{"id":"636bac55-af27-4b90-acf6-5b5d06f05712","type":"GlyphRenderer"},{"id":"69326977-943b-48db-9ec1-17ff0bc15089","type":"GlyphRenderer"},{"id":"0997d298-40bb-493c-a985-3bb71dff3595","type":"GlyphRenderer"},{"id":"98f86815-b6fa-40e4-9459-a9bbcc68654b","type":"Legend"},{"id":"bd4f9588-f24b-4f58-a13d-cd6417f39dae","type":"CategoricalAxis"},{"id":"2b33d92f-0f54-4f19-b1b3-ba886b904d62","type":"LinearAxis"},{"id":"ba0a6ce3-792d-41ba-b831-8692348ed02f","type":"Grid"}],"title":{"id":"68db6ad4-defc-47d3-b9 ...

# %% [markdown]
# # Income Data

# %% [markdown]
# ## Choosing columns that contain valuable data
# I have decided to keep the following columns:
#
# STATE: The State associated with the ZIP code
#
# ZIPCODE: 5digit
#
# Zip code
#
# NUMDEP: Number of dependents
#
# A00100: Adjust gross income

# %%
# !csvcut -n zipcode06.csv
# Out:
#   1: state
#   2: agi_class
#   3: zipcode
#   4: n1
#   5: n2
#   6: n6
#   7: a00100
#   8: n00200
#   9: a00200
#  10: n00300
#  11: a00300
#  12: n00600
#  13: a00600
#  14: n23900
#  15: a23900
#  16: n00900
#  17: a00900
#  18: n02100
#  19: a02100
#  20: n03150
#  21: a03150
#  22: n03300
#  23: a03300
#  24: n04470
#  25: agi_04470
#  26: a04470
#  27: n19700
#  28: agi_19700
#  29: a19700
#  30: n18300
#  31: agi_18300
#  32: a18300
#  33: n09600
#  34: a09600
#  35: n05800
#  36: a05800
#  37: n09200
#  38: a09200
#  39: n59660
#  40: a59660
#  41: prep

# %%
# !csvcut -c 1,2,3,7,9 zipcode06.csv > zipincome06.csv

# %%
# !csvcut -n zipcode07.csv
# Out:
#   1: state
#   2: ZIPCODE
#   3: agi_class
#   4: n1
#   5: mars2
#   6: prep
#   7: n2
#   8: numdep
#   9: a00100
#  10: n00200
#  11: a00200
#  12: n00300
#  13: a00300
#  14: n00600
#  15: a00600
#  16: n00900
#  17: a00900
#  18: schf
#  19: n23900
#  20: a23900
#  21: n01400
#  22: a01400
#  23: n01700
#  24: a01700
#  25: n02300
#  26: a02300
#  27: n02500
#  28: a02500
#  29: n03300
#  30: a03300
#  31: n04470
#  32: a04470
#  33: n18425
#  34: a18425
#  35: n18450
#  36: a18450
#  37: n18500
#  38: a18500
#  39: n18300
#  40: a18300
#  41: n19300
#  42: a19300
#  43: n19700
#  44: a19700
#  45: n04800
#  46: a04800
#  47: n07100
#  48: a07100
#  49: nf5695
#  50: af5695
#  51: n07220
#  52: a07220
#  53: n07180
#  54: a07180

# %%
# !csvcut -c 1,2,3,9,11 zipcode07.csv > zipincome07.csv

# %%
# !csvcut -n 08zpall.csv
# Out:
#   1: state
#   2: ZIPCODE
#   3: agi_class
#   4: n1
#   5: mars2
#   6: prep
#   7: n2
#   8: numdep
#   9: a00100
#  10: a00200
#  11: a00300
#  12: a00600
#  13: a00900
#  14: a23900
#  15: a01400
#  16: a01700
#  17: a02300
#  18: a02500
#  19: a03300
#  20: a04470
#  21: a18425
#  22: a18450
#  23: a18500
#  24: a18300
#  25: a19300
#  26: a19700
#  27: a04800
#  28: a07100
#  29: af5695
#  30: a07220
#  31: a07180
#  32: a59660
#  33: a59720
#  34: a09600
#  35: a06500
#  36: a10300
#  37: a11900gt0
#  38: a11900lt0

# %%
# !csvcut -c 1,2,3,9,11 08zpall.csv > zipincome08.csv

# %%
# !csvcut -n 09zpallagi.csv
# Out:
#   1: STATEFIPS
#   2: STATE
#   3: zipcode
#   4: agi_stub
#   5: N1
#   6: MARS2
#   7: PREP
#   8: N2
#   9: NUMDEP
#  10: A00100
#  11: N00200
#  12: A00200
#  13: N00300
#  14: A00300
#  15: N00600
#  16: A00600
#  17: N00650
#  18: A00650
#  19: N00900
#  20: A00900
#  21: SCHF
#  22: N01000
#  23: A01000
#  24: N01400
#  25: A01400
#  26: N01700
#  27: A01700
#  28: N02300
#  29: A02300
#  30: N02500
#  31: A02500
#  32: N03300
#  33: A03300
#  34: N04470
#  35: A04470
#  36: N18425
#  37: A18425
#  38: N18450
#  39: A18450
#  40: N18500
#  41: A18500
#  42: N18300
#  43: A18300
#  44: N19300
#  45: A19300
#  46: N19700
#  47: A19700
#  48: N04800
#  49: A04800
#  50: N07100
#  51: A07100
#  52: N07220
#  53: A07220
#  54: N07180
#  55: A07180
#  56: N07260
#  57: A07260
#  58: N59660
#  59: A59660
#  60: N59720
#  61: A59720
#  62: N11070
#  63: A11070
#  64: N09600
#  65: A09600
#  66: N06500
#  67: A06500
#  68: N10300
#  69: A10300
#  70: N11901
#  71: A11901
#  72: N11902
#  73: A11902

# %%
# !csvcut -c 2,3,4,10,12 09zpallagi.csv > zipincome09.csv

# %%
# !csvcut -n 10zpallagi.csv
# Out:
#   1: STATEFIPS
#   2: STATE
#   3: zipcode
#   4: agi_stub
#   5: N1
#   6: MARS2
#   7: PREP
#   8: N2
#   9: NUMDEP
#  10: A00100
#  11: N00200
#  12: A00200
#  13: N00300
#  14: A00300
#  15: N00600
#  16: A00600
#  17: N00650
#  18: A00650
#  19: N00900
#  20: A00900
#  21: SCHF
#  22: N01000
#  23: A01000
#  24: N01400
#  25: A01400
#  26: N01700
#  27: A01700
#  28: N02300
#  29: A02300
#  30: N02500
#  31: A02500
#  32: N03300
#  33: A03300
#  34: N04470
#  35: A04470
#  36: N18425
#  37: A18425
#  38: N18450
#  39: A18450
#  40: N18500
#  41: A18500
#  42: N18300
#  43: A18300
#  44: N19300
#  45: A19300
#  46: N19700
#  47: A19700
#  48: N04800
#  49: A04800
#  50: N07100
#  51: A07100
#  52: N07220
#  53: A07220
#  54: N07180
#  55: A07180
#  56: N07260
#  57: A07260
#  58: N59660
#  59: A59660
#  60: N59720
#  61: A59720
#  62: N11070
#  63: A11070
#  64: N09600
#  65: A09600
#  66: N06500
#  67: A06500
#  68: N10300
#  69: A10300
#  70: N11901
#  71: A11901
#  72: N11902
#  73: A11902

# %%
# !csvcut -c 2,3,4,10,12 10zpallagi.csv > zipincome10.csv

# %%
# !csvstat zipincome10.csv
# Out:
#   1. STATE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 51
# 	5 most frequent values:
# 		TX:	9744
# 		NY:	9288
# 		CA:	8922
# 		PA:	8220
# 		IL:	7380
# 	Max length: 2
#   2. zipcode
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 27787
# 	5 most frequent values:
# 		00000:	306
# 		33136:	6
# 		28170:	6
# 		68524:	6
# 		78418:	6
# 	Max length: 5
#   3. agi_stub
# 	<class 'int'>
# 	Nulls: False
# 	Min: 1
# 	Max: 6
# 	Sum: 584577
# 	Mean: 3.5
# 	Median: 3.5
# 	Standard Deviation: 1.707825127659933
# 	Unique values: 6
# 	5 most frequent values:
# 		6:	27837
# 		3:	27837
# 		2:	27837
# 		4:	27837
# 		1:	27837
#   4. A00100
# 	<class 'float'>
# 	Nulls: False
# 	Min: 0.0
# 	Max: 333873277.0
# 	Sum: 16069192552.126
# 	Mean: 96210.03551703368
# 	Median: 13141.5
# 	Standard Deviation: 1938347.0504983012
# 	Unique values: 73258
# 	5 most frequent values:
# 		0.0001:	21260
# 		0.0:	1432
# 		2995.0:	20
# 		4416.0:	18
# 		5150.0:	17
#   5. A00200
# 	<class 'float'>
# 	Nulls: False
# 	Min: 0.0
# 	Max: 190429362.0
# 	Sum: 11356585042.2569
# 	Mean: 67994.54588172157
# 	Median: 8914.0
# 	Standard Deviation: 1311928.7123288058
# 	Unique values: 64860
# 	5 most frequent values:
# 		0.0001:	22569
# 		0.0:	1432
# 		3133.0:	22
# 		3227.0:	22
# 		2878.0:	22
#
# Row count: 167022

# %%
# %%sql
# DROP TABLE IF EXISTS incomezip06;
# CREATE TABLE incomezip06 (
# STATE CHAR (8),
# ZIP CHAR(10),
# AGI_STUB INT,
# A00100 NUMERIC,
# A00200 VARCHAR(32)
# )
# Out:
# Done.
# Done.
# []

# %%
# !pwd
# Out:
# /Users/abhinavchandel/Desktop/FinalFolder

# %%
# %%sql
# COPY incomezip06 FROM '/Users/abhinavchandel/Desktop/FinalFolder/zipincome06.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 269603 rows affected.
# []

# %%
# %%sql
# ALTER TABLE incomezip06
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2006
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS incomezip07;
# CREATE TABLE incomezip07 (
# STATE CHAR (8),
# ZIP CHAR(10),
# AGI_STUB INT,
# A00100 NUMERIC,
# A00200 VARCHAR(32)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY incomezip07 FROM '/Users/abhinavchandel/Desktop/FinalFolder/zipincome07.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 232681 rows affected.
# []

# %%
# %%sql
# ALTER TABLE incomezip07
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2007
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS incomezip08;
# CREATE TABLE incomezip08 (
# STATE CHAR (8),
# ZIP CHAR(10),
# AGI_STUB INT,
# A00100 NUMERIC,
# A00200 VARCHAR(32)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY incomezip08 FROM '/Users/abhinavchandel/Desktop/FinalFolder/zipincome08.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 191284 rows affected.
# []

# %%
# %%sql
# ALTER TABLE incomezip08
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2008
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS incomezip09;
# CREATE TABLE incomezip09 (
# STATE CHAR (8),
# ZIP CHAR(10),
# AGI_STUB INT,
# A00100 NUMERIC,
# A00200 VARCHAR(32)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY incomezip09 FROM '/Users/abhinavchandel/Desktop/FinalFolder/zipincome09.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 167178 rows affected.
# []

# %%
# %%sql
# ALTER TABLE incomezip09
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2009
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS incomezip10;
# CREATE TABLE incomezip10 (
# STATE CHAR (8),
# ZIP CHAR(10),
# AGI_STUB INT,
# A00100 NUMERIC,
# A00200 VARCHAR(32)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY incomezip10 FROM '/Users/abhinavchandel/Desktop/FinalFolder/zipincome10.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 167022 rows affected.
# []

# %%
# %%sql
# ALTER TABLE incomezip10
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2010
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS incomezip;
# SELECT *
#     INTO incomezip
#     FROM (
#     SELECT * FROM incomezip07
#     UNION ALL
#     SELECT * FROM incomezip08
#     UNION ALL
#     SELECT * FROM incomezip09
#     UNION ALL
#     SELECT * FROM incomezip10
#     ) AS incomebyzip
# Out:
# Done.
# 758165 rows affected.
# []

# %%
# %%sql
# SELECT * FROM incomezip
# ORDER BY year DESC
# LIMIT 5
# Out:
# 5 rows affected.
# [('AL      ', '00000     ', 2, Decimal('17382840.000'), '14163028.000', 2010),
#  ('AL      ', '00000     ', 3, Decimal('15383011.000'), '12072207.000', 2010),
#  ('AL      ', '00000     ', 1, Decimal('11813654.000'), '9033252.0000', 2010),
#  ('AL      ', '00000     ', 5, Decimal('22173063.000'), '16811858.000', 2010),
#  ('AL      ', '00000     ', 4, Decimal('13175268.000'), '10270849.000', 2010)]

# %%
# %%sql
# DROP TABLE IF EXISTS location1_D;
# CREATE TABLE location1_D (
# state CHAR(8),
# zip CHAR(10)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO location1_D
# SELECT DISTINCT state,zip from incomezip;
# Out:
# 41019 rows affected.
# []

# %%
# %%sql
# ALTER TABLE location1_D
# ADD COLUMN location_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * from location_D LIMIT 10;
# Out:
# 10 rows affected.
# [('DuBois', 'PA', '15801-2549', 1),
#  ('Angola', 'IN', '46703-1764', 2),
#  ('Rochester', 'NY', '14620-2589', 3),
#  ('Denver', 'CO', '80247', 4),
#  ('Senatobia', 'MS', '38668-1714', 5),
#  ('Harlem', 'MT', '59526', 6),
#  ('Orlando', 'FL', '32804', 7),
#  ('Ludlow', 'MA', '01056', 8),
#  ('La Jolla', 'CA', '92037-1011', 9),
#  ('Charlotte', 'NC', '28204', 10)]

# %%
# %%sql
# DROP TABLE IF EXISTS income_level_D;
# CREATE TABLE income_level_D (
# level INT
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO income_level_D
# SELECT DISTINCT agi_stub from incomezip;
# Out:
# 8 rows affected.
# []

# %%
# %%sql
# ALTER TABLE income_level_D
# ADD COLUMN income_level_id SERIAL PRIMARY KEY;
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS income_fact;
# CREATE TABLE income_fact (
#     A00100 NUMERIC,
#     A00200 VARCHAR(32),
#     year_id INT,
#     location_id INT,
#     income_level_id INT,
#     FOREIGN KEY (year_id) REFERENCES year_D(year_id),
#     FOREIGN KEY (location_id) REFERENCES location1_D(location_id),
#     FOREIGN KEY (income_level_id) REFERENCES income_level_D(income_level_id)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO income_fact
# SELECT incomezip.A00100,incomezip.A00200,year_D.year_id,location1_D.location_id,income_level_D.income_level_id
# FROM incomezip
# JOIN
# year_D
# ON incomezip.year=year_D.year
# JOIN
# location1_D
# ON
# incomezip.state=location1_D.state
# AND incomezip.zip=location1_D.zip
# JOIN
# income_level_D
# ON
# incomezip.agi_stub=income_level_D.level
# Out:
# 758164 rows affected.
# []

# %%
# %%sql
# select * from  location_d;
# Out:
# 6602 rows affected.
# [('DuBois', 'PA', '15801-2549', 1),
#  ('Angola', 'IN', '46703-1764', 2),
#  ('Rochester', 'NY', '14620-2589', 3),
#  ('Denver', 'CO', '80247', 4),
#  ('Senatobia', 'MS', '38668-1714', 5),
#  ('Harlem', 'MT', '59526', 6),
#  ('Orlando', 'FL', '32804', 7),
#  ('Ludlow', 'MA', '01056', 8),
#  ('La Jolla', 'CA', '92037-1011', 9),
#  ('Charlotte', 'NC', '28204', 10),
#  ('Spring Arbor', 'MI', '49283-9799', 11),
#  ('Skokie', 'IL', '60077-1074', 12),
#  ('Memphis', 'TN', '38133', 13),
#  ('Columbia', 'SC', '29204', 14),
#  ('Reno', 'NV', '89502', 15),
#  ('Plymouth', 'MN', '55446', 16),
#  ('Nashville', 'TN', '37210', 17),
#  ('Billings', 'MT', '59101', 18),
#  ('West Monroe', 'LA', '71291', 19),
#  ('Birmingham', 'AL', '35294-0110', 20),
#  ('San Juan', 'PR', '00936-5067', 21),
#  ('Castleton', 'VT', '05735', 22),
#  ('Lynchburg', 'VA', '24502', 23),
#  ('Seaside', 'CA', '93955-8001', 24),
#  ('Koror', 'PW', '96940', 25),
#  ('Milwaukee', 'WI', '53207', 26),
#  ('West Melbourne', 'FL', '32904', 27),
#  ('Anaheim', 'CA', '92801', 28),
#  ('Malden', 'MA', '02148-8143', 29),
#  ('Fort Lauderdale', 'FL', '33309-9731', 30),
#  ('Wooster', 'OH', '44691-4000', 31),
#  ('Ponce', 'PR', '00731', 32),
#  ('Epworth', 'IA', '52045', 33),
#  ('Turlock', 'CA', '95382-0299', 34),
#  ('Carthage', 'MS', '39050-4423', 35),
#  ('Bloomington', 'MN', '554355444', 36),
#  ('Hayward', 'CA', '94545', 37),
#  ('Knoxville', 'TN', '37917-6312', 38),
#  ('Corpus Christi', 'TX', '78412', 39),
#  ('Visalia', 'CA', '93277-2214', 40),
#  ('Cass Lake', 'MN', '56633', 41),
#  ('Green Bay', 'WI', '54303-2349', 42),
#  ('Seattle', 'WA', '98168-2610', 43),
#  ('Montgomery', 'WV', '25136', 44),
#  ('Virginia Beach', 'VA', '23456-2499', 45),
#  ('Victoria', 'TX', '77901', 46),
#  ('McAllen', 'TX', '78501', 47),
#  ('Sandy', 'UT', '84070-2004', 48),
#  ('Flint', 'MI', '48507', 49),
#  ('Shelby', 'NC', '28152-6224', 50),
#  ('Jeffersonville', 'IN', '47130', 51),
#  ('Bemidji', 'MN', '56601', 52),
#  ('Tulsa', 'OK', '74104-3189', 53),
#  ('Idabel', 'OK', '74745', 54),
#  ('Fort Wayne', 'IN', '46835', 55),
#  ('Raleigh', 'NC', '27604-1194', 56),
#  ('Chicago', 'IL', '60601-3608', 57),
#  ('Green', 'OH', '44232-0248', 58),
#  ('Hinton', 'WV', '25951', 59),
#  ('Jacksonville', 'FL', '32225', 60),
#  ('Monticello', 'AR', '71656', 61),
#  ('Arkadelphia', 'AR', '71999-0001', 62),
#  ('Columbus', 'OH', '43240', 63),
#  ('Rapid City', 'SD', '57701-2823', 64),
#  ('Eau Claire', 'WI', '54701-7633', 65),
#  ('Tempe', 'AZ', '85282-1707', 66),
#  ('Newport Beach', 'CA', '92660', 67),
#  ('Corpus Christi', 'TX', '78416', 68),
#  ('Hagerstown', 'MD', '21742-6514', 69),
#  ('Independence', 'MO', '64055', 70),
#  ('Jackson', 'MS', '39206', 71),
#  ('Forrest City', 'AR', '72335-2204', 72),
#  ('Lancaster', 'CA', '93534', 73),
#  ('Portland', 'OR', '97209-2911', 74),
#  ('Milwaukee', 'WI', '53201-0413', 75),
#  ('Traverse City', 'MI', '49686', 76),
#  ('Franklin', 'VA', '23851', 77),
#  ('Seattle', 'WA', '98109', 78),
#  ('Horn Lake', 'MS', '38637', 79),
#  ('Wheaton', 'IL', '60187-5593', 80),
#  ('San Jose', 'CA', '95127-3823', 81),
#  ('Winter Haven', 'FL', '33881-4299', 82),
#  ('El Paso', 'TX', '79927', 83),
#  ('Cleveland', 'OH', '44102', 84),
#  ('Ashwaubenon', 'WI', '54304-4838', 85),
#  ('Northfield', 'MN', '55057-4001', 86),
#  ('Branchburg', 'NJ', '08876', 87),
#  ('New Orleans', 'LA', '70125-1098', 88),
#  ('Cheyenne', 'WY', '82009-6112', 89),
#  ('Fremont', 'CA', '94539', 90),
#  ('Seattle', 'WA', '98106-1499', 91),
#  ('Cincinnati', 'OH', '45202', 92),
#  ('McLean', 'VA', '22102', 93),
#  ('New Paltz', 'NY', '12561-2443', 94),
#  ('Mississippi State', 'MS', '39762', 95),
#  ('Oakdale', 'NY', '11769-1999', 96),
#  ('Montgomery', 'AL', '36117-2800', 97),
#  ('Fergus Falls', 'MN', '56537-1000', 98),
#  ('Marshall', 'TX', '75670', 99),
#  ('Gurabo', 'PR', '00778', 100),
#  ('Belmont', 'NC', '28012-1802', 101),
#  ('Clovis', 'CA', '93611', 102),
#  ('Gaithersburg', 'MD', '20877-1414', 103),
#  ('Honolulu', 'HI', '96813-2811', 104),
#  ('New York', 'NY', '10021-4597', 105),
#  ('Los Angeles', 'CA', '900175418', 106),
#  ('Lakewood', 'OH', '44107', 107),
#  ('Glen Cove', 'NY', '11542-1398', 108),
#  ('Salem', 'OR', '97301-1952', 109),
#  ('Abilene', 'TX', '79697', 110),
#  ('San Jose', 'CA', '95134-1805', 111),
#  ('Cleveland', 'TN', '37312', 112),
#  ('Oxford', 'OH', '45056', 113),
#  ('Wyomissing', 'PA', '19610-1168', 114),
#  ('Clarion', 'PA', '16214', 115),
#  ('Reynoldsville', 'PA', '15851', 116),
#  ('Pittsburgh', 'PA', '15237-5898', 117),
#  ('Hot Springs', 'AR', '71901', 118),
#  ('Teterboro', 'NJ', '07608-1083', 119),
#  ('Oregon', 'OH', '43616', 120),
#  ('Greenfield', 'WI', '53228', 121),
#  ('Saint Paul', 'MN', '55119-7003', 122),
#  ('Columbus', 'OH', '43213', 123),
#  ('Miami', 'FL', '33142', 124),
#  ('Colorado Springs', 'CO', '80919', 125),
#  ('Westland', 'MI', '48185', 126),
#  ('New Ulm', 'MN', '56073-3965', 127),
#  ('Miramar', 'FL', '33027-3209', 128),
#  ('Boston', 'MA', '02129-2925', 129),
#  ('Belleville', 'IL', '62226', 130),
#  ('Spiro', 'OK', '74959', 131),
#  ('Terre Haute', 'IN', '47802-4898', 132),
#  ('Bakersfield', 'CA', '93309-7018', 133),
#  ('Santa Ana', 'CA', '92705-5479', 134),
#  ('Clyde', 'NC', '28721-9901', 135),
#  ('Boardman', 'OH', '44512', 136),
#  ('Council Bluffs', 'IA', '51503-5289', 137),
#  ('Towson', 'MD', '21252-0001', 138),
#  ('Lauderhill', 'FL', '33313', 139),
#  ('Wilmington', 'DE', '19805-1511', 140),
#  ('Stone Ridge', 'NY', '12484', 141),
#  ('San Bernardino', 'CA', '92408', 142),
#  ('Mitchell', 'SD', '57301', 143),
#  ('Tulsa', 'OK', '74133', 144),
#  ('Pottstown', 'PA', '19464-5437', 145),
#  ('Anaheim', 'CA', '92804', 146),
#  ('Kansas City', 'MO', '64136', 147),
#  ('Harriman', 'TN', '37748-5849', 148),
#  ('Throggs Neck', 'NY', '10465-4198', 149),
#  ('Los Angeles', 'CA', '90089', 150),
#  ('Ansonia', 'CT', '06401', 151),
#  ('Hibbing', 'MN', '55746', 152),
#  ('Lexington', 'KY', '40503', 153),
#  ('Austin', 'TX', '78758', 154),
#  ('Portsmouth', 'NH', '03801-2879', 155),
#  ('Lamar', 'CO', '81052-3999', 156),
#  ('Royal Palm Beach', 'FL', '33411', 157),
#  ('Kansas City', 'KS', '66112', 158),
#  ('Atlanta', 'GA', '30322', 159),
#  ('Murray', 'KY', '42071-2530', 160),
#  ('Hollywood', 'CA', '90038', 161),
#  ('Amityville', 'NY', '11701-2704', 162),
#  ('Wilson', 'NC', '27893', 163),
#  ('Mount Berry', 'GA', '30149', 164),
#  ('Poplar', 'MT', '59255-0398', 165),
#  ('Syracuse', 'NY', '13215-4585', 166),
#  ('Honolulu', 'HI', '96816-4421', 167),
#  ('Riverside', 'CA', '92505', 168),
#  ('Baltimore', 'MD', '21210-1994', 169),
#  ('Salem', 'OH', '44460-2906', 170),
#  ('Sparks', 'NV', '89431', 171),
#  ('Jacksonville', 'NC', '28546-6816', 172),
#  ('Tulsa', 'OK', '74146-3801', 173),
#  ('Saint Bonifacius', 'MN', '55375-9001', 174),
#  ('Jacksonville', 'AR', '72076', 175),
#  ('Norfolk', 'VA', '23510', 176),
#  ('Oakland', 'CA', '94609-2419', 177),
#  ('New York', 'NY', '10014', 178),
#  ('Hamlet', 'NC', '28345-1189', 179),
#  ('Galesburg', 'IL', '61401', 180),
#  ('Ankeny', 'IA', '50023-2152', 181),
#  ('Forest Hills', 'NY', '11375', 182),
#  ('El Centro', 'CA', '92243', 183),
#  ('El Paso', 'TX', '79935', 184),
#  ('Silver  Spring', 'MD', '20902', 185),
#  ('Lincoln', 'IL', '62656', 186),
#  ('Pinellas Park', 'FL', '33781', 187),
#  ('Mays Landing', 'NJ', '08330-2699', 188),
#  ('Saint Clairsville', 'OH', '43950', 189),
#  ('West  Palm Beach', 'FL', '33409', 190),
#  ('San Diego', 'CA', '92115-3919', 191),
#  ('Orlando', 'FL', '32816', 192),
#  ('Los Angeles', 'CA', '90015-4001', 193),
#  ('San Jose', 'CA', '95128-2798', 194),
#  ('Spartanburg', 'SC', '29303', 195),
#  ('Goodman', 'MS', '39079', 196),
#  ('Sparkill', 'NY', '10976-1050', 197),
#  ('Greenfield', 'MA', '01301-9739', 198),
#  ('New York', 'NY', '10036-8003', 199),
#  ('Houston', 'TX', '77074-6010', 200),
#  ('Chambersburg', 'PA', '17202', 201),
#  ('Wauwatosa', 'WI', '53226', 202),
#  ('Dubuque', 'IA', '52001', 203),
#  ('Fishersville', 'VA', '22939-1500', 204),
#  ('Ferndale', 'MI', '48220', 205),
#  ('Glendale', 'WI', '53217', 206),
#  ('Ontario', 'CA', '91764', 207),
#  ('Houston', 'TX', '77064', 208),
#  ('Hialeah', 'FL', '330122478', 209),
#  ('San Francisco', 'CA', '94105', 210),
#  ('Claremont', 'CA', '91711-6101', 211),
#  ('Gold River', 'CA', '95670-4443', 212),
#  ('Kansas City', 'MO', '64131', 213),
#  ('Glenwood Springs', 'CO', '81601', 214),
#  ('Rockville Centre', 'NY', '11571-5002', 215),
#  ('Cincinnati', 'OH', '45221-0063', 216),
#  ('Juana Diaz', 'PR', '00795', 217),
#  ('Dallas', 'TX', '75202-3604', 218),
#  ('Miami', 'FL', '33156', 219),
#  ('Hawthorne', 'NJ', '07506', 220),
#  ('Goldsboro', 'NC', '27534-8002', 221),
#  ('CHESTER', 'VA', '23836', 222),
#  ('Irving', 'TX', '75038-3899', 223),
#  ('Donaldson', 'IN', '46513-0001', 224),
#  ('Cranford', 'NJ', '07016-1599', 225),
#  ('Indianapolis', 'IN', '46250-1932', 226),
#  ('Cushing', 'OK', '74023', 227),
#  ('Chicago', 'IL', '60617-4303', 228),
#  ('New Bedford', 'MA', '02740', 229),
#  ('East Windsor', 'CT', '06088', 230),
#  ('White Bear Lake', 'MN', '55110', 231),
#  ('Center Valley', 'PA', '18034-9568', 232),
#  ('Davenport', 'IA', '52803-5287', 233),
#  ('Martinez', 'GA', '30907', 234),
#  ('Urbana', 'IL', '61801', 235),
#  ('Poughkeepsie', 'NY', '12601', 236),
#  ('Aguada', 'PR', '00602', 237),
#  ('Nampa', 'ID', '83651', 238),
#  ('Houston', 'TX', '77074', 239),
#  ('Aurora', 'IL', '60504', 240),
#  ('Pittsburgh', 'PA', '15276', 241),
#  ('Atherton', 'CA', '94027-4301', 242),
#  ('Philadelphia', 'PA', '19131-1395', 243),
#  ('Torrance', 'CA', '90501', 244),
#  ('Visalia', 'CA', '93291-9283', 245),
#  ('Boston', 'MA', '02115-5005', 246),
#  ('Waukesha', 'WI', '53186-4047', 247),
#  ('Presque Isle', 'ME', '04769-2016', 248),
#  ('San Antonio', 'TX', '78212-7200', 249),
#  ('Bayamon', 'PR', '00960-6032', 250),
#  ('Lebanon', 'PA', '170425235', 251),
#  ('Cincinnati', 'OH', '45237-3839', 252),
#  ('Augusta', 'GA', '30909-4583', 253),
#  ('Lafayette', 'IN', '47905', 254),
#  ('New Carrollton', 'MD', '20784', 255),
#  ('Virginia Beach', 'VA', '23451', 256),
#  ('Mahwah', 'NJ', '07430-1680', 257),
#  ('San Jose', 'CA', '95113', 258),
#  ('Clearwater', 'FL', '33761', 259),
#  ('Long Beach', 'CA', '90840-0115', 260),
#  ('Charleston', 'SC', '29420', 261),
#  ('Laie', 'HI', '96762-1294', 262),
#  ('Willowbrook', 'IL', '60527', 263),
#  ('Troy', 'MI', '48098-2623', 264),
#  ('Salinas', 'CA', '93906', 265),
#  ('Altoona', 'PA', '16601-3777', 266),
#  ('Canyon Country', 'CA', '91351', 267),
#  ('Bryan', 'TX', '77803', 268),
#  ('Charleston', 'SC', '29409', 269),
#  ('Stratford', 'CT', '06615', 270),
#  ('Wichita', 'KS', '67212', 271),
#  ('Spartanburg', 'SC', '29302-0006', 272),
#  ('Chattanooga', 'TN', '37415', 273),
#  ('Enfield', 'CT', '060821400', 274),
#  ('Brooklyn', 'NY', '11201-8423', 275),
#  ('Blaine', 'MN', '550148624', 276),
#  ('Santa Ana', 'CA', '92701-0000', 277),
#  ('Fort Lauderdale', 'FL', '33314-7796', 278),
#  ('Mountain Home', 'AR', '72653-3164', 279),
#  ('Washington', 'PA', '15301-6822', 280),
#  ('Decatur', 'GA', '30030-2198', 281),
#  ('Muncie', 'IN', '47303', 282),
#  ('Minneapolis', 'MN', '55403-1192', 283),
#  ('El Dorado', 'AR', '71731-7010', 284),
#  ('San Diego', 'CA', '92154', 285),
#  ('Akron', 'OH', '44308-1979', 286),
#  ('Jacksonville', 'TX', '75766-4759', 287),
#  ('Kenosha', 'WI', '53140-1994', 288),
#  ('Macon', 'GA', '31206', 289),
#  ('Fresno', 'CA', '93720-1562', 290),
#  ('Batavia', 'OH', '45103', 291),
#  ('Huntington Beach', 'CA', '92646', 292),
#  ('Pippa Passes', 'KY', '41844', 293),
#  ('Bridgeview', 'IL', '60455', 294),
#  ('Falls Church', 'VA', '22042', 295),
#  ('Seattle', 'WA', '98195-4550', 296),
#  ('Cordova', 'TN', '38016', 297),
#  ('Sikeston', 'MO', '63801-3347', 298),
#  ('New York', 'NY', '10011-7307', 299),
#  ('Clarks Summit', 'PA', '18411-1250', 300),
#  ('Canton', 'OH', '44709-3308', 301),
#  ('Oakland City', 'IN', '47660-1099', 302),
#  ('Elizabeth City', 'NC', '27909', 303),
#  ('San Marcos', 'CA', '92078', 304),
#  ('Beaverton', 'OR', '97005', 305),
#  ('Chattanooga', 'TN', '37421', 306),
#  ('Greenfield', 'WI', '53220-4612', 307),
#  ('Grenada', 'MS', '38901', 308),
#  ('La Salle', 'IL', '61301', 309),
#  ('Pablo', 'MT', '59855', 310),
#  ('Lexington', 'VA', '24450-0304', 311),
#  ('Taft', 'CA', '93268', 312),
#  ('Richmond', 'VA', '23235-5250', 313),
#  ('Albany', 'GA', '31705', 314),
#  ('Brookline', 'MA', '02445', 315),
#  ('West Valley City', 'UT', '84120', 316),
#  ('McAlester', 'OK', '74501', 317),
#  ('Warren', 'OH', '44483', 318),
#  ('Southfield', 'MI', '48076', 319),
#  ('Marion', 'AL', '36756-3207', 320),
#  ('Parsippany', 'NJ', '07054-3897', 321),
#  ('Paterson', 'NJ', '07505-1179', 322),
#  ('Memphis', 'TN', '38126-6595', 323),
#  ('Waterloo', 'IA', '50703-1999', 324),
#  ('Springfield', 'IL', '62707', 325),
#  ('Delhi', 'NY', '13753-1100', 326),
#  ('Salisbury', 'NC', '28144', 327),
#  ('Southlake', 'TX', '76092', 328),
#  ('Wheaton', 'MD', '20902', 329),
#  ('Manchester', 'NH', '03101', 330),
#  ('Allentown', 'PA', '18109-1629', 331),
#  ('Hannibal', 'MO', '63401-2285', 332),
#  ('West Memphis', 'AR', '72301-3829', 333),
#  ('Parsons', 'KS', '67357-4201', 334),
#  ('Lumberton', 'NC', '28360', 335),
#  ('Sumter', 'SC', '29150-2498', 336),
#  ('Vancouver', 'WA', '98684', 337),
#  ('Boca Raton', 'FL', '33431-0991', 338),
#  ('Kent', 'OH', '44240', 339),
#  ('Harlingen', 'TX', '78550-3697', 340),
#  ('Warner', 'NH', '03278-4012', 341),
#  ('Las Vegas', 'NV', '89154', 342),
#  ('Allentown', 'PA', '18101-1604', 343),
#  ('Skokie', 'IL', '60076', 344),
#  ('Saint George', 'UT', '84770', 345),
#  ('Saint Paul', 'MN', '55104-3435', 346),
#  ('York', 'PA', '17402-4696', 347),
#  ('Rio Grande', 'OH', '45674-0157', 348),
#  ('Springfield', 'MO', '65804', 349),
#  ('Greensburg', 'PA', '15601', 350),
#  ('Allentown', 'PA', '18109', 351),
#  ('Guaynabo', 'PR', '00968-3028', 352),
#  ('Atlanta', 'GA', '30328-1635', 353),
#  ('Kirksville', 'MO', '63501', 354),
#  ('Utica', 'NY', '13503-0479', 355),
#  ('Bellingham', 'WA', '98226', 356),
#  ('Montevallo', 'AL', '35115-6000', 357),
#  ('Arecibo', 'PR', '00614-4045', 358),
#  ('Rockford', 'IL', '61108-2513', 359),
#  ('Kansas City', 'MO', '64145-1698', 360),
#  ('Lehi', 'UT', '84043', 361),
#  ('Blacksburg', 'VA', '24061-0131', 362),
#  ('Madisonville', 'TN', '37354-4001', 363),
#  ('Alameda', 'CA', '94501', 364),
#  ('White Plains', 'NY', '10601', 365),
#  ('Lancaster', 'OH', '43130-1037', 366),
#  ('Victoria', 'TX', '77901-6233', 367),
#  ('Savannah', 'GA', '31405-5594', 368),
#  ('Los Angeles', 'CA', '90045-3505', 369),
#  ('Garden Grove', 'CA', '92840-9201', 370),
#  ('Fulton', 'MO', '65251-1299', 371),
#  ('Nanuet', 'NY', '10954', 372),
#  ('Latham', 'NY', '12110', 373),
#  ('Bottineau', 'ND', '58318-1198', 374),
#  ('Atlanta', 'GA', '30318', 375),
#  ('Goodwell', 'OK', '73939-0430', 376),
#  ('Menomonie', 'WI', '54751', 377),
#  ('Falmouth', 'MA', '02540-2958', 378),
#  ('Jasper', 'GA', '30143-1253', 379),
#  ('Houston', 'TX', '77004-2930', 380),
#  ('Richfield', 'UT', '84701', 381),
#  ('Los Angeles', 'CA', '90066', 382),
#  ('Norfolk', 'VA', '23502-4101', 383),
#  ('Vista', 'CA', '92083-7736', 384),
#  ('Arlington', 'TX', '76013', 385),
#  ('Newark', 'OH', '43055', 386),
#  ('Gladstone', 'MO', '64118', 387),
#  ('Moorestown', 'NJ', '08057', 388),
#  ('Los Angeles', 'CA', '90041-3392', 389),
#  ('Prestonburg', 'KY', '41653', 390),
#  ('Maitland', 'FL', '32751-7001', 391),
#  ('Fitchburg', 'MA', '01420', 392),
#  ('Hazle Township', 'PA', '18202', 393),
#  ('Billerica', 'MA', '01821-5499', 394),
#  ('Chicago', 'IL', '60601', 395),
#  ('Bel Air', 'MD', '21015-1698', 396),
#  ('Rockford', 'IL', '61108-2311', 397),
#  ('Miami', 'FL', '33133-2703', 398),
#  ('Waterbury', 'CT', '06706', 399),
#  ('Bountiful', 'UT', '84010', 400),
#  ('Alexandria', 'VA', '22314', 401),
#  ('Somersworth', 'NH', '03878', 402),
#  ('Winooski', 'VT', '05404-2245', 403),
#  ('Tucson', 'AZ', '85716', 404),
#  ('Grand Rapids', 'MI', '49525', 405),
#  ('Fairfield', 'CA', '94534-3197', 406),
#  ('Saint Joseph', 'MO', '64506-5102', 407),
#  ('Deerfield Beach', 'FL', '33441', 408),
#  ('Portland', 'OR', '97225', 409),
#  ('Indianapolis', 'IN', '46227', 410),
#  ('Scottsdale', 'AZ', '85251-2729', 411),
#  ('Whittier', 'CA', '90601-1616', 412),
#  ('Aurora', 'CO', '80011-9036', 413),
#  ('Statesboro', 'GA', '30460-8126', 414),
#  ('Arlington', 'TX', '76010', 415),
#  ('Spirit Lake', 'IA', '51360', 416),
#  ('Los Angeles', 'CA', '90045-2659', 417),
#  ('Winnsboro', 'LA', '71295', 418),
#  ('Jeffersonville', 'IN', '47130-4215', 419),
#  ('East Liverpool', 'OH', '43920-9585', 420),
#  ('Lancaster', 'PA', '17604-3003', 421),
#  ('Schuylkill Haven', 'PA', '17972-2202', 422),
#  ('Worcester', 'MA', '01609', 423),
#  ('Las Vegas', 'NV', '89128-4340', 424),
#  ('Storm Lake', 'IA', '50588', 425),
#  ('Woodland Hills', 'CA', '91367', 426),
#  ('Lincoln', 'NE', '68506', 427),
#  ('Eugene', 'OR', '97405', 428),
#  ('North Adams', 'MA', '01247-4100', 429),
#  ('Oxnard', 'CA', '93033-6699', 430),
#  ('Keokuk', 'IA', '52632', 431),
#  ('McKeesport', 'PA', '15132-7644', 432),
#  ('Mequon', 'WI', '53097-2402', 433),
#  ('Waukesha', 'WI', '53186-0000', 434),
#  ('Elkhart', 'IN', '46516', 435),
#  ('Baton Rouge', 'LA', '70816-2246', 436),
#  ('Lakeland', 'FL', '33805', 437),
#  ('Bedford', 'MA', '01730', 438),
#  ('Hayward', 'CA', '94541', 439),
#  ('Arroyo', 'PR', '00714-0270', 440),
#  ('Milwaukee', 'WI', '53233-1443', 441),
#  ('Oakland', 'CA', '94612', 442),
#  ('Graham', 'NC', '27253-8000', 443),
#  ('Colorado Springs', 'CO', '80909', 444),
#  ('Bridgeport', 'WV', '26330', 445),
#  ('Trevose', 'PA', '19053-6939', 446),
#  ('Ullin', 'IL', '62992', 447),
#  ('Saint Paul', 'MN', '55113-1598', 448),
#  ('San Antonio', 'TX', '78230-1736', 449),
#  ('Pine City', 'MN', '55063', 450),
#  ('Kansas City', 'MO', '64111-2429', 451),
#  ('Irvine', 'CA', '92618-0301', 452),
#  ('Canton', 'OH', '44705', 453),
#  ('Fairfax', 'VA', '22031', 454),
#  ('Douglas', 'GA', '31533-5098', 455),
#  ('Coolidge', 'AZ', '85128-9030', 456),
#  ('Orland Park', 'IL', '60467', 457),
#  ('Westminster', 'CO', '80234-2010', 458),
#  ('Denver', 'CO', '80246', 459),
#  ('Johnson City', 'TN', '37601-9989', 460),
#  ('Humacao', 'PR', '00791', 461),
#  ('Memphis', 'TN', '38107', 462),
#  ('Mansfield', 'PA', '16933', 463),
#  ('Wichita', 'KS', '67226-4011', 464),
#  ('Farmington', 'ME', '04938-9978', 465),
#  ('Las Cruces', 'NM', '88011', 466),
#  ('East Moline', 'IL', '61244', 467),
#  ('Redlands', 'CA', '92374', 468),
#  ('Providence', 'RI', '02918-0001', 469),
#  ('North Wales', 'PA', '19454-4114', 470),
#  ('Coamo', 'PR', '00769', 471),
#  ('Frankfort', 'KY', '40601-2355', 472),
#  ('Tacoma', 'WA', '98402-3100', 473),
#  ('Port Angeles', 'WA', '98362', 474),
#  ('Plymouth Meeting', 'PA', '19462', 475),
#  ('Blaine', 'MN', '55449', 476),
#  ('Hancock', 'MI', '49930-1832', 477),
#  ('Wyncote', 'PA', '19095-1898', 478),
#  ('Lubbock', 'TX', '79414', 479),
#  ('Bethpage', 'NY', '11714-3545', 480),
#  ('Cleveland', 'TN', '37320-3330', 481),
#  ('Tarzana', 'CA', '91356-4159', 482),
#  ('Cleveland', 'TN', '37312-3862', 483),
#  ('Cape Girardeau', 'MO', '63703-0000', 484),
#  ('Houston', 'TX', '77004', 485),
#  ('Columbia', 'MD', '21044-3197', 486),
#  ('St. Louis', 'MO', '63122', 487),
#  ('Memphis', 'TN', '38111-1375', 488),
#  ('Ithaca', 'NY', '14853', 489),
#  ('San Antonio', 'TX', '78249-1644', 490),
#  ('Newport News', 'VA', '23606-3072', 491),
#  ('San Diego', 'CA', '92106-2899', 492),
#  ('Manchester', 'NH', '03101-1113', 493),
#  ('Tampa', 'FL', '33606-3584', 494),
#  ('Baton Rouge', 'LA', '70813', 495),
#  ('Mansfield', 'OH', '44905', 496),
#  ("St. Mary's City", 'MD', '20686-3001', 497),
#  ('Phenix City', 'AL', '368694419', 498),
#  ('Buffalo', 'NY', '14225-3999', 499),
#  ('West Barnstable', 'MA', '02668-1599', 500),
#  ('Kalamazoo', 'MI', '49008-5200', 501),
#  ('Swannanoa', 'NC', '28778-2099', 502),
#  ('Staunton', 'VA', '24401', 503),
#  ('Mission Viejo', 'CA', '92692-3635', 504),
#  ('Beaumont', 'CA', '92223', 505),
#  ('Santa Monica', 'CA', '90407-2138', 506),
#  ('Oakland', 'CA', '94609', 507),
#  ('Victorville', 'CA', '92395', 508),
#  ('Monmouth', 'IL', '61462-1998', 509),
#  ('Brooklyn', 'NY', '11204-1545', 510),
#  ('Wethersfield', 'CT', '06109', 511),
#  ('Chandler', 'AZ', '85224', 512),
#  ('Phoenix', 'AZ', '85006', 513),
#  ('Westerville', 'OH', '43081', 514),
#  ('Cutler Bay', 'FL', '33157', 515),
#  ('High Point', 'NC', '27265', 516),
#  ('Nashville', 'TN', '37212-3757', 517),
#  ('Grand Prairie', 'TX', '75051-4892', 518),
#  ('San Pedro', 'CA', '90731', 519),
#  ('Beaver Falls', 'PA', '15010-3599', 520),
#  ('Albany', 'KY', '42602', 521),
#  ('Carolina', 'PR', '00982', 522),
#  ('Grants', 'NM', '87020-2025', 523),
#  ('Concord', 'CA', '94520', 524),
#  ('Jacksonville', 'FL', '32205', 525),
#  ('Fort Collins', 'CO', '80528', 526),
#  ('Hornell', 'NY', '14843-2197', 527),
#  ('Niles', 'OH', '44446-4398', 528),
#  ('Wheeling', 'IL', '60090-2646', 529),
#  ('Chicago', 'IL', '60628-1598', 530),
#  ('Whitehall', 'PA', '18052', 531),
#  ('Akron', 'OH', '44333', 532),
#  ('Monroeville', 'AL', '36460', 533),
#  ('Bradenton', 'FL', '34203', 534),
#  ('Monroe', 'MI', '48161-9746', 535),
#  ('Johnston', 'IA', '50131', 536),
#  ('Lynchburg', 'VA', '24502-2652', 537),
#  ('Lorain', 'OH', '44052-1803', 538),
#  ('Los Alamos', 'NM', '87544', 539),
#  ('Manitowoc', 'WI', '54220-9319', 540),
#  ('Vancouver', 'WA', '98661-4323', 541),
#  ('El Paso', 'TX', '799221354', 542),
#  ('Rio Grande', 'PR', '00745-0000', 543),
#  ('Myrtle Beach', 'SC', '29579', 544),
#  ('Danbury', 'CT', '06810-6826', 545),
#  ('ERIAL', 'NJ', '08081', 546),
#  ('Livonia', 'MI', '481529069', 547),
#  ('Upper Darby', 'PA', '19082', 548),
#  ('Vermillion', 'SD', '57069-2390', 549),
#  ('Spokane', 'WA', '99217-5399', 550),
#  ('Kansas City', 'MO', '64117', 551),
#  ('Mount Hope', 'WV', '25880', 552),
#  ('Ocean Springs', 'MS', '39564', 553),
#  ('Alton', 'IL', '62002', 554),
#  ('Canton', 'NY', '13617', 555),
#  ('Bel Air', 'MD', '21014-3639', 556),
#  ('Vancouver', 'WA', '98663-3598', 557),
#  ('San Jose', 'CA', '95131', 558),
#  ('Waterbury', 'CT', '06723', 559),
#  ('Irving', 'TX', '75061', 560),
#  ('Cleveland', 'OH', '44106-1776', 561),
#  ('Geneva', 'NY', '14456-1651', 562),
#  ('Claremore', 'OK', '74017', 563),
#  ('Bozeman', 'MT', '59717', 564),
#  ('New York', 'NY', '10025', 565),
#  ('Cambridge', 'MA', '02138-3495', 566),
#  ('Miami', 'FL', '33133', 567),
#  ('El Cajon', 'CA', '92020-3057', 568),
#  ('West Chester', 'OH', '45069-4874', 569),
#  ('West Lebanon', 'NH', '03784', 570),
#  ('University', 'MS', '38677-1848', 571),
#  ('Newberry', 'SC', '29108', 572),
#  ('Buena Vista', 'VA', '24416', 573),
#  ('Pago Pago', 'AS', '96799-2609', 574),
#  ('San Bernardino', 'CA', '92408-2800', 575),
#  ('Henrico', 'VA', '23228', 576),
#  ('Piqua', 'OH', '45356', 577),
#  ('Marion', 'OH', '43302-5694', 578),
#  ('Milford', 'CT', '06461', 579),
#  ('Bayamon', 'PR', '00959', 580),
#  ('Mooresville', 'NC', '28115', 581),
#  ('Newton', 'MA', '02466', 582),
#  ('Lancaster', 'PA', '17608-0059', 583),
#  ('Plainfield', 'NJ', '07060', 584),
#  ('Palos Heights', 'IL', '60463-0929', 585),
#  ('Salem', 'MA', '01970', 586),
#  ('Jefferson City', 'MO', '65109', 587),
#  ('Pinehurst', 'NC', '28374', 588),
#  ('Columbus', 'OH', '43235-1499', 589),
#  ('Henderson', 'TN', '38340-2399', 590),
#  ('Ipswich', 'MA', '01938', 591),
#  ('Eagan', 'MN', '55121-1696', 592),
#  ('Los Angeles', 'CA', '90047', 593),
#  ('Allendale', 'MI', '49401-9403', 594),
#  ('Portland', 'OR', '97205-2793', 595),
#  ('Beverly Hills', 'CA', '90211', 596),
#  ('Roanoke', 'VA', '24015', 597),
#  ('Eureka', 'IL', '61530', 598),
#  ('Gloucester', 'NJ', '08030', 599),
#  ('Fort Smith', 'AR', '72913-3649', 600),
#  ('Warner Robins', 'GA', '31093-3631', 601),
#  ('Torrance', 'CA', '90502', 602),
#  ('Hartsville', 'TN', '37074-2028', 603),
#  ('Washington', 'NC', '27889', 604),
#  ('Manchester', 'NH', '03106-1045', 605),
#  ('Upland', 'CA', '91786-7148', 606),
#  ('Davie', 'FL', '33317', 607),
#  ('Weatherford', 'OK', '73096-3098', 608),
#  ('Claremore', 'OK', '74017-3252', 609),
#  ('Chicago', 'IL', '60640-3593', 610),
#  ('Honolulu', 'HI', '96821', 611),
#  ('Plantation', 'FL', '33324-1393', 612),
#  ('New York', 'NY', '10035-2737', 613),
#  ('Carolina', 'PR', '00987', 614),
#  ('Winston Salem', 'NC', '27101', 615),
#  ('Largo', 'MD', '20774-2199', 616),
#  ('Omaha', 'NE', '68154-5258', 617),
#  ('Flat Rock', 'NC', '28731-4728', 618),
#  ('Duluth', 'MN', '55812', 619),
#  ('Thief River Falls', 'MN', '56701', 620),
#  ('Memphis', 'TN', '38103', 621),
#  ('Aurora', 'CO', '80011-9307', 622),
#  ('Chicago', 'IL', '60604-4110', 623),
#  ('Dover', 'NJ', '07801', 624),
#  ('Kinston', 'NC', '28502-0188', 625),
#  ('Boca Raton', 'FL', '33431', 626),
#  ('Salt Lake City', 'UT', '84101-3500', 627),
#  ('Dublin', 'VA', '24084-1127', 628),
#  ('San Juan', 'PR', '00917', 629),
#  ('Marietta', 'GA', '30067', 630),
#  ('Conway', 'SC', '29526', 631),
#  ('Morehead', 'KY', '40351', 632),
#  ('Williston', 'VT', '05495', 633),
#  ('Iselin', 'NJ', '08830', 634),
#  ('Hudson', 'NC', '28638', 635),
#  ('Alexandria', 'IN', '46001-0287', 636),
#  ('Sallisaw', 'OK', '74955', 637),
#  ('Burlington', 'VT', '05408-2721', 638),
#  ('Waltham', 'MA', '02453', 639),
#  ('Chattanooga', 'TN', '37421-3707', 640),
#  ('Hickory', 'NC', '28601', 641),
#  ('Sedalia', 'MO', '65301-2199', 642),
#  ('Bowling Green', 'KY', '42101-1000', 643),
#  ('Hanceville', 'AL', '35077-2000', 644),
#  ('Drumright', 'OK', '74030', 645),
#  ('Saint Louis', 'MO', '63110-1088', 646),
#  ('Brecksville', 'OH', '44141-1296', 647),
#  ('Birmingham', 'AL', '35244', 648),
#  ('Wayne', 'NE', '68787', 649),
#  ('Las Vegas', 'NV', '89146', 650),
#  ('Coldwater', 'MI', '49036', 651),
#  ('Miramar', 'FL', '33027-3264', 652),
#  ('South Bend', 'IN', '46601', 653),
#  ('West Jordan', 'UT', '84088', 654),
#  ('Saint Paul', 'MN', '55108-1496', 655),
#  ('Midlothian', 'VA', '23112', 656),
#  ('Garden City', 'NY', '11530-0701', 657),
#  ('International Falls', 'MN', '56649', 658),
#  ('Galveston', 'TX', '77554', 659),
#  ('Wichita', 'KS', '67206-1097', 660),
#  ('Erdenheim', 'PA', '19038-8242', 661),
#  ('Austin', 'TX', '78705-5711', 662),
#  ('Dunwoody', 'GA', '30338', 663),
#  ('Minden', 'LA', '71055-0000', 664),
#  ('Newport News', 'VA', '23606', 665),
#  ('Huntington', 'WV', '25705', 666),
#  ('Sells', 'AZ', '85634-3129', 667),
#  ('Lauderhill', 'FL', '33351', 668),
#  ('Faribault', 'MN', '550215782', 669),
#  ('Waldorf', 'MD', '20602', 670),
#  ('Sterling', 'VA', '20166', 671),
#  ('Keyser', 'WV', '26726', 672),
#  ('Lowell', 'MA', '01852-1909', 673),
#  ('Neosho', 'MO', '64850', 674),
#  ('Chicago', 'IL', '60631', 675),
#  ('Eagan', 'MN', '55122-1346', 676),
#  ('Martinsville', 'VA', '24112', 677),
#  ('Teaneck', 'NJ', '07666', 678),
#  ('Westminster', 'MD', '21157', 679),
#  ('Greenwood', 'SC', '29649', 680),
#  ('Brooklyn', 'NY', '11205', 681),
#  ('Madison', 'FL', '32340', 682),
#  ('Los Angeles', 'CA', '90047-4899', 683),
#  ('Davenport', 'IA', '52807', 684),
#  ('Bryan', 'TX', '77802', 685),
#  ('Wesson', 'MS', '39191', 686),
#  ('Seward', 'NE', '68434-1556', 687),
#  ('Sain Peters', 'MO', '63376', 688),
#  ('Saranac Lake', 'NY', '12983-0089', 689),
#  ('Portland', 'OR', '97225-6651', 690),
#  ('Oklahoma City', 'OK', '73116', 691),
#  ('Houston', 'TX', '77042', 692),
#  ('Enterprise', 'AL', '36330-1300', 693),
#  ('Oneonta', 'NY', '13820-4020', 694),
#  ('Bluffton', 'OH', '45817-2104', 695),
#  ('Pembroke Pines', 'FL', '33028', 696),
#  ('Altamonte', 'FL', '32701', 697),
#  ('Lubbock', 'TX', '79407', 698),
#  ('Sylvania', 'OH', '43560', 699),
#  ('Phoenix', 'AZ', '85033', 700),
#  ('Kentwood', 'MI', '49508', 701),
#  ('Saratoga', 'CA', '95070-5698', 702),
#  ('Columbus', 'GA', '31907', 703),
#  ('Bellingham', 'WA', '98225', 704),
#  ('Hammond', 'LA', '70401', 705),
#  ('Irwin', 'OH', '43029', 706),
#  ('Fort Wayne', 'IN', '46805-1499', 707),
#  ('Detroit', 'MI', '48204', 708),
#  ('Saint Petersburg', 'FL', '33708-3116', 709),
#  ('Longview', 'TX', '75602', 710),
#  ('Oceanside', 'CA', '92056-3899', 711),
#  ('Waco', 'TX', '76798', 712),
#  ('Fajardo', 'PR', '00738-7003', 713),
#  ('Baltimore', 'MD', '21201-1627', 714),
#  ('Milligan College', 'TN', '37682', 715),
#  ('South Portland', 'ME', '04106', 716),
#  ('Chubbuck', 'ID', '83202', 717),
#  ('Unity', 'ME', '04988', 718),
#  ('New York', 'NY', '10012-1091', 719),
#  ('Bryn Mawr', 'PA', '19010-3470', 720),
#  ('Chattanooga', 'TN', '37404', 721),
#  ('Tampa', 'FL', '33614-7095', 722),
#  ('Lone Tree', 'CO', '80124-5453', 723),
#  ('Staten Island', 'NY', '10301-4495', 724),
#  ('Houston', 'TX', '77058-1002', 725),
#  ('Pittsburgh', 'PA', '15276-0119', 726),
#  ('North Canton', 'OH', '44720-3396', 727),
#  ('Sedalia', 'MO', '65301', 728),
#  ('Providence', 'RI', '02912', 729),
#  ('Denver', 'CO', '80221-1099', 730),
#  ('Frederick', 'MD', '21701', 731),
#  ('Oak Hill', 'WV', '25901', 732),
#  ('North Plainfield', 'NJ', '07060', 733),
#  ('Philadelphia', 'PA', '19128', 734),
#  ('Buckhannon', 'WV', '26201', 735),
#  ('Dubuque', 'IA', '52004-0873', 736),
#  ('Trenton', 'NJ', '08629-1986', 737),
#  ('New Orleans', 'LA', '70123', 738),
#  ('Trinity', 'FL', '34655-4401', 739),
#  ('Asheville', 'NC', '28801-4897', 740),
#  ('Phoenixville', 'PA', '19460-2373', 741),
#  ('Duluth', 'MN', '55802', 742),
#  ('Pullman', 'WA', '99164-5910', 743),
#  ('Shoreline', 'WA', '98133', 744),
#  ('Orange', 'CA', '92868', 745),
#  ('Cerritos', 'CA', '90703', 746),
#  ('Harrison', 'NY', '10528', 747),
#  ('Syracuse', 'NY', '13203', 748),
#  ('Waynesville', 'MO', '65583', 749),
#  ('Corona', 'CA', '92879', 750),
#  ('Blue Ash', 'OH', '45236-1096', 751),
#  ('W Bloomfield', 'MI', '48322-3032', 752),
#  ('Everett', 'WA', '98208', 753),
#  ('Madison', 'NJ', '07940', 754),
#  ('Vallejo', 'CA', '94590', 755),
#  ('Murfreesboro', 'TN', '37132', 756),
#  ('Waterbury', 'CT', '06705', 757),
#  ('Haltom city', 'TX', '76117', 758),
#  ('Huber Heights', 'OH', '45424', 759),
#  ('Landover', 'MD', '20785', 760),
#  ('Abilene', 'TX', '79698-0001', 761),
#  ('Kansas City', 'MO', '64131-3459', 762),
#  ('Columbus', 'KS', '66725', 763),
#  ('Atchison', 'KS', '66002', 764),
#  ('Hillsdale', 'MI', '49242', 765),
#  ('Cleveland Heights', 'OH', '44118', 766),
#  ('Latrobe', 'PA', '15650-2690', 767),
#  ('Washington', 'DC', '20006-5540', 768),
#  ('Ottawa', 'OH', '45875', 769),
#  ('Farmers Branch', 'TX', '75244-4997', 770),
#  ('Portland', 'OR', '97215-3367', 771),
#  ('Baton Rouge', 'LA', '70806', 772),
#  ('Brooklyn Center', 'MN', '55430', 773),
#  ('Linwood', 'NJ', '08221', 774),
#  ('West Park', 'NY', '12493-0174', 775),
#  ('Waycross', 'GA', '31503', 776),
#  ('Sioux Falls', 'SD', '57108', 777),
#  ('Washington', 'DC', '20005', 778),
#  ('Chicago', 'IL', '60630', 779),
#  ('Aberdeen', 'SD', '57401-7198', 780),
#  ('El Cajon', 'CA', '92019-1108', 781),
#  ('New Rochelle', 'NY', '10801-1890', 782),
#  ('Atlanta', 'GA', '30326', 783),
#  ('Farmington Hills', 'MI', '48334-4512', 784),
#  ('Huntsville', 'TN', '37756-4149', 785),
#  ('Gainesville', 'FL', '32601', 786),
#  ('Jackson', 'OH', '45640', 787),
#  ('Hartford', 'CT', '06103', 788),
#  ('Phoenix', 'AZ', '85017-5885', 789),
#  ('Bessemer', 'AL', '35022', 790),
#  ('Miami', 'FL', '33122-1707', 791),
#  ('York', 'PA', '17403-3326', 792),
#  ('Dothan', 'AL', '363034419', 793),
#  ('Greensboro', 'NC', '27401-3239', 794),
#  ('North Lima', 'OH', '44452', 795),
#  ('Lawrence', 'KS', '66046-2703', 796),
#  ('Lubbock', 'TX', '79411', 797),
#  ('Wilmington', 'NC', '28401-3910', 798),
#  ('Bedford Park', 'IL', '60638', 799),
#  ('Saint Louis', 'MO', '63119-4399', 800),
#  ('Cheraw', 'SC', '29520', 801),
#  ('Cincinnati', 'OH', '45202-1706', 802),
#  ('Bellingham', 'WA', '98225-9008', 803),
#  ('Chicago', 'IL', '60615-5698', 804),
#  ('Dayton', 'TN', '37321', 805),
#  ('Lakeland', 'FL', '33801', 806),
#  ('Oklahoma City', 'OK', '73116-1695', 807),
#  ('Baton Rouge', 'LA', '70808', 808),
#  ('Seattle', 'WA', '98133', 809),
#  ('North Charleston', 'SC', '29406', 810),
#  ('Huntsville', 'AL', '35810', 811),
#  ('Davenport', 'IA', '52807-3003', 812),
#  ('Fort Gordon', 'GA', '30907', 813),
#  ('Exton', 'PA', '19341-1310', 814),
#  ('East Peoria', 'IL', '61635-0001', 815),
#  ('Modesto', 'CA', '95356', 816),
#  ('St Louis', 'MO', '63114', 817),
#  ('West Columbia', 'SC', '29170-2176', 818),
#  ('Carthage', 'TX', '75633-2397', 819),
#  ('Longmeadow', 'MA', '01106', 820),
#  ('Philadelphia', 'PA', '19110', 821),
#  ('Fort Lauderdale', 'FL', '33312', 822),
#  ('Cedar Rapids', 'IA', '52406-2068', 823),
#  ('Huntington', 'NY', '11743-1626', 824),
#  ('Maryville', 'TN', '37804-5907', 825),
#  ('Aston', 'PA', '19014-1298', 826),
#  ('Cullowhee', 'NC', '28723-9646', 827),
#  ('Houston', 'TX', '77090-5918', 828),
#  ('Youngwood', 'PA', '15697-1895', 829),
#  ('Ranger', 'TX', '76470', 830),
#  ('Kirkland', 'WA', '98034-8506', 831),
#  ('Anaheim', 'CA', '92801-0000', 832),
#  ('Wilmington', 'CA', '90744-2397', 833),
#  ('Fort Lauderdale', 'FL', '33301', 834),
#  ('Asheville', 'NC', '28804-8510', 835),
#  ('Chadron', 'NE', '69337-2690', 836),
#  ('Dryden', 'NY', '13053-0139', 837),
#  ('Houston', 'TX', '77071-0000', 838),
#  ('Fayetteville', 'NC', '28311-1420', 839),
#  ('Houston', 'TX', '77063', 840),
#  ('Macon', 'GA', '31210', 841),
#  ('Johnstown', 'PA', '15905-4398', 842),
#  ('Rochester', 'MN', '55906', 843),
#  ('Greencastle', 'IN', '46135-1772', 844),
#  ('Bartlesville', 'OK', '74006-6299', 845),
#  ('Petoskey', 'MI', '49770', 846),
#  ('Denver', 'CO', '80206', 847),
#  ('Arlington', 'VA', '22203', 848),
#  ('Richmond', 'VA', '23227', 849),
#  ('Sandusky', 'OH', '44870-5871', 850),
#  ('Lima', 'OH', '45807', 851),
#  ('Greenville', 'TX', '75402', 852),
#  ('Columbia', 'MO', '65202', 853),
#  ('North Charleston', 'SC', '29418', 854),
#  ('Spokane', 'WA', '99201', 855),
#  ('Raleigh', 'NC', '27695-7001', 856),
#  ('Allentown', 'PA', '18109-3253', 857),
#  ('Florence', 'MS', '39073-1070', 858),
#  ('Franklin', 'TN', '37067', 859),
#  ('San Dimas', 'CA', '91773-3298', 860),
#  ('OREGON', 'OH', '43616', 861),
#  ('Ilion', 'NY', '13357', 862),
#  ('West Palm Beach', 'FL', '33401', 863),
#  ('Andover', 'MA', '01810', 864),
#  ('Brunswick', 'ME', '04011', 865),
#  ('Mont Alto', 'PA', '17237-9700', 866),
#  ('Texarkana', 'TX', '75503', 867),
#  ('Hannibal', 'MO', '63401', 868),
#  ('St Peters', 'MO', '63376', 869),
#  ('Grand Junction', 'CO', '81501', 870),
#  ('York', 'PA', '17404', 871),
#  ('Prescott', 'AZ', '86303', 872),
#  ('New Haven', 'CT', '06511-1189', 873),
#  ('Evansville', 'IN', '47715-4601', 874),
#  ('Far Rockaway', 'NY', '11691', 875),
#  ('Boston', 'MA', '02108-2770', 876),
#  ('University of Richmond', 'VA', '23173', 877),
#  ('Costa Mesa', 'CA', '92626-3099', 878),
#  ('Harrisonville', 'MO', '64701-2024', 879),
#  ('Brooklyn', 'NY', '11210', 880),
#  ('South Houston', 'TX', '77587-3714', 881),
#  ('Bay City', 'MI', '48708-5614', 882),
#  ('Lebanon', 'OH', '45036-1099', 883),
#  ('Cleveland', 'MS', '38733', 884),
#  ('Los Angeles', 'CA', '90049-1599', 885),
#  ('Miami', 'FL', '33134', 886),
#  ('Bowling Green', 'KY', '42101-3601', 887),
#  ('Berlin', 'NH', '03570', 888),
#  ('Culver City', 'CA', '90230-3519', 889),
#  ('Bayamon', 'PR', '00961-9998', 890),
#  ('Blytheville', 'AR', '72315', 891),
#  ('Palm Springs', 'CA', '92264', 892),
#  ('University Park', 'IL', '60484', 893),
#  ('Albany', 'OR', '97321', 894),
#  ('Plymouth', 'NH', '03264-1595', 895),
#  ('Marshall', 'TX', '75670-1498', 896),
#  ('Capitol Heights', 'MD', '20743', 897),
#  ('Winter Park', 'FL', '32792', 898),
#  ('Compton', 'CA', '90221-5393', 899),
#  ('Arecibo', 'PR', '00614-4010', 900),
#  ('Chicago', 'IL', '60628-1696', 901),
#  ('Saint Paul', 'MN', '55104-1284', 902),
#  ('Columbus', 'OH', '43209', 903),
#  ('Garland', 'TX', '75040-3294', 904),
#  ('Louisville', 'KY', '40223', 905),
#  ('Pleasant Hill', 'CA', '94523', 906),
#  ('Texas City', 'TX', '77591-2499', 907),
#  ('West Monroe', 'LA', '71292-9064', 908),
#  ('Wellesley', 'MA', '02457-0310', 909),
#  ('West Monroe', 'LA', '71291-0603', 910),
#  ('Craftsbury Common', 'VT', '05827-0072', 911),
#  ('Fairview Park', 'OH', '44126-2214', 912),
#  ('Saint George', 'UT', '84770-0000', 913),
#  ('Camden', 'SC', '29020', 914),
#  ('Chillicothe', 'MO', '64601', 915),
#  ('Winston-Salem', 'NC', '27127', 916),
#  ('Cincinnati', 'OH', '45224-1462', 917),
#  ('Albuquerque', 'NM', '87112-4413', 918),
#  ('Grantsboro', 'NC', '28529', 919),
#  ('Toledo', 'OH', '43612-2822', 920),
#  ('Feasterville Trevose', 'PA', '19053', 921),
#  ('Kosciusko', 'MS', '39090', 922),
#  ('Fredericksburg', 'VA', '22401-5300', 923),
#  ('Richmond', 'IN', '47374-4095', 924),
#  ('Duluth', 'GA', '30096', 925),
#  ('Sugar Grove', 'IL', '60554-9454', 926),
#  ('Lexington', 'KY', '40506-0032', 927),
#  ('Pompano Beach', 'FL', '33064', 928),
#  ('Fort Wayne', 'IN', '46805', 929),
#  ('Plattsburgh', 'NY', '12901-2681', 930),
#  ('Tulsa', 'OK', '74105', 931),
#  ('Braintree', 'MA', '02184', 932),
#  ('Ridgewood', 'NY', '11385', 933),
#  ('Muskogee', 'OK', '74403-1889', 934),
#  ('Orange Park', 'FL', '32073', 935),
#  ('Hoffman Estates', 'IL', '60192', 936),
#  ('Los Angeles', 'CA', '90059', 937),
#  ('Raleigh', 'NC', '27604-6072', 938),
#  ('Clarksville', 'TN', '37044', 939),
#  ('Woodland', 'CA', '95695', 940),
#  ('Dearborn', 'MI', '48128-1491', 941),
#  ('Annandale', 'VA', '22003', 942),
#  ('Sapulpa', 'OK', '74066', 943),
#  ('Blue Lake', 'CA', '95525-0816', 944),
#  ('Memphis', 'TN', '38105-3604', 945),
#  ('Chicago', 'IL', '60642-3312', 946),
#  ('Winter Garden', 'FL', '34787-3733', 947),
#  ('San Juan', 'PR', '00931-0000', 948),
#  ('Rainsville', 'AL', '35986', 949),
#  ('Chestnut Hill', 'MA', '02467', 950),
#  ('Federal Way', 'WA', '98003', 951),
#  ('Harrisburg', 'PA', '17112-1012', 952),
#  ('West Point', 'MS', '39773', 953),
#  ('Petersburg', 'VA', '23805', 954),
#  ('Philadelphia', 'PA', '19130', 955),
#  ('Nutley', 'NJ', '07110', 956),
#  ('Fremont', 'OH', '43420-9670', 957),
#  ('Houston', 'TX', '77057', 958),
#  ('Tucson', 'AZ', '85711', 959),
#  ('Spartanburg', 'SC', '29301', 960),
#  ('Chico', 'CA', '95929-0150', 961),
#  ('North Haven', 'CT', '06473', 962),
#  ('Jacksonville', 'FL', '32246', 963),
#  ('Sidney', 'MI', '48885-9723', 964),
#  ('Shelby', 'OH', '44875', 965),
#  ('Jackson', 'MI', '48901', 966),
#  ('Hollywood', 'CA', '90028-6106', 967),
#  ('Chicago', 'IL', '60601-2449', 968),
#  ('Cape Girardeau', 'MO', '63701', 969),
#  ('Mansfield', 'OH', '44906', 970),
#  ('Dover', 'NH', '03820', 971),
#  ('Saint Joseph', 'MI', '49085', 972),
#  ('Jamaica', 'NY', '11432', 973),
#  ('Norman', 'OK', '73069', 974),
#  ('Bartlett', 'TN', '38133', 975),
#  ('Lake Forest', 'IL', '60045-2399', 976),
#  ('Clearfield', 'PA', '16830', 977),
#  ('Northridge', 'CA', '91324', 978),
#  ('Parkersburg', 'WV', '26101', 979),
#  ('Braintree', 'MA', '02184-1744', 980),
#  ('Peoria', 'IL', '61603', 981),
#  ('Chalmette', 'LA', '70043', 982),
#  ('Corpus Christi', 'TX', '78410', 983),
#  ('Kansas City', 'MO', '64108', 984),
#  ('Edison', 'NJ', '08818-3050', 985),
#  ('Upland', 'CA', '91786', 986),
#  ('Honolulu', 'HI', '96822-2217', 987),
#  ('Timonium', 'MD', '21093', 988),
#  ('Pine Bluff', 'AR', '71601', 989),
#  ('Gettysburg', 'PA', '17325-3403', 990),
#  ('Cresco', 'IA', '52136', 991),
#  ('West Haven', 'CT', '06516', 992),
#  ('Galloway', 'NJ', '08205-9441', 993),
#  ('Greeley', 'CO', '80631', 994),
#  ('La Puente', 'CA', '91746-0002', 995),
#  ('Fort Smith', 'AR', '72908', 996),
#  ('Canonsburg', 'PA', '15317', 997),
#  ('Minneapolis', 'MN', '55402-3389', 998),
#  ('Sumter', 'SC', '29150-2871', 999),
#  ('Scottsville', 'KY', '42164', 1000),
#  ...]

# %%
# %%sql
# UPDATE location_D
# SET zip=t1.zip1 FROM
# (SELECT city,state,location_id,split_part(zip, '-', 1) as zip1 FROM location_D)t1
# where location_D.city=t1.city
# AND location_D.state=t1.state
# AND location_D.location_id=t1.location_id
# Out:
# 6602 rows affected.
# []

# %%
# %%sql
# ALTER TABLE location_D
# ADD COLUMN state_zip_id INT
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE location_D
# ADD FOREIGN KEY (state_zip_id)
# REFERENCES location1_D(location_id)
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE location_D
# ADD COLUMN spare_state_zip_id INT
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE location_D
# ADD FOREIGN KEY (spare_state_zip_id)
# REFERENCES spare_state_zip(spare_state_zip_id)
# Out:
# (psycopg2.ProgrammingError) relation "spare_state_zip" does not exist
#  [SQL: 'ALTER TABLE location_D\nADD FOREIGN KEY (spare_state_zip_id)\nREFERENCES spare_state_zip(spare_state_zip_id)']

# %%
# %%sql
# UPDATE location_D
# SET state_zip_id=location1_D.location_id FROM location1_D
# WHERE location_D.state = location1_D.state AND location_D.zip = location1_D.zip
# Out:
# 6284 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS spare_state_zip;
# CREATE TABLE spare_state_zip(
# state CHAR(4),
# zip CHAR(10)
# )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO spare_state_zip
# select state,zip from location_D where state_zip_id IS NULL
# Out:
# 318 rows affected.
# []

# %%
# %%sql
# ALTER TABLE spare_state_zip
# ADD COLUMN spare_state_zip_id SERIAL PRIMARY KEY
# Out:
# Done.
# []

# %%
# %%sql
# UPDATE location_D
# SET spare_state_zip_id=spare_state_zip.spare_state_zip_id FROM spare_state_zip
# WHERE location_D.state = spare_state_zip.state AND location_D.zip = spare_state_zip.zip
# Out:
# 318 rows affected.
# []

# %%
# %%sql
# ALTER TABLE location_D
# DROP COLUMN state
# Out:
# Done.
# []

# %%
# %%sql
# ALTER TABLE location_D
# DROP COLUMN ZIP
# Out:
# Done.
# []

# %%
# %%sql
# select * from location_D
# Out:
# 6602 rows affected.
# [('San Juan', 21, None, 1),
#  ('Koror', 25, None, 2),
#  ('Ponce', 32, None, 3),
#  ('Carthage', 35, None, 4),
#  ('Bloomington', 36, None, 5),
#  ('Gurabo', 100, None, 6),
#  ('Los Angeles', 106, None, 7),
#  ('Teterboro', 119, None, 8),
#  ('Hialeah', 209, None, 9),
#  ('Juana Diaz', 217, None, 10),
#  ('Aguada', 237, None, 11),
#  ('Pittsburgh', 241, None, 12),
#  ('Bayamon', 250, None, 13),
#  ('Lebanon', 251, None, 14),
#  ('Long Beach', 260, None, 15),
#  ('Enfield', 274, None, 16),
#  ('Blaine', 276, None, 17),
#  ('Guaynabo', 352, None, 18),
#  ('Arecibo', 358, None, 19),
#  ('Arroyo', 440, None, 20),
#  ('Humacao', 461, None, 21),
#  ('Providence', 469, None, 22),
#  ('Coamo', 471, None, 23),
#  ('Phenix City', 498, None, 24),
#  ('Santa Monica', 506, None, 25),
#  ('Carolina', 522, None, 26),
#  ('El Paso', 542, None, 27),
#  ('Rio Grande', 543, None, 28),
#  ('Livonia', 547, None, 29),
#  ('Waterbury', 559, None, 30),
#  ('Pago Pago', 574, None, 31),
#  ('Bayamon', 580, None, 32),
#  ('Pittsburgh', 726, None, 12),
#  ('Carolina', 614, None, 33),
#  ('San Juan', 629, None, 34),
#  ('Faribault', 669, None, 35),
#  ('Fajardo', 713, None, 36),
#  ('Dothan', 793, None, 38),
#  ('East Peoria', 815, None, 39),
#  ('Bayamon', 890, None, 40),
#  ('Arecibo', 900, None, 19),
#  ('Wellesley', 909, None, 42),
#  ('San Juan', 948, None, 43),
#  ('Ponce', 1019, None, 44),
#  ('Gurabo', 1184, None, 6),
#  ('Bayamon', 1080, None, 40),
#  ('Wichita', 1057, None, 45),
#  ('Ft Myers', 1123, None, 47),
#  ('Granger', 1135, None, 48),
#  ('Modesto', 1176, None, 49),
#  ('Bayamón', 1220, None, 40),
#  ('San Diego', 1206, None, 51),
#  ('Meadville', 1228, None, 53),
#  ('Bend', 1229, None, 54),
#  ('Colorado Springs', 1240, None, 55),
#  ('New Port Richey', 1293, None, 56),
#  ('Anaheim', 1296, None, 57),
#  ('Arecibo', 1436, None, 19),
#  ('Bridgewater', 1364, None, 58),
#  ('Walnut Creek', 1375, None, 59),
#  ('Lubbock', 1442, None, 61),
#  ('San Juan', 1451, None, 62),
#  ('San Sebastian', 1484, None, 63),
#  ('St. Petersburg', 1492, None, 64),
#  ('Ponce', 1499, None, 65),
#  ('Reno', 1593, None, 66),
#  ('Castine', 1595, None, 67),
#  ('Jamaica', 1611, None, 68),
#  ('Mayaguez', 1637, None, 69),
#  ('Hato Rey', 1675, None, 62),
#  ('Guaynabo', 1684, None, 71),
#  ('London', 1724, None, 72),
#  ('Kalamazoo', 1728, None, 73),
#  ('Charlotte', 1732, None, 74),
#  ('Mayaguez', 1794, None, 75),
#  ('Fajardo', 1808, None, 76),
#  ('Pasadena', 1842, None, 77),
#  ('Farmington', 1875, None, 78),
#  ('Omaha', 1877, None, 79),
#  ('Moca', 1893, None, 80),
#  ('Bay City', 1895, None, 81),
#  ('Hato Rey', 1990, None, 34),
#  ('Hato Rey', 1989, None, 76),
#  ('Wilkes-Barre', 1971, None, 82),
#  ('Merced', 1996, None, 85),
#  ('San Juan', 1997, None, 86),
#  ('Barranquitas', 2013, None, 87),
#  ('Little Rock', 2014, None, 88),
#  ('Staten Island', 2021, None, 89),
#  ('Arecibo', 2052, None, 90),
#  ('Rio Piedras', 2068, None, 91),
#  ('Charleston', 2118, None, 92),
#  ('Manatí', 2137, None, 93),
#  ('New York', 2190, None, 94),
#  ('Dayton', 2210, None, 95),
#  ('Perkasie', 2212, None, 96),
#  ('Irvine', 2224, None, 97),
#  ('Worcester', 2240, None, 98),
#  ('Aguadilla', 2259, None, 99),
#  ('Richmond', 2275, None, 100),
#  ('Carolina', 2298, None, 101),
#  ('Highland Heights', 2408, None, 102),
#  ('Lincoln', 2416, None, 103),
#  ('Northampton', 2422, None, 104),
#  ('Fresno', 2482, None, 105),
#  ('Guayama', 2498, None, 106),
#  ('San Marcos', 2513, None, 107),
#  ('Santurce', 2551, None, 108),
#  ('Manati', 2644, None, 93),
#  ('Romeoville', 2561, None, 109),
#  ('Cedar Falls', 2609, None, 110),
#  ('Middletown', 2649, None, 112),
#  ('Utuado', 2661, None, 113),
#  ('Mesa', 2682, None, 114),
#  ('Bismarck', 2689, None, 115),
#  ('Hato Rey', 2805, None, 76),
#  ('High Point', 2712, None, 116),
#  ('Youngstown', 2733, None, 117),
#  ('Santurce', 2800, None, 118),
#  ('Cayey', 2826, None, 120),
#  ('Midland', 2874, None, 121),
#  ('Troy', 2907, None, 122),
#  ('Enfield', 2929, None, 123),
#  ('York', 2954, None, 124),
#  ('Eagan', 3001, None, 125),
#  ('Teterboro', 3008, None, 8),
#  ('Hato Rey', 3054, None, 62),
#  ('Manati', 3150, None, 93),
#  ('Trujillo Alto', 3094, None, 128),
#  ('Amherst', 3097, None, 129),
#  ('Earth City', 3118, None, 130),
#  ('Texarkana', 3126, None, 131),
#  ('Ponce', 3289, None, 44),
#  ('Wadena', 3162, None, 133),
#  ('Spokane', 3182, None, 134),
#  ('Wausau', 3288, None, 135),
#  ('Orono', 3297, None, 137),
#  ('Manati', 3347, None, 93),
#  ('Mokena', 3317, None, 138),
#  ('San Juan', 3362, None, 140),
#  ('Tucson', 3377, None, 141),
#  ('Evansville', 3411, None, 142),
#  ('Ponce', 3511, None, 44),
#  ('Barranquitas', 3529, None, 87),
#  ('San Juan', 3495, None, 108),
#  ('Bayamon', 3482, None, 143),
#  ('Guayama', 3584, None, 147),
#  ('St. Croix', 3589, None, 148),
#  ('Houston', 3607, None, 149),
#  ('San Juan', 3624, None, 118),
#  ('Colchester', 3616, None, 150),
#  ('Austin', 3620, None, 151),
#  ('Columbus', 3625, None, 153),
#  ('Fort Myers', 3689, None, 154),
#  ('Sacramento', 3701, None, 155),
#  ('Chicopee', 3729, None, 156),
#  ('New Wilmington', 3736, None, 157),
#  ('Mayaguez', 3872, None, 69),
#  ('Aguadilla', 3767, None, 158),
#  ('Saipan', 3769, None, 159),
#  ('San Juan', 3802, None, 160),
#  ('Boston', 3827, None, 161),
#  ('Phoenix', 3844, None, 162),
#  ('Topeka', 3874, None, 164),
#  ('Caro', 3892, None, 165),
#  ('Pittsburgh', 3903, None, 166),
#  ('Rio Grande', 3914, None, 28),
#  ('Santurce', 3984, None, 118),
#  ('Vancouver', 3913, None, 167),
#  ('Charlotte Amalie', 3993, None, 170),
#  ('Appleton', 4007, None, 171),
#  ('Phoenix', 4013, None, 172),
#  ('Pittsburgh', 4181, None, 12),
#  ('Bayamón', 4192, None, 13),
#  ('Cayey', 4161, None, 120),
#  ('Watertown', 4070, None, 173),
#  ('Sacramento', 4084, None, 174),
#  ('Coffeyville', 4106, None, 175),
#  ('Aurora', 4109, None, 176),
#  ('Carolina', 4130, None, 177),
#  ('Warren', 4136, None, 178),
#  ('Memphis', 4177, None, 180),
#  ('Lake Elmo', 4203, None, 183),
#  ('San Juan', 4242, None, 62),
#  ('Mayaguez', 4244, None, 69),
#  ('Cambridge', 4232, None, 184),
#  ('Vega Baja', 4273, None, 187),
#  ('Marina', 4276, None, 188),
#  ('Mercedita', 4296, None, 189),
#  ('Bristol', 4324, None, 190),
#  ('Siloam Springs', 4338, None, 191),
#  ('Fresno', 4354, None, 192),
#  ('Flagstaff', 4357, None, 193),
#  ('Howell', 4379, None, 194),
#  ('Grand Rapids', 4383, None, 195),
#  ('Carolina', 4416, None, 196),
#  ('Saginaw', 4427, None, 197),
#  ('San Juan', 4430, None, 198),
#  ('Burlington', 4460, None, 199),
#  ('Arecibo', 4464, None, 200),
#  ('New York', 4470, None, 201),
#  ('Mangilao', 4473, None, 202),
#  ('Willimantic', 4476, None, 203),
#  ('Yauco', 4486, None, 204),
#  ('Santa Clara', 4505, None, 205),
#  ('Bad Axe', 4554, None, 206),
#  ('Detroit Lakes', 4565, None, 207),
#  ('Del Rio', 4574, None, 208),
#  ('Vega Baja', 4605, None, 209),
#  ('Ponce', 4615, None, 210),
#  ('Sarasota', 4653, None, 211),
#  ('Lynchburg', 4657, None, 212),
#  ('Santurce', 4680, None, 76),
#  ('Traverse City', 4676, None, 213),
#  ('Caguas', 4682, None, 215),
#  ('Battle Creek', 4708, None, 216),
#  ('Keene', 4743, None, 217),
#  ('Alma', 4761, None, 218),
#  ('Torrance', 4788, None, 219),
#  ('Flint', 4813, None, 220),
#  ('Bayamon', 4895, None, 13),
#  ('Laramie', 4815, None, 221),
#  ('Pine Bluff', 4819, None, 222),
#  ('Peoria', 4861, None, 223),
#  ('Nashville', 4875, None, 224),
#  ('Moorhead', 4931, None, 226),
#  ('Montgomery', 4941, None, 227),
#  ('San Juan', 5041, None, 108),
#  ('North Miami Beach', 4970, None, 228),
#  ('Staples', 5004, None, 229),
#  ('Adelphia', 5029, None, 230),
#  ('Normal', 5089, None, 232),
#  ('San Juan', 5213, None, 1),
#  ('San Sebastian', 5173, None, 23),
#  ('Lakeland', 5142, None, 233),
#  ('Ponce', 5331, None, 44),
#  ('Mayaguez', 5275, None, 75),
#  ('San Juan', 5325, None, 91),
#  ('San Juan', 5290, None, 140),
#  ('Richland', 5266, None, 236),
#  ('Lansing', 5317, None, 239),
#  ('Holland', 5348, None, 242),
#  ('Rolla', 5378, None, 243),
#  ('Columbus', 5381, None, 244),
#  ('Pohnpei', 5407, None, 245),
#  ('Alpena', 5471, 1610, None),
#  ('Bayamon', 5558, None, 13),
#  ('Bayamon', 5457, None, 32),
#  ('San Juan', 5514, None, 86),
#  ('Caguas', 5463, None, 247),
#  ('Miami', 5477, None, 248),
#  ('Fresno', 5519, None, 250),
#  ('Patchogue', 5522, None, 251),
#  ('Spokane', 5534, None, 252),
#  ('Isabela', 5535, None, 253),
#  ('Arecibo', 5633, None, 19),
#  ('Erie', 5629, None, 255),
#  ('San Jose', 5660, None, 257),
#  ('San Lorenzo', 5702, None, 258),
#  ('Alhambra', 5706, None, 259),
#  ('Fajardo', 5845, None, 36),
#  ('Bayamon', 5852, None, 143),
#  ('Guayama', 5720, None, 147),
#  ('Montpelier', 5751, None, 261),
#  ('Huntsville', 5769, None, 262),
#  ('Rocky Hill', 5787, None, 263),
#  ('Ponce', 5847, None, 265),
#  ('Roseville', 5850, None, 266),
#  ('Mankato', 5856, None, 268),
#  ('Carolina', 5857, None, 269),
#  ('Caguas', 5975, None, 247),
#  ('Brooklyn Park', 5876, None, 270),
#  ('Woodland Hills', 5929, None, 271),
#  ('Easton', 5980, None, 273),
#  ('Independence', 6009, None, 274),
#  ('Austin', 6015, None, 275),
#  ('Ponce', 6116, None, 65),
#  ('Juana Diaz', 6068, None, 76),
#  ('Carolina', 6142, None, 177),
#  ('Caguas', 6050, None, 247),
#  ('Omaha', 6045, None, 276),
#  ('Springfield', 6048, None, 277),
#  ('Albuquerque', 6053, None, 279),
#  ('Rogers', 6073, None, 281),
#  ('Brattleboro', 6097, None, 282),
#  ('Gettysburg', 6113, None, 283),
#  ('St. Benedict', 6119, None, 285),
#  ('Mangilao', 6144, None, 287),
#  ('San Juan', 6202, None, 76),
#  ('Manati', 6168, None, 93),
#  ('Ponce', 6170, None, 210),
#  ('Tampa', 6172, None, 290),
#  ('San German', 6210, None, 292),
#  ('Rio Piedras', 6236, None, 293),
#  ('Merrillville', 6258, None, 294),
#  ('Norfolk', 6261, None, 295),
#  ('San Francisco', 6267, None, 296),
#  ('Majuro', 6275, None, 297),
#  ('San Juan', 6310, None, 298),
#  ('Columbus', 6317, None, 299),
#  ('Bell', 6444, 2556, None),
#  ('Aguada', 6455, None, 11),
#  ('Bayamon', 6434, None, 13),
#  ('Humacao', 6376, None, 21),
#  ('Ponce', 6355, None, 65),
#  ('Arroyo', 6400, None, 76),
#  ('Aguadilla', 6349, None, 99),
#  ('San Juan', 6443, None, 118),
#  ('Humacao', 6357, None, 302),
#  ('Los Angeles', 6372, None, 303),
#  ('Seattle', 6407, None, 306),
#  ('Perrysburg', 6410, None, 307),
#  ('Guaynabo', 6429, None, 308),
#  ('Overland Park', 6432, None, 309),
#  ('Las Cruces', 6437, None, 311),
#  ('Battle Creek', 6452, None, 313),
#  ('Dallas', 3814, 19, None),
#  ('Selinsgrove', 3066, 20, None),
#  ('Sacramento', 6020, 23, None),
#  ('Everett', 753, 27, None),
#  ('Aliso Viejo', 5466, 31, None),
#  ('Phoenix', 3512, 48, None),
#  ('Phoenix', 789, 48, None),
#  ('Toppenish', 5794, 57, None),
#  ('South Gate', 1536, 62, None),
#  ('Fulton', 4630, 66, None),
#  ('Texarkana', 6328, 70, None),
#  ('New Haven', 4229, 79, None),
#  ('Oklahoma City', 6162, 84, None),
#  ('Kenansville', 4909, 85, None),
#  ('Claremont', 5984, 90, None),
#  ('Ponce', 6600, None, 44),
#  ('Ramey', 6480, None, 315),
#  ('Dearborn', 6557, None, 316),
#  ('Houston', 6602, None, 318),
#  ('Claremont', 4951, 90, None),
#  ('Claremont', 3938, 90, None),
#  ('Claremont', 3693, 90, None),
#  ('Claremont', 3282, 90, None),
#  ('Claremont', 2163, 90, None),
#  ('Claremont', 211, 90, None),
#  ('Plattsburgh', 2854, 115, None),
#  ('Plattsburgh', 1671, 115, None),
#  ('Plattsburgh', 1551, 115, None),
#  ('Plattsburgh', 930, 115, None),
#  ('Wilkes Barre', 3574, 122, None),
#  ('Anamosa', 3601, 134, None),
#  ('Columbus', 5303, 143, None),
#  ('Columbus', 4309, 143, None),
#  ('Southfield', 4490, 146, None),
#  ('Southfield', 2006, 146, None),
#  ('Riverside', 2339, 147, None),
#  ('Los Angeles', 2827, 150, None),
#  ('Los Angeles', 2588, 150, None),
#  ('Kosciusko', 922, 157, None),
#  ('Bowling Green', 2438, 159, None),
#  ('Maryville', 6245, 163, None),
#  ('Elkhart', 435, 170, None),
#  ('Las Vegas', 5619, 174, None),
#  ('Athens', 1797, 181, None),
#  ('Corning', 4537, 198, None),
#  ('Chicago', 4081, 214, None),
#  ('Annapolis', 5912, 228, None),
#  ('Washington', 2906, 241, None),
#  ('Santa Paula', 5271, 243, None),
#  ('Silver City', 1120, 249, None),
#  ('Johnson City', 5382, 252, None),
#  ('Warner Robins', 2842, 262, None),
#  ('Warner Robins', 601, 262, None),
#  ('Dubuque', 2760, 302, None),
#  ('Dubuque', 736, 302, None),
#  ('Albuquerque', 4624, 320, None),
#  ('Albuquerque', 1437, 320, None),
#  ('Moorefield', 1336, 333, None),
#  ('Minneapolis', 2881, 339, None),
#  ('Rothschild', 4816, 352, None),
#  ('Pikeville', 2995, 353, None),
#  ('Hoboken', 5454, 356, None),
#  ('Cottleville', 4617, 371, None),
#  ('St. Peters', 3722, 371, None),
#  ('Saint Peters', 1662, 371, None),
#  ('St Peters', 869, 371, None),
#  ('Sain Peters', 688, 371, None),
#  ('Lacey', 5775, 373, None),
#  ('Piketon', 1005, 376, None),
#  ('Minneapolis', 6513, 409, None),
#  ('Sioux City', 6132, 411, None),
#  ('Sioux City', 5911, 411, None),
#  ('Spartanburg', 2762, 448, None),
#  ('Spartanburg', 1465, 448, None),
#  ('Spartanburg', 195, 448, None),
#  ('Bradenton', 3422, 461, None),
#  ('Ukiah', 3933, 462, None),
#  ('Potsdam', 4144, 469, None),
#  ('Savannah', 3869, 470, None),
#  ('Savannah', 2950, 470, None),
#  ('Newtown', 5010, 471, None),
#  ('Cranford', 225, 483, None),
#  ('Arlington', 4834, 495, None),
#  ('Arlington', 3293, 495, None),
# %%sql
# SELECT CAST(ROUND(avg(t.income),2)AS FLOAT) AS Income,CAST(ROUND(avg(t.adm_rate),2)AS FLOAT) AS ADM FROM (SELECT avg(income_fact.A00100) as income,income_level_D.level,avg(CAST(admission_D.adm_rate_all AS NUMERIC)) as adm_rate,location1_D.zip
# FROM education_fact
# JOIN
# admission_D
# ON education_fact.admission_id=admission_D.admission_id
# JOIN
# location_D
# ON education_fact.location_id=location_D.location_id
# JOIN
# location1_D
# ON location_D.state_zip_id=location1_D.location_id
# JOIN income_fact
# ON location1_D.location_id=income_fact.location_id
# JOIN income_level_D
# ON income_fact.income_level_id=income_level_D.income_level_id
# WHERE admission_D.adm_rate_all NOT LIKE 'NULL'
# GROUP BY ROLLUP (location1_D.zip,income_level_D.level))t GROUP BY ZIP
# Out:
# 2614 rows affected.
# [(49684116.14, 0.37),
#  (19151400.47, 0.84),
#  (31158316.56, 0.54),
#  (3189296.33, 0.6),
#  (14865844.3, 0.6),
#  (90700120.08, 0.73),
#  (15525739.61, 0.73),
#  (11659568.39, 0.77),
#  (63163033.07, 0.89),
#  (15546960.88, 0.83),
#  (13100020.71, 0.71),
#  (23456163.1, 0.19),
#  (5206412.89, 0.77),
#  (36817349.92, 0.76),
#  (28021699.43, 0.73),
#  (33050171.48, 0.58),
#  (36470621.53, 0.85),
#  (50962134.77, 0.71),
#  (11652217.89, 0.48),
#  (12761079.68, 0.78),
#  (92083960.34, 0.61),
#  (60432096.16, 0.61),
#  (79049959.37, 0.6),
#  (77195737.23, 0.83),
#  (54883709.12, 0.77),
#  (124418160.64, 0.77),
#  (21450360.64, 0.72),
#  (28481689.87, 0.66),
#  (51638433.11, 0.44),
#  (69502197.58, 0.67),
#  (101445188.76, 0.49),
#  (62226489.92, 0.58),
#  (40512858.24, 0.7),
#  (92778476.53, 0.16),
#  (91137351.72, 0.61),
#  (72380695.65, 0.44),
#  (123664163.97, 0.83),
#  (102571512.04, 0.64),
#  (112807792.05, 0.97),
#  (84148982.45, 0.57),
#  (315832548.2, 0.59),
#  (29684092.12, 0.61),
#  (55318979.64, 0.75),
#  (32877622.37, 0.72),
#  (236233117.36, 0.44),
#  (87517139.52, 0.11),
#  (16322763.46, 0.77),
#  (68566849.1, 1.0),
#  (26013840.47, 0.72),
#  (97126555.36, 0.3),
#  (29054976.71, 0.61),
#  (139608074.18, 0.59),
#  (26364099.58, 0.56),
#  (55022716.23, 0.9),
#  (31074295.36, 0.22),
#  (24691474.51, 0.34),
#  (178084581.07, 0.41),
#  (29432642.83, 0.41),
#  (2826178.0, 0.36),
#  (179771112.28, 0.72),
#  (37130058.17, 0.6),
#  (181709683.17, 0.46),
#  (300756462.5, 0.35),
#  (191858956.28, 0.18),
#  (331162985.39, 0.76),
#  (17260509.79, 0.53),
#  (10376409.52, 0.42),
#  (31250236.75, 0.66),
#  (36859397.78, 0.51),
#  (30144658.27, 0.62),
#  (45247220.02, 0.67),
#  (48825920.65, 0.72),
#  (51562994.72, 0.9),
#  (4957576.7, 0.83),
#  (59838402.38, 0.68),
#  (61815526.05, 0.74),
#  ...]

# %%
from bokeh.charts import Scatter, output_file, show
from bokeh.io import output_notebook, show
from pandas import DataFrame

result=_
df = result.DataFrame()
#xx = df['round_1'].values.tolist()
#yy = df['round'].values.tolist()
print(df)
p = Scatter(df, x='income', y= 'adm', title="Income vs. Admission Rate",
          xlabel="Income", ylabel="Admission Rate")

#output_file("scatter.html")

show(p)
# Out:
#             income   adm
# 0     4.968412e+07  0.37
# 1     1.915140e+07  0.84
# 2     3.115832e+07  0.54
# 3     3.189296e+06  0.60
# 4     1.486584e+07  0.60
# 5     9.070012e+07  0.73
# 6     1.552574e+07  0.73
# 7     1.165957e+07  0.77
# 8     6.316303e+07  0.89
# 9     1.554696e+07  0.83
# 10    1.310002e+07  0.71
# 11    2.345616e+07  0.19
# 12    5.206413e+06  0.77
# 13    3.681735e+07  0.76
# 14    2.802170e+07  0.73
# 15    3.305017e+07  0.58
# 16    3.647062e+07  0.85
# 17    5.096213e+07  0.71
# 18    1.165222e+07  0.48
# 19    1.276108e+07  0.78
# 20    9.208396e+07  0.61
# 21    6.043210e+07  0.61
# 22    7.904996e+07  0.60
# 23    7.719574e+07  0.83
# 24    5.488371e+07  0.77
# 25    1.244182e+08  0.77
# 26    2.145036e+07  0.72
# 27    2.848169e+07  0.66
# 28    5.163843e+07  0.44
# 29    6.950220e+07  0.67
# ...            ...   ...
# 2584  5.301559e+07  0.92
# 2585  9.196851e+06  0.79
# 2586  7.171566e+07  0.67
# 2587  1.219948e+07  0.70
# 2588  5.820282e+07  0.77
# 2589  3.204240e+05  0.62
# 2590  2.134017e+07  0.90
# 2591  3.567290e+05  0.77
# 2592  5.836598e+07  0.75
# 2593  5.896610e+05  0.95
# 2594  8.572754e+07  0.81
# 2595  5.022610e+07  0.77
# 2596  3.408206e+07  0.90
# 2597  2.267632e+07  0.85
# 2598  4.430156e+07  0.80
# 2599  2.297527e+07  0.82
# 2600  1.940155e+05  0.73
# 2601  2.068783e+07  0.71
# 2602  5.984562e+07  0.97
# 2603  3.271260e+07  0.41
# 2604  2.059200e+05  0.52
# 2605  4.808505e+05  0.65
# 2606  1.166535e+07  0.95
# 2607  7.997514e+07  0.45
# 2608  6.337565e+07  0.71
# 2609  9.730137e+06  0.34
# 2610  1.105120e+07  0.71
# 2611  3.654950e+06  0.74
# 2612  5.406101e+07  0.71
# 2613  5.899863e+07  0.68
#
# [2614 rows x 2 columns]
#     <div class="bk-root">
#         <div class="plotdiv" id="e6335a35-ff03-4bdb-88e7-975d62bdcbef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e6335a35-ff03-4bdb-88e7-975d62bdcbef").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6335a35-ff03-4bdb-88e7-975d62bdcbef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6335a35-ff03-4bdb-88e7-975d62bdcbef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8ac01030-cdbd-441b-9c01-4823ce458a38":{"roots":{"references":[{"attributes":{},"id":"c8b132e4-381e-4d66-be0e-9e51c249d469","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"dc6a260b-ad86-4274-b7f8-f812c3748bf6","type":"Circle"},{"attributes":{"plot":{"id":"9ffdfa37-a394-463c-9991-be0b140fc7a7","subtype":"Chart","type":"Plot"}},"id":